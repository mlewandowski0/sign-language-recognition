# %% [markdown]
# This notebook will run MHI with decay specified in config, with transforms on
# - MobileNet
# - Resnet50
# - EfficientNetB0
#
# Dataset is 100 samples.<br>
# DECAY = 0.09<br>
# FRAME_SIZE = 20<br>
# BINARY_THRESHOLD = 25

# %%
# !pip install opencv-python numpy tensorflow scikit-learn matplotlib wandb tdqm wurlitzer albumentations
# Out:
# Requirement already satisfied: opencv-python in e:\anaconda\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow in e:\anaconda\lib\site-packages (2.16.1)
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (1.4.2)
# Requirement already satisfied: matplotlib in e:\anaconda\lib\site-packages (3.8.0)
# Requirement already satisfied: wandb in e:\anaconda\lib\site-packages (0.16.6)
# Requirement already satisfied: tdqm in e:\anaconda\lib\site-packages (0.0.1)
# Requirement already satisfied: wurlitzer in e:\anaconda\lib\site-packages (3.0.3)
# Requirement already satisfied: albumentations in e:\anaconda\lib\site-packages (1.4.3)
# Requirement already satisfied: tensorflow-intel==2.16.1 in e:\anaconda\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: scipy>=1.6.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in e:\anaconda\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in e:\anaconda\lib\site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in e:\anaconda\lib\site-packages (from wandb) (3.1.37)
# Requirement already satisfied: psutil>=5.0.0 in e:\anaconda\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in e:\anaconda\lib\site-packages (from wandb) (1.45.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in e:\anaconda\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in e:\anaconda\lib\site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in e:\anaconda\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in e:\anaconda\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: tqdm in e:\anaconda\lib\site-packages (from tdqm) (4.65.0)
# Requirement already satisfied: scikit-image>=0.21.0 in e:\anaconda\lib\site-packages (from albumentations) (0.22.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in e:\anaconda\lib\site-packages (from albumentations) (4.9.0.80)
# Requirement already satisfied: colorama in e:\anaconda\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\anaconda\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: networkx>=2.8 in e:\anaconda\lib\site-packages (from scikit-image>=0.21.0->albumentations) (3.1)
# Requirement already satisfied: imageio>=2.27 in e:\anaconda\lib\site-packages (from scikit-image>=0.21.0->albumentations) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in e:\anaconda\lib\site-packages (from scikit-image>=0.21.0->albumentations) (2023.4.12)
# Requirement already satisfied: lazy_loader>=0.3 in e:\anaconda\lib\site-packages (from scikit-image>=0.21.0->albumentations) (0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: smmap<5,>=3.0.1 in e:\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (4.0.0)
# Requirement already satisfied: rich in e:\anaconda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Requirement already satisfied: namex in e:\anaconda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in e:\anaconda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: markdown>=2.6.8 in e:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in e:\anaconda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\anaconda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in e:\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)

# %% [markdown]
# # Config

# %%
#all the required dependencies of the project
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import random
import wandb

from typing import Tuple
from collections import Counter
import albumentations as A
from tqdm import tqdm
from typing import List
import json
import tensorflow.keras as keras 
import tensorflow as tf

# %%
class CONFIG:
    ROOT_DIRECTORY = os.path.join("..","data","WLASL")
    JSON_FILE = "WLASL_v0.3.json"
    NSLT_FILE = "nslt_100.json"
    VIDEO_FOLDER = "videos"

    mean=[0, 0, 0]
    std=[1, 1, 1]
    DEBUG = True
    
    P_OF_TRANSFORM = 0.8
    P_OF_TRANSFORM_COLOR = 0.2
    
    SHIFT_LIMIT=0.1
    SCALE_LIMIT=0.05
    ROTATE_LIMIT=10
    
    # set to small, when prototyping, or 0 when deploying to cloud or PC with loads of RAM
    DATA_LIMIT = 100
    FRAME_SIZE = 20
    
    BATCH_SIZE = 4
    PORTION_OF_DATA_FOR_TRAINING = 0.8

    ROUND_DIGIT = 3
    #WANDB_RUN = "mediapipe-asl-dataset"
    DECAY = 0.09
    
    USE_WANDB = True

    WANDB_RUN = "MHI-CNN"

# %% [markdown]
# ## Utils

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LeakyReLU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import backend as K
from wandb.keras import WandbMetricsLogger
from keras.callbacks import Callback
from wandb.keras import WandbMetricsLogger
import tensorflow as tf
import wandb


class CosineAnnealingLearningRateScheduler(Callback):
    def __init__(self, max_lr, min_lr, T_max):
        super(CosineAnnealingLearningRateScheduler, self).__init__()
        self.max_lr = max_lr  # Maximum learning rate (i.e., start learning rate)
        self.min_lr = min_lr  # Minimum learning rate
        self.T_max = T_max    # Specifies the number of epochs per cycle
        self.t = 0            # Current epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.t += 1
        cos = np.cos(np.pi * (self.t % self.T_max) / self.T_max)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + cos)

        keras.backend.set_value(self.model.optimizer.lr, lr)

def keras_train(model, filepath : str, run_name : str,
                train_ds, val_ds, dataset_name,
                max_lr = 1e-4, min_lr = 5e-5,
                T_max=50, epochs=100,
                decay = 0.09,USE_WANDB=True): 
   
    checkpoint = keras.callbacks.ModelCheckpoint(filepath,
                                                 monitor="val_categorical_accuracy",
                                                 verbose=0,
                                                 save_best_only=True,
                                                 mode="max",
                                                 save_freq="epoch")
    
    cosine_annealer = CosineAnnealingLearningRateScheduler(max_lr=max_lr,
                                                           min_lr=min_lr,
                                                           T_max=T_max)

    callbacks = [checkpoint, cosine_annealer]

    if USE_WANDB:
        wandb.init(project=CONFIG.WANDB_RUN,
                        name=run_name,
                        notes="Model summary : \n" + str(model),
                        config={"max_lr" : max_lr, 
                                "min_lr" : min_lr, 
                                "scheduler" : "cosineAnnealer", 
                                "epochs" : epochs, 
                                "T_max" : T_max, 
                                "train_size" : train_ds_len,
                                "val_size" : val_ds_len,
                                "unique_classes" : unique_labels_num, 
                                "video_length" : CONFIG.FRAME_SIZE,
                                "decay" : decay,
                                "SHIFT_LIMIT" : CONFIG.SHIFT_LIMIT,
                                "SCALE_LIMIT" : CONFIG.SCALE_LIMIT,
                                "ROTATE_LIMIT" : CONFIG.ROTATE_LIMIT,
                                "CACHEING" : dataset_name
                               })
        callbacks.append(WandbMetricsLogger())
    
    #Adam Optimizer - fixed learning rate.
    adam_optimizer = tf.keras.optimizers.Adam(learning_rate=max_lr, clipnorm=1.)
    #lr_metric = get_lr_metric(adam_optimizer)

    model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    
    #history = model.fit(train_dataset_parquet, epochs=epochs, validation_data = val_dataset_parquet, batch_size = 8, callbacks=[WandbMetricsLogger(), checkpoint, cosine_annealer])
    history = model.fit(train_ds, epochs=epochs, validation_data = val_ds, batch_size = CONFIG.BATCH_SIZE, callbacks=callbacks)
    #wandb.finish()
    if USE_WANDB:      
        wandb.finish()
    
    return history

# %% [markdown]
# # Cacheing V1

# %% [markdown]
# ## Dataset definitions

# %%
from sklearn.model_selection import train_test_split
from math import ceil

class SignRecognitionDataset(keras.utils.Sequence):

    def __init__(self, max_start : int, max_end) -> None:
        # setup the paths
        video_path = os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.VIDEO_FOLDER)
        dataset_description = os.path.join(CONFIG.ROOT_DIRECTORY)

        # load the filepaths for videos
        self.video_paths = [os.path.join(video_path, file) for file in os.listdir(video_path)]

        # load the dataset config json
        self.config_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.JSON_FILE)) as f:
            self.config_json = json.load(f)

        # load the dataset json
        self.dataset_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.NSLT_FILE)) as f:
            self.dataset_json = json.load(f)
        
        self.videos_paths = []
        self.paths_not_found = []
        self.labels = []
        self.start_frames = []
        self.end_frames = []
       
        self.dataset_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.NSLT_FILE)) as f:
            self.dataset_json = json.load(f) 

        for el in tqdm(self.dataset_json.items()):
            video_id, properties = el[0], el[1]
            path = os.path.join(video_path, video_id + ".mp4")
            
            if not os.path.exists(path):
                self.paths_not_found.append(path)
                continue

            subset = properties["subset"]
            label, start, end = properties["action"]
            
            if start > max_start:
                continue
                
            if end > max_end:
                continue
            
            self.videos_paths.append(path)
            self.labels.append(label)
            self.start_frames.append(start)
            self.end_frames.append(end)
    
        self.videos_paths = np.array(self.video_paths)
        self.paths_not_found = np.array(self.paths_not_found)
        self.labels = np.array(self.labels)
        self.start_frames = np.array(self.start_frames)
        self.end_frames = np.array(self.end_frames)

        self.unique_labels = np.unique(self.labels)
        
    
    def preprocess_trajectory(self, traj : List[np.ndarray]):
        return traj
    
    def __len__(self):
        return len(self.videos_paths)

    def __getitem__(self, idx):
        path, label = self.videos_paths[idx], self.labels[idx]
        trajectory = SignRecognitionDataset.get_video(path)
        
        return self.preprocess_trajectory(trajectory), label

    def permutate(self):
        l = len(self.videos_paths)
        mask = np.arange(l)
        np.random.shuffle(mask)
        
        self.videos_paths = np.array(self.videos_paths)[mask]
        self.labels = np.array(self.labels)[mask]
        self.start_frames = np.array(self.start_frames)[mask]
        self.end_frames = np.array(self.end_frames)[mask]
        
    def sort_by_size(self):
        c = Counter(self.labels)
        _mask = sorted([ (10000 * c[l] + l, i) for i, l in enumerate(self.labels)])[::-1]
        mask_by_size = np.array([el[1] for el in _mask])

        self.video_paths        = np.array(self.video_paths)[mask_by_size]
        self.labels             = np.array(self.labels)[mask_by_size]
        self.start_frames       = np.array(self.start_frames)[mask_by_size]
        self.end_frames         = np.array(self.end_frames)[mask_by_size]

    def crop_video(self, trajectory : np.array) -> np.array:
        cropped = trajectory
        
        if self.FRAME_SIZE != 0:
            frame_size = len(trajectory)
            start = 0 
            
            if frame_size > self.FRAME_SIZE:
                start = np.random.randint(0, frame_size - self.FRAME_SIZE)
            cropped = trajectory[start: (start + self.FRAME_SIZE)]
                    
            if len(cropped) < self.FRAME_SIZE:
                necessary = self.FRAME_SIZE - len(cropped)
                t, h, w, c = trajectory.shape
                cropped = np.concatenate([cropped, np.zeros((necessary, h, w, c))], axis= 0)
                
            return cropped
                        
        return trajectory
                
    @staticmethod
    def get_video(video_path : str) -> List[np.ndarray]:

        if not os.path.exists(video_path):
            return None

        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            return None

        frames = []
        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                frame_array = np.array(frame)
                frames.append(cv2.cvtColor(frame_array, cv2.COLOR_BGR2RGB))
            else:
                break

        cap.release()
        return np.array(frames)

    @staticmethod
    def rescale_video(frames : np.ndarray, desired_shape) -> np.ndarray:
        refined = []
        for img in frames: 
            y, x, c = img.shape
            cropped = img[:, (x // 2 - y//2) : (x // 2 + y//2), :]
            scaled = cv2.resize(cropped, desired_shape)
            refined.append(scaled)
    
        return np.array(refined)
        
class SignRecognitionDatasetMHICached(SignRecognitionDataset):

    def __init__(self, max_start: int, max_end, 
                 per_image_transform=None,
                 after_MHI_transform=None,
                 scaled_resolution : Tuple[int]= (224, 224),
                 frame_size:int=CONFIG.FRAME_SIZE,
                 data_limit : int = CONFIG.DATA_LIMIT,
                 decay : float = 0.7,
                 threshold_method : str = "regular",
                 threshold_val : float = 25/255.,
                 by_size=True,
                 train_val_split:float=CONFIG.PORTION_OF_DATA_FOR_TRAINING,
                 split:str="train") -> None:
        super().__init__(max_start, max_end)
        self.scaled_resolution = scaled_resolution
        self.DATA_LIMIT = data_limit
        self.by_size = by_size
        self.per_image_transform = per_image_transform
        self.after_MHI_transform = after_MHI_transform
        self.FRAME_SIZE = frame_size
        self.decay = decay
        self.threshold_method = threshold_method
        self.threshold_val = threshold_val
        
        self.keywords = ["image" ] + list(str(i) for i in range(frame_size-1))
        
        self.sort_by_size()
        
        if self.DATA_LIMIT > 0:
            self.video_paths        = self.video_paths[:self.DATA_LIMIT]
            self.labels             = self.labels[:self.DATA_LIMIT]
            self.start_frames       = self.start_frames[:self.DATA_LIMIT]
            self.end_frames         = self.end_frames[:self.DATA_LIMIT]
        
        
        self.dataset = np.concatenate([np.array(self.video_paths).reshape(-1, 1),
                                       np.array(self.labels).reshape(-1, 1)], axis=1)   
        
        self.unique_labels = np.unique(self.dataset[:, 1])
        self.label_2_id = { key : i for i, key in enumerate(self.unique_labels)}
        train_ds, val_ds = train_test_split(self.dataset, train_size=train_val_split, 
                                            random_state=42, stratify=self.dataset[:, 1])
                                                            
        if split.lower() == "train":
            self.dataset = train_ds
            
        elif split.lower() == "val":
            self.dataset = val_ds
        
        else: 
            raise Exception("")

        self.cache_data()

    
    def cache_data(self):    
        self.cached_X = []
        self.cached_Y = []
        
        for i,el in tqdm(enumerate(self.dataset), desc="Cacheing"):
            
            trajectory = SignRecognitionDataset.get_video(el[0])  
            trajectory, label = self.preprocess_trajectory(trajectory), el[1]            
            
            onehotencoded = np.zeros(len(self.unique_labels))
            onehotencoded[self.label_2_id[label]] = 1.0
                    
            self.cached_X.append(trajectory)
            self.cached_Y.append(onehotencoded)
        
        
    def preprocess_trajectory(self, traj : List[np.ndarray]):
        return SignRecognitionDataset.rescale_video(traj, self.scaled_resolution)
        
    def __len__(self):
        return len(self.dataset)

    def postprocess_trajectory(self, traj : np.ndarray) -> np.ndarray:
        # timeframe, Width, height, channels
        ts, w, h, c = traj.shape
        
        mhi = np.zeros((w, h))
                
        for i in range(1, ts):
            frame_diff = np.abs(traj[i] - traj[i-1])
            gray_diff = np.mean(frame_diff, axis=2)
            
            _, binary_diff = cv2.threshold(gray_diff, self.threshold_val, 1.0, cv2.THRESH_BINARY)
    
    
            mhi = mhi * (1.0 - self.decay) + binary_diff

        mhi = mhi.reshape(mhi.shape[0], mhi.shape[1], 1)
        return np.concatenate([mhi,mhi,mhi], axis=2)


    def __getitem__(self, idx):
        
        trajectory, label = self.crop_video(self.cached_X[idx]), self.cached_Y[idx]
        
        if self.per_image_transform is not None:            
            frames = {self.keywords[i] : frame for i, frame in enumerate(trajectory)}
            processing = self.per_image_transform(**frames)       

            trajectory = np.array([processing[kw] for kw in self.keywords])    

        return self.postprocess_trajectory(trajectory), label

# %% [markdown]
# ## Dataset Creation

# %%
import matplotlib.pyplot as plt 

transform = A.Compose(
    [
        A.Normalize(mean=CONFIG.mean, std=CONFIG.std),
        #A.HorizontalFlip(p=CONFIG.P_OF_TRANSFORM),
        #A.ShiftScaleRotate(p=CONFIG.P_OF_TRANSFORM, shift_limit=CONFIG.SHIFT_LIMIT, 
        #                   scale_limit=CONFIG.SCALE_LIMIT, rotate_limit=CONFIG.ROTATE_LIMIT),
        #A.RandomBrightnessContrast(p=CONFIG.P_OF_TRANSFORM_COLOR),
        #A.RGBShift(p=CONFIG.P_OF_TRANSFORM_COLOR),
    ],
    additional_targets={str(i) : "image" for i in range(CONFIG.FRAME_SIZE)}
)

train_ds = SignRecognitionDatasetMHICached(1, 150, per_image_transform=transform, decay=0.01, split="train")
val_ds = SignRecognitionDatasetMHICached(1, 150, per_image_transform=transform, decay=0.01, split="val")

train_ds_len = len(train_ds)
val_ds_len = len(val_ds)
unique_labels_num = len(train_ds.unique_labels)

print(f"size of train_ds = {len(train_ds)}, size of val_ds = {len(val_ds)}")
x, y = next(iter(train_ds))
x_shape = x.shape
y_shape = y.shape
print(x_shape, y_shape)

def dataset_train_generator():
    # Instantiate your existing dataset loader

    for i in range(len(train_ds)):
        X_batch, Y_batch = train_ds[i]
        yield X_batch, Y_batch
        
def dataset_val_generator():
    # Instantiate your existing dataset loader

    for i in range(len(val_ds)):
        X_batch, Y_batch = val_ds[i]
        yield X_batch, Y_batch        

train_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_train_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)

val_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_val_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)
# Out:
# 100%|██████████| 2038/2038 [00:00<00:00, 43145.74it/s]
# Cacheing: 80it [00:12,  6.45it/s]
# 100%|██████████| 2038/2038 [00:00<00:00, 48468.72it/s]
# Cacheing: 20it [00:02,  6.84it/s]
# size of train_ds = 80, size of val_ds = 20
# (224, 224, 3) (7,)

# %%
train_labels = []
val_labels = []

for x, y in train_dataset:
    labels = np.argmax(y, axis=1)
    for l in labels:
        train_labels.append(l)
        
for x, y in val_dataset:
    labels = np.argmax(y, axis=1)
    for l in labels:
        val_labels.append(l)

# %%
for x, y in train_dataset:
    labels = np.argmax(y, axis=1)
    for l in labels:
        train_labels.append(l)

# %%
plt.hist(train_labels, alpha=0.7,label="training_labels", edgecolor="black")
plt.hist(val_labels, alpha=0.7,label="valdidation_labels",  edgecolor="black")
plt.legend()
plt.xlabel("label id")
plt.ylabel("count")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Run experimenets

# %% [markdown]
# ### MobileNetV3

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.MobileNetV3Small(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

hist = keras_train(model, run_name="C1_MobileNetV3Small_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 0.5e-4, 
            min_lr = 1e-5,
            T_max=10, 
            epochs=50,
            filepath=os.path.join("models", "MHI_MobileNetV3Small_no_transforms.keras"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: mlewand (mlewand7). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>e:\PROJS\dynamic-sign2\experiments\wandb\run-20240416_021044-63fh5m6z</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/63fh5m6z' target="_blank">C1_MobileNetV3Small_no_transforms</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/63fh5m6z' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/63fh5m6z</a>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 16
#      13 model.add(base_model)
#      14 model.add(Dense(len(train_ds.unique_labels), activation='softmax'))
# ---> 16 hist = keras_train(model, run_name="C1_MobileNetV3Small_no_transforms",
#      17             train_ds=train_dataset,
#      18             val_ds=val_dataset,
#      19             dataset_name="transforms_for_video_no_transforms",
#      20             max_lr = 0.5e-4,
#      21             min_lr = 1e-5,
#      22             T_max=10,
#      23             epochs=50,
#      24             filepath=os.path.join("models", "MHI_MobileNetV3Small_no_transforms.keras"),
#      25             USE_WANDB=CONFIG.USE_WANDB)
#
# Cell In[3], line 75, in keras_train(model, filepath, run_name, train_ds, val_ds, dataset_name, max_lr, min_lr, T_max, epochs, decay, USE_WANDB)
#      71 model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#      74 #history = model.fit(train_dataset_parquet, epochs=epochs, validation_data = val_dataset_parquet, batch_size = 8, callbacks=[WandbMetricsLogger(), checkpoint, cosine_annealer])
# ---> 75 history = model.fit(train_ds, epochs=epochs, validation_data = val_ds, batch_size = CONFIG.BATCH_SIZE, callbacks=callbacks)
#      76 #wandb.finish()
#      77 if USE_WANDB:
#
# File e:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In[3], line 25, in CosineAnnealingLearningRateScheduler.on_epoch_begin(self, epoch, logs)
#      22 cos = np.cos(np.pi * (self.t % self.T_max) / self.T_max)
#      23 lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + cos)
# ---> 25 keras.backend.set_value(self.model.optimizer.lr, lr)
#
# AttributeError: 'Adam' object has no attribute 'lr'

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.MobileNetV3Small(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, run_name="C1_MobileNetV3Small_2_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 0.5e-4, 
            min_lr = 1e-5,
            T_max=251, 
            epochs=500,
            filepath=os.path.join("models", "MHI_MobileNetV3Small_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)

# %% [markdown]
# ### Resnet50

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.ResNet50(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))


keras_train(model, run_name="C1_Resnet50_augmentation_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 0.5e-4, 
            min_lr = 1e-5,
            T_max=51, 
            epochs=100,
            filepath=os.path.join("models", "MHI_Resnet50_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_124133-mrbsyoj9</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/mrbsyoj9' target="_blank">C1_Resnet50_augmentation</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/mrbsyoj9' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/mrbsyoj9</a>
# Epoch 1/100
#      20/Unknown - 32s 187ms/step - loss: 2.7425 - categorical_accuracy: 0.1125
# 2024-04-15 12:42:08.295078: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 8940206431827680969
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 50s 1s/step - loss: 2.7425 - categorical_accuracy: 0.1125 - val_loss: 3.4292 - val_categorical_accuracy: 0.1000
# Epoch 2/100
# 20/20 [==============================] - ETA: 0s - loss: 2.3185 - categorical_accuracy: 0.1625INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 2.3185 - categorical_accuracy: 0.1625 - val_loss: 2.3697 - val_categorical_accuracy: 0.2000
# Epoch 3/100
# 20/20 [==============================] - 5s 248ms/step - loss: 2.1710 - categorical_accuracy: 0.1250 - val_loss: 2.5196 - val_categorical_accuracy: 0.1500
# Epoch 4/100
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9684 - categorical_accuracy: 0.3000 - val_loss: 3.2079 - val_categorical_accuracy: 0.2000
# Epoch 5/100
# 20/20 [==============================] - 5s 242ms/step - loss: 1.9586 - categorical_accuracy: 0.2750 - val_loss: 3.1360 - val_categorical_accuracy: 0.1000
# Epoch 6/100
# 20/20 [==============================] - 5s 248ms/step - loss: 1.6959 - categorical_accuracy: 0.3250 - val_loss: 3.4383 - val_categorical_accuracy: 0.1500
# Epoch 7/100
# 20/20 [==============================] - 5s 245ms/step - loss: 1.8800 - categorical_accuracy: 0.3125 - val_loss: 3.4253 - val_categorical_accuracy: 0.0500
# Epoch 8/100
# 20/20 [==============================] - 5s 238ms/step - loss: 1.5329 - categorical_accuracy: 0.4625 - val_loss: 2.7363 - val_categorical_accuracy: 0.1000
# Epoch 9/100
# 20/20 [==============================] - 5s 242ms/step - loss: 1.7456 - categorical_accuracy: 0.3625 - val_loss: 3.1268 - val_categorical_accuracy: 0.2000
# Epoch 10/100
# 20/20 [==============================] - 5s 244ms/step - loss: 1.6880 - categorical_accuracy: 0.4625 - val_loss: 3.3368 - val_categorical_accuracy: 0.1000
# Epoch 11/100
# 20/20 [==============================] - 5s 248ms/step - loss: 1.3554 - categorical_accuracy: 0.5375 - val_loss: 4.1161 - val_categorical_accuracy: 0.2000
# Epoch 12/100
# 20/20 [==============================] - 5s 239ms/step - loss: 1.5020 - categorical_accuracy: 0.4250 - val_loss: 3.2074 - val_categorical_accuracy: 0.1000
# Epoch 13/100
# 20/20 [==============================] - 5s 242ms/step - loss: 1.3363 - categorical_accuracy: 0.4875 - val_loss: 2.6486 - val_categorical_accuracy: 0.2000
# Epoch 14/100
# 20/20 [==============================] - 5s 244ms/step - loss: 1.1560 - categorical_accuracy: 0.6500 - val_loss: 2.7468 - val_categorical_accuracy: 0.1000
# Epoch 15/100
# 20/20 [==============================] - 5s 243ms/step - loss: 1.1131 - categorical_accuracy: 0.6000 - val_loss: 2.8127 - val_categorical_accuracy: 0.1500
# Epoch 16/100
# 20/20 [==============================] - 5s 238ms/step - loss: 1.1741 - categorical_accuracy: 0.5125 - val_loss: 3.7394 - val_categorical_accuracy: 0.1500
# Epoch 17/100
# 20/20 [==============================] - 5s 239ms/step - loss: 1.1705 - categorical_accuracy: 0.5625 - val_loss: 2.4529 - val_categorical_accuracy: 0.1500
# Epoch 18/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.9354 - categorical_accuracy: 0.7125 - val_loss: 2.9617 - val_categorical_accuracy: 0.1500
# Epoch 19/100
# 20/20 [==============================] - 5s 239ms/step - loss: 1.0185 - categorical_accuracy: 0.6500 - val_loss: 3.1583 - val_categorical_accuracy: 0.0500
# Epoch 20/100
# 20/20 [==============================] - 5s 245ms/step - loss: 0.9474 - categorical_accuracy: 0.6500 - val_loss: 2.5276 - val_categorical_accuracy: 0.1500
# Epoch 21/100
# 20/20 [==============================] - 5s 250ms/step - loss: 0.7761 - categorical_accuracy: 0.7375 - val_loss: 3.0610 - val_categorical_accuracy: 0.2000
# Epoch 22/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8915 - categorical_accuracy: 0.6875INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 20s 1s/step - loss: 0.8915 - categorical_accuracy: 0.6875 - val_loss: 2.2654 - val_categorical_accuracy: 0.3500
# Epoch 23/100
# 20/20 [==============================] - 5s 248ms/step - loss: 0.7608 - categorical_accuracy: 0.7500 - val_loss: 2.4483 - val_categorical_accuracy: 0.2500
# Epoch 24/100
# 20/20 [==============================] - 5s 243ms/step - loss: 0.6526 - categorical_accuracy: 0.8375 - val_loss: 3.1179 - val_categorical_accuracy: 0.1000
# Epoch 25/100
# 20/20 [==============================] - 5s 248ms/step - loss: 0.8073 - categorical_accuracy: 0.7375 - val_loss: 3.7050 - val_categorical_accuracy: 0.2500
# Epoch 26/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.6973 - categorical_accuracy: 0.7875 - val_loss: 3.9360 - val_categorical_accuracy: 0.2000
# Epoch 27/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.7814 - categorical_accuracy: 0.7250 - val_loss: 3.5362 - val_categorical_accuracy: 0.2000
# Epoch 28/100
# 20/20 [==============================] - 5s 237ms/step - loss: 0.6338 - categorical_accuracy: 0.7750 - val_loss: 2.4085 - val_categorical_accuracy: 0.1500
# Epoch 29/100
# 20/20 [==============================] - 5s 251ms/step - loss: 0.6750 - categorical_accuracy: 0.8125 - val_loss: 2.6050 - val_categorical_accuracy: 0.3000
# Epoch 30/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.6253 - categorical_accuracy: 0.8125 - val_loss: 3.7834 - val_categorical_accuracy: 0.3000
# Epoch 31/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.5956 - categorical_accuracy: 0.8000 - val_loss: 4.7422 - val_categorical_accuracy: 0.1500
# Epoch 32/100
# 20/20 [==============================] - 5s 248ms/step - loss: 0.6787 - categorical_accuracy: 0.7500 - val_loss: 4.4527 - val_categorical_accuracy: 0.2000
# Epoch 33/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.6631 - categorical_accuracy: 0.7750 - val_loss: 4.1475 - val_categorical_accuracy: 0.1000
# Epoch 34/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.5725 - categorical_accuracy: 0.8625 - val_loss: 3.1559 - val_categorical_accuracy: 0.2000
# Epoch 35/100
# 20/20 [==============================] - 5s 236ms/step - loss: 0.5852 - categorical_accuracy: 0.8000 - val_loss: 3.1117 - val_categorical_accuracy: 0.1500
# Epoch 36/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.5834 - categorical_accuracy: 0.8250 - val_loss: 4.2631 - val_categorical_accuracy: 0.2000
# Epoch 37/100
# 20/20 [==============================] - 5s 241ms/step - loss: 0.6217 - categorical_accuracy: 0.7625 - val_loss: 3.0749 - val_categorical_accuracy: 0.1000
# Epoch 38/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.5341 - categorical_accuracy: 0.8375 - val_loss: 3.3796 - val_categorical_accuracy: 0.3000
# Epoch 39/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.4462 - categorical_accuracy: 0.8375 - val_loss: 3.1858 - val_categorical_accuracy: 0.1000
# Epoch 40/100
# 20/20 [==============================] - 5s 253ms/step - loss: 0.5897 - categorical_accuracy: 0.8125 - val_loss: 4.2091 - val_categorical_accuracy: 0.1500
# Epoch 41/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.6730 - categorical_accuracy: 0.7875 - val_loss: 3.9058 - val_categorical_accuracy: 0.2000
# Epoch 42/100
# 20/20 [==============================] - 5s 255ms/step - loss: 0.4201 - categorical_accuracy: 0.8625 - val_loss: 4.2723 - val_categorical_accuracy: 0.3500
# Epoch 43/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.5603 - categorical_accuracy: 0.8375 - val_loss: 4.0860 - val_categorical_accuracy: 0.1000
# Epoch 44/100
# 20/20 [==============================] - 5s 241ms/step - loss: 0.4170 - categorical_accuracy: 0.8875 - val_loss: 4.5163 - val_categorical_accuracy: 0.2500
# Epoch 45/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.3786 - categorical_accuracy: 0.8750 - val_loss: 3.1661 - val_categorical_accuracy: 0.3000
# Epoch 46/100
# 20/20 [==============================] - 5s 239ms/step - loss: 0.3299 - categorical_accuracy: 0.9250 - val_loss: 3.2945 - val_categorical_accuracy: 0.2500
# Epoch 47/100
# 20/20 [==============================] - 5s 236ms/step - loss: 0.4211 - categorical_accuracy: 0.8500 - val_loss: 4.8720 - val_categorical_accuracy: 0.2000
# Epoch 48/100
# 20/20 [==============================] - 5s 258ms/step - loss: 0.2092 - categorical_accuracy: 0.9750 - val_loss: 4.3575 - val_categorical_accuracy: 0.2500
# Epoch 49/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.3083 - categorical_accuracy: 0.9250 - val_loss: 6.1871 - val_categorical_accuracy: 0.2500
# Epoch 50/100
# 20/20 [==============================] - 5s 243ms/step - loss: 0.4283 - categorical_accuracy: 0.8750 - val_loss: 3.7099 - val_categorical_accuracy: 0.3000
# Epoch 51/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.3590 - categorical_accuracy: 0.8750 - val_loss: 5.7642 - val_categorical_accuracy: 0.1500
# Epoch 52/100
# 20/20 [==============================] - 5s 243ms/step - loss: 0.3059 - categorical_accuracy: 0.8500 - val_loss: 6.7052 - val_categorical_accuracy: 0.1500
# Epoch 53/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.5219 - categorical_accuracy: 0.8250 - val_loss: 4.2934 - val_categorical_accuracy: 0.2000
# Epoch 54/100
# 20/20 [==============================] - 5s 239ms/step - loss: 0.4042 - categorical_accuracy: 0.8750 - val_loss: 3.5100 - val_categorical_accuracy: 0.3000
# Epoch 55/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.2431 - categorical_accuracy: 0.9375 - val_loss: 3.8594 - val_categorical_accuracy: 0.1500
# Epoch 56/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.5390 - categorical_accuracy: 0.8250 - val_loss: 4.1216 - val_categorical_accuracy: 0.3500
# Epoch 57/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.4836 - categorical_accuracy: 0.8375 - val_loss: 3.9760 - val_categorical_accuracy: 0.3500
# Epoch 58/100
# 20/20 [==============================] - 5s 245ms/step - loss: 0.5060 - categorical_accuracy: 0.8125 - val_loss: 4.0989 - val_categorical_accuracy: 0.3000
# Epoch 59/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.3181 - categorical_accuracy: 0.8750 - val_loss: 3.2118 - val_categorical_accuracy: 0.3500
# Epoch 60/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.3436 - categorical_accuracy: 0.8750 - val_loss: 4.7847 - val_categorical_accuracy: 0.2500
# Epoch 61/100
# 20/20 [==============================] - 5s 243ms/step - loss: 0.4427 - categorical_accuracy: 0.8500 - val_loss: 4.2317 - val_categorical_accuracy: 0.3500
# Epoch 62/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.3142 - categorical_accuracy: 0.9250 - val_loss: 4.5967 - val_categorical_accuracy: 0.3000
# Epoch 63/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.3759 - categorical_accuracy: 0.8500 - val_loss: 4.6187 - val_categorical_accuracy: 0.1500
# Epoch 64/100
# 20/20 [==============================] - 5s 241ms/step - loss: 0.4061 - categorical_accuracy: 0.8750 - val_loss: 3.0870 - val_categorical_accuracy: 0.2500
# Epoch 65/100
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2862 - categorical_accuracy: 0.8875 - val_loss: 3.3719 - val_categorical_accuracy: 0.2000
# Epoch 66/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.3357 - categorical_accuracy: 0.8875 - val_loss: 3.7645 - val_categorical_accuracy: 0.3000
# Epoch 67/100
# 20/20 [==============================] - 5s 239ms/step - loss: 0.1863 - categorical_accuracy: 0.9250 - val_loss: 3.9742 - val_categorical_accuracy: 0.3500
# Epoch 68/100
# 20/20 [==============================] - 5s 247ms/step - loss: 0.3035 - categorical_accuracy: 0.8875 - val_loss: 4.5900 - val_categorical_accuracy: 0.1500
# Epoch 69/100
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1658 - categorical_accuracy: 0.9375 - val_loss: 4.0201 - val_categorical_accuracy: 0.3500
# Epoch 70/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2241 - categorical_accuracy: 0.9250INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 0.2241 - categorical_accuracy: 0.9250 - val_loss: 5.5460 - val_categorical_accuracy: 0.4000
# Epoch 71/100
#  9/20 [============>.................] - ETA: 2s - loss: 0.0332 - categorical_accuracy: 1.0000

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.ResNet50(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))


keras_train(model, run_name="C1_Resnet50_augmentation_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 0.5e-4, 
            min_lr = 1e-5,
            T_max=251, 
            epochs=500,
            filepath=os.path.join("models", "MHI_Resnet50_2_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_131505-ccvd2jdl</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/ccvd2jdl' target="_blank">C1_Resnet50_augmentation</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/ccvd2jdl' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/ccvd2jdl</a>
# Epoch 1/500
#      20/Unknown - 31s 182ms/step - loss: 2.2559 - categorical_accuracy: 0.1625INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 48s 1s/step - loss: 2.2559 - categorical_accuracy: 0.1625 - val_loss: 2.8161 - val_categorical_accuracy: 0.1000
# Epoch 2/500
# 20/20 [==============================] - ETA: 0s - loss: 2.2016 - categorical_accuracy: 0.1500INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 2.2016 - categorical_accuracy: 0.1500 - val_loss: 2.2531 - val_categorical_accuracy: 0.2000
# Epoch 3/500
# 20/20 [==============================] - 5s 241ms/step - loss: 2.0535 - categorical_accuracy: 0.3000 - val_loss: 2.3415 - val_categorical_accuracy: 0.0500
# Epoch 4/500
# 20/20 [==============================] - 5s 244ms/step - loss: 1.8420 - categorical_accuracy: 0.3375 - val_loss: 2.0719 - val_categorical_accuracy: 0.2000
# Epoch 5/500
# 20/20 [==============================] - 5s 254ms/step - loss: 1.7283 - categorical_accuracy: 0.3250 - val_loss: 2.5633 - val_categorical_accuracy: 0.1500
# Epoch 6/500
# 20/20 [==============================] - 5s 245ms/step - loss: 1.5408 - categorical_accuracy: 0.4000 - val_loss: 2.9205 - val_categorical_accuracy: 0.0500
# Epoch 7/500
# 20/20 [==============================] - ETA: 0s - loss: 1.5710 - categorical_accuracy: 0.4375INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 1.5710 - categorical_accuracy: 0.4375 - val_loss: 2.4161 - val_categorical_accuracy: 0.2500
# Epoch 8/500
# 20/20 [==============================] - 5s 255ms/step - loss: 1.5095 - categorical_accuracy: 0.4750 - val_loss: 4.6276 - val_categorical_accuracy: 0.2000
# Epoch 9/500
# 20/20 [==============================] - 5s 245ms/step - loss: 1.2043 - categorical_accuracy: 0.5750 - val_loss: 4.0033 - val_categorical_accuracy: 0.1500
# Epoch 10/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.3818 - categorical_accuracy: 0.4625 - val_loss: 2.5415 - val_categorical_accuracy: 0.1000
# Epoch 11/500
# 20/20 [==============================] - 5s 245ms/step - loss: 1.4359 - categorical_accuracy: 0.4500 - val_loss: 2.9595 - val_categorical_accuracy: 0.1500
# Epoch 12/500
# 20/20 [==============================] - 5s 242ms/step - loss: 1.1256 - categorical_accuracy: 0.5875 - val_loss: 2.9570 - val_categorical_accuracy: 0.2000
# Epoch 13/500
# 20/20 [==============================] - 5s 242ms/step - loss: 1.1387 - categorical_accuracy: 0.5875 - val_loss: 3.7564 - val_categorical_accuracy: 0.1500
# Epoch 14/500
# 20/20 [==============================] - 5s 246ms/step - loss: 1.0176 - categorical_accuracy: 0.5875 - val_loss: 3.4903 - val_categorical_accuracy: 0.0000e+00
# Epoch 15/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.9377 - categorical_accuracy: 0.5875 - val_loss: 3.2524 - val_categorical_accuracy: 0.1000
# Epoch 16/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.9861 - categorical_accuracy: 0.7000 - val_loss: 3.5831 - val_categorical_accuracy: 0.0500
# Epoch 17/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.9883 - categorical_accuracy: 0.6125 - val_loss: 3.8016 - val_categorical_accuracy: 0.1500
# Epoch 18/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.9676 - categorical_accuracy: 0.6750 - val_loss: 3.8096 - val_categorical_accuracy: 0.1000
# Epoch 19/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.7997 - categorical_accuracy: 0.7625 - val_loss: 4.4353 - val_categorical_accuracy: 0.0500
# Epoch 20/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.9328 - categorical_accuracy: 0.6875 - val_loss: 4.1552 - val_categorical_accuracy: 0.1500
# Epoch 21/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.8627 - categorical_accuracy: 0.6625 - val_loss: 3.9051 - val_categorical_accuracy: 0.0500
# Epoch 22/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.8663 - categorical_accuracy: 0.7125 - val_loss: 5.3695 - val_categorical_accuracy: 0.1000
# Epoch 23/500
# 20/20 [==============================] - ETA: 0s - loss: 0.7793 - categorical_accuracy: 0.7250INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 0.7793 - categorical_accuracy: 0.7250 - val_loss: 3.3272 - val_categorical_accuracy: 0.3000
# Epoch 24/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.8156 - categorical_accuracy: 0.7125 - val_loss: 4.3214 - val_categorical_accuracy: 0.1500
# Epoch 25/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.8565 - categorical_accuracy: 0.7250 - val_loss: 4.9854 - val_categorical_accuracy: 0.1500
# Epoch 26/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.7412 - categorical_accuracy: 0.7375 - val_loss: 3.4444 - val_categorical_accuracy: 0.2500
# Epoch 27/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.5364 - categorical_accuracy: 0.8625 - val_loss: 3.9056 - val_categorical_accuracy: 0.0500
# Epoch 28/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.7214 - categorical_accuracy: 0.7375 - val_loss: 4.0813 - val_categorical_accuracy: 0.3000
# Epoch 29/500
# 20/20 [==============================] - ETA: 0s - loss: 0.6302 - categorical_accuracy: 0.7875INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 22s 1s/step - loss: 0.6302 - categorical_accuracy: 0.7875 - val_loss: 3.0000 - val_categorical_accuracy: 0.3500
# Epoch 30/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.6068 - categorical_accuracy: 0.8125 - val_loss: 3.7095 - val_categorical_accuracy: 0.2000
# Epoch 31/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.5476 - categorical_accuracy: 0.8375 - val_loss: 3.9564 - val_categorical_accuracy: 0.2000
# Epoch 32/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.5385 - categorical_accuracy: 0.8500 - val_loss: 4.1791 - val_categorical_accuracy: 0.2500
# Epoch 33/500
# 20/20 [==============================] - ETA: 0s - loss: 0.6450 - categorical_accuracy: 0.7875INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 0.6450 - categorical_accuracy: 0.7875 - val_loss: 3.1386 - val_categorical_accuracy: 0.4000
# Epoch 34/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.6010 - categorical_accuracy: 0.8000 - val_loss: 3.9849 - val_categorical_accuracy: 0.2000
# Epoch 35/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.3713 - categorical_accuracy: 0.9000 - val_loss: 2.7535 - val_categorical_accuracy: 0.2000
# Epoch 36/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.2770 - categorical_accuracy: 0.9000 - val_loss: 2.1210 - val_categorical_accuracy: 0.4000
# Epoch 37/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.5238 - categorical_accuracy: 0.8250 - val_loss: 2.4425 - val_categorical_accuracy: 0.3500
# Epoch 38/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.4729 - categorical_accuracy: 0.8500 - val_loss: 5.8577 - val_categorical_accuracy: 0.1500
# Epoch 39/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.2390 - categorical_accuracy: 0.9250 - val_loss: 4.9852 - val_categorical_accuracy: 0.2000
# Epoch 40/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.3964 - categorical_accuracy: 0.8375 - val_loss: 3.5430 - val_categorical_accuracy: 0.2000
# Epoch 41/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.2522 - categorical_accuracy: 0.9375 - val_loss: 3.2760 - val_categorical_accuracy: 0.3000
# Epoch 42/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.2775 - categorical_accuracy: 0.9250 - val_loss: 4.1750 - val_categorical_accuracy: 0.2500
# Epoch 43/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.3359 - categorical_accuracy: 0.8875 - val_loss: 5.9057 - val_categorical_accuracy: 0.2000
# Epoch 44/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.3238 - categorical_accuracy: 0.9125 - val_loss: 6.3514 - val_categorical_accuracy: 0.3000
# Epoch 45/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.4313 - categorical_accuracy: 0.8500 - val_loss: 4.1008 - val_categorical_accuracy: 0.3500
# Epoch 46/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1473 - categorical_accuracy: 0.9500 - val_loss: 3.0184 - val_categorical_accuracy: 0.1000
# Epoch 47/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.3478 - categorical_accuracy: 0.8875 - val_loss: 2.6242 - val_categorical_accuracy: 0.3500
# Epoch 48/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.4679 - categorical_accuracy: 0.8125 - val_loss: 3.8306 - val_categorical_accuracy: 0.2500
# Epoch 49/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.3244 - categorical_accuracy: 0.8875 - val_loss: 3.1986 - val_categorical_accuracy: 0.3000
# Epoch 50/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1181 - categorical_accuracy: 0.9750 - val_loss: 2.2607 - val_categorical_accuracy: 0.4000
# Epoch 51/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.2194 - categorical_accuracy: 0.9250 - val_loss: 2.8761 - val_categorical_accuracy: 0.4000
# Epoch 52/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2295 - categorical_accuracy: 0.9125 - val_loss: 5.1723 - val_categorical_accuracy: 0.2000
# Epoch 53/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.2345 - categorical_accuracy: 0.9125 - val_loss: 3.8610 - val_categorical_accuracy: 0.1500
# Epoch 54/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.2154 - categorical_accuracy: 0.9250 - val_loss: 4.3424 - val_categorical_accuracy: 0.3000
# Epoch 55/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.2738 - categorical_accuracy: 0.9125 - val_loss: 4.1472 - val_categorical_accuracy: 0.1500
# Epoch 56/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.2570 - categorical_accuracy: 0.9125 - val_loss: 2.9664 - val_categorical_accuracy: 0.4000
# Epoch 57/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.3221 - categorical_accuracy: 0.9125 - val_loss: 2.7597 - val_categorical_accuracy: 0.2000
# Epoch 58/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.3237 - categorical_accuracy: 0.8750 - val_loss: 3.0243 - val_categorical_accuracy: 0.3000
# Epoch 59/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1792 - categorical_accuracy: 0.9375 - val_loss: 4.4958 - val_categorical_accuracy: 0.2500
# Epoch 60/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1411 - categorical_accuracy: 0.9625 - val_loss: 5.3184 - val_categorical_accuracy: 0.2500
# Epoch 61/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1535 - categorical_accuracy: 0.9375 - val_loss: 3.0463 - val_categorical_accuracy: 0.3000
# Epoch 62/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1143 - categorical_accuracy: 0.9625 - val_loss: 4.0625 - val_categorical_accuracy: 0.3000
# Epoch 63/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.1336 - categorical_accuracy: 0.9625 - val_loss: 4.1369 - val_categorical_accuracy: 0.1500
# Epoch 64/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.1214 - categorical_accuracy: 0.9750 - val_loss: 3.6298 - val_categorical_accuracy: 0.2000
# Epoch 65/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.3265 - categorical_accuracy: 0.9250 - val_loss: 4.9170 - val_categorical_accuracy: 0.2500
# Epoch 66/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1930 - categorical_accuracy: 0.9500 - val_loss: 5.5840 - val_categorical_accuracy: 0.3000
# Epoch 67/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1677 - categorical_accuracy: 0.9625 - val_loss: 3.6878 - val_categorical_accuracy: 0.2000
# Epoch 68/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0331 - categorical_accuracy: 1.0000 - val_loss: 4.1615 - val_categorical_accuracy: 0.1500
# Epoch 69/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0784 - categorical_accuracy: 0.9750 - val_loss: 3.9339 - val_categorical_accuracy: 0.2000
# Epoch 70/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.2220 - categorical_accuracy: 0.9375 - val_loss: 4.0844 - val_categorical_accuracy: 0.1500
# Epoch 71/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2140 - categorical_accuracy: 0.9500 - val_loss: 3.2895 - val_categorical_accuracy: 0.3000
# Epoch 72/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.1076 - categorical_accuracy: 0.9750 - val_loss: 3.7110 - val_categorical_accuracy: 0.3500
# Epoch 73/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1243 - categorical_accuracy: 0.9750 - val_loss: 4.1088 - val_categorical_accuracy: 0.3000
# Epoch 74/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1302 - categorical_accuracy: 0.9500 - val_loss: 4.1671 - val_categorical_accuracy: 0.2000
# Epoch 75/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0838 - categorical_accuracy: 0.9750 - val_loss: 2.7171 - val_categorical_accuracy: 0.3500
# Epoch 76/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0874 - categorical_accuracy: 0.9750 - val_loss: 4.4994 - val_categorical_accuracy: 0.2000
# Epoch 77/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1138 - categorical_accuracy: 0.9750 - val_loss: 3.8462 - val_categorical_accuracy: 0.2000
# Epoch 78/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0323 - categorical_accuracy: 1.0000 - val_loss: 4.3667 - val_categorical_accuracy: 0.3000
# Epoch 79/500
# 20/20 [==============================] - 5s 260ms/step - loss: 0.0920 - categorical_accuracy: 0.9875 - val_loss: 5.3457 - val_categorical_accuracy: 0.1500
# Epoch 80/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0851 - categorical_accuracy: 0.9625 - val_loss: 5.0697 - val_categorical_accuracy: 0.1500
# Epoch 81/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0436 - categorical_accuracy: 1.0000 - val_loss: 5.4873 - val_categorical_accuracy: 0.2000
# Epoch 82/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0614 - categorical_accuracy: 0.9750 - val_loss: 4.0435 - val_categorical_accuracy: 0.3000
# Epoch 83/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.1895 - categorical_accuracy: 0.9500 - val_loss: 4.7996 - val_categorical_accuracy: 0.2500
# Epoch 84/500
# 20/20 [==============================] - ETA: 0s - loss: 0.0559 - categorical_accuracy: 0.9750INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 21s 1s/step - loss: 0.0559 - categorical_accuracy: 0.9750 - val_loss: 3.2410 - val_categorical_accuracy: 0.4500
# Epoch 85/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0351 - categorical_accuracy: 1.0000 - val_loss: 4.8353 - val_categorical_accuracy: 0.2500
# Epoch 86/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0766 - categorical_accuracy: 0.9875 - val_loss: 3.9569 - val_categorical_accuracy: 0.2500
# Epoch 87/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0994 - categorical_accuracy: 0.9750 - val_loss: 3.5450 - val_categorical_accuracy: 0.1500
# Epoch 88/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0467 - categorical_accuracy: 0.9875 - val_loss: 4.7898 - val_categorical_accuracy: 0.2000
# Epoch 89/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0294 - categorical_accuracy: 0.9875 - val_loss: 3.0480 - val_categorical_accuracy: 0.1500
# Epoch 90/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0893 - categorical_accuracy: 0.9750 - val_loss: 4.7243 - val_categorical_accuracy: 0.2500
# Epoch 91/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0586 - categorical_accuracy: 0.9875 - val_loss: 4.0443 - val_categorical_accuracy: 0.2500
# Epoch 92/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.2085 - categorical_accuracy: 0.9375 - val_loss: 4.2804 - val_categorical_accuracy: 0.2500
# Epoch 93/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0321 - categorical_accuracy: 0.9875 - val_loss: 3.7928 - val_categorical_accuracy: 0.3000
# Epoch 94/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1073 - categorical_accuracy: 0.9750 - val_loss: 4.3043 - val_categorical_accuracy: 0.2500
# Epoch 95/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0586 - categorical_accuracy: 0.9750 - val_loss: 3.2019 - val_categorical_accuracy: 0.3000
# Epoch 96/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1092 - categorical_accuracy: 0.9625 - val_loss: 4.0916 - val_categorical_accuracy: 0.2500
# Epoch 97/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0423 - categorical_accuracy: 0.9875 - val_loss: 3.9882 - val_categorical_accuracy: 0.2000
# Epoch 98/500
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0356 - categorical_accuracy: 0.9750 - val_loss: 3.3708 - val_categorical_accuracy: 0.3000
# Epoch 99/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0582 - categorical_accuracy: 0.9750 - val_loss: 3.4996 - val_categorical_accuracy: 0.2500
# Epoch 100/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0692 - categorical_accuracy: 0.9750 - val_loss: 3.8120 - val_categorical_accuracy: 0.2500
# Epoch 101/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0919 - categorical_accuracy: 0.9625 - val_loss: 3.9930 - val_categorical_accuracy: 0.2500
# Epoch 102/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0209 - categorical_accuracy: 1.0000 - val_loss: 5.0904 - val_categorical_accuracy: 0.3000
# Epoch 103/500
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0371 - categorical_accuracy: 0.9875 - val_loss: 4.7185 - val_categorical_accuracy: 0.1500
# Epoch 104/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0791 - categorical_accuracy: 0.9625 - val_loss: 2.7086 - val_categorical_accuracy: 0.4000
# Epoch 105/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0446 - categorical_accuracy: 0.9875 - val_loss: 3.4236 - val_categorical_accuracy: 0.3500
# Epoch 106/500
# 20/20 [==============================] - ETA: 0s - loss: 0.0435 - categorical_accuracy: 0.9875INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50_2.tf/assets
# 20/20 [==============================] - 22s 1s/step - loss: 0.0435 - categorical_accuracy: 0.9875 - val_loss: 3.9502 - val_categorical_accuracy: 0.5000
# Epoch 107/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0393 - categorical_accuracy: 0.9875 - val_loss: 3.4501 - val_categorical_accuracy: 0.3500
# Epoch 108/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0864 - categorical_accuracy: 0.9750 - val_loss: 3.5222 - val_categorical_accuracy: 0.2000
# Epoch 109/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0203 - categorical_accuracy: 1.0000 - val_loss: 3.8761 - val_categorical_accuracy: 0.2000
# Epoch 110/500
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0253 - categorical_accuracy: 0.9875 - val_loss: 4.1685 - val_categorical_accuracy: 0.2500
# Epoch 111/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0717 - categorical_accuracy: 0.9625 - val_loss: 5.0495 - val_categorical_accuracy: 0.3500
# Epoch 112/500
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0142 - categorical_accuracy: 1.0000 - val_loss: 4.0529 - val_categorical_accuracy: 0.3000
# Epoch 113/500
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1544 - categorical_accuracy: 0.9750 - val_loss: 4.8685 - val_categorical_accuracy: 0.2000
# Epoch 114/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0071 - categorical_accuracy: 1.0000 - val_loss: 4.2358 - val_categorical_accuracy: 0.2500
# Epoch 115/500
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0320 - categorical_accuracy: 0.9875 - val_loss: 3.8138 - val_categorical_accuracy: 0.3500
# Epoch 116/500
# 20/20 [==============================] - 5s 269ms/step - loss: 0.1349 - categorical_accuracy: 0.9625 - val_loss: 5.1842 - val_categorical_accuracy: 0.3000
# Epoch 117/500
# 20/20 [==============================] - 5s 268ms/step - loss: 0.1814 - categorical_accuracy: 0.9625 - val_loss: 5.7244 - val_categorical_accuracy: 0.2500
# Epoch 118/500
# 20/20 [==============================] - 6s 274ms/step - loss: 0.0107 - categorical_accuracy: 1.0000 - val_loss: 4.4739 - val_categorical_accuracy: 0.3500
# Epoch 119/500
# 20/20 [==============================] - 6s 288ms/step - loss: 0.0158 - categorical_accuracy: 1.0000 - val_loss: 4.7167 - val_categorical_accuracy: 0.2500
# Epoch 120/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0445 - categorical_accuracy: 0.9875 - val_loss: 4.5717 - val_categorical_accuracy: 0.2500
# Epoch 121/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0817 - categorical_accuracy: 0.9750 - val_loss: 3.6490 - val_categorical_accuracy: 0.2000
# Epoch 122/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0365 - categorical_accuracy: 0.9875 - val_loss: 3.4197 - val_categorical_accuracy: 0.2000
# Epoch 123/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0138 - categorical_accuracy: 1.0000 - val_loss: 4.1203 - val_categorical_accuracy: 0.2000
# Epoch 124/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0104 - categorical_accuracy: 1.0000 - val_loss: 3.8950 - val_categorical_accuracy: 0.2000
# Epoch 125/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0276 - categorical_accuracy: 0.9875 - val_loss: 4.4652 - val_categorical_accuracy: 0.2500
# Epoch 126/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0678 - categorical_accuracy: 0.9625 - val_loss: 5.1612 - val_categorical_accuracy: 0.1000
# Epoch 127/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0245 - categorical_accuracy: 0.9875 - val_loss: 3.6364 - val_categorical_accuracy: 0.2500
# Epoch 128/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0126 - categorical_accuracy: 1.0000 - val_loss: 3.2762 - val_categorical_accuracy: 0.3000
# Epoch 129/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0606 - categorical_accuracy: 0.9750 - val_loss: 4.9638 - val_categorical_accuracy: 0.2500
# Epoch 130/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0061 - categorical_accuracy: 1.0000 - val_loss: 3.7882 - val_categorical_accuracy: 0.3000
# Epoch 131/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0195 - categorical_accuracy: 1.0000 - val_loss: 2.8738 - val_categorical_accuracy: 0.4500
# Epoch 132/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0347 - categorical_accuracy: 0.9875 - val_loss: 3.7187 - val_categorical_accuracy: 0.3000
# Epoch 133/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0280 - categorical_accuracy: 0.9875 - val_loss: 3.8138 - val_categorical_accuracy: 0.4000
# Epoch 134/500
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0245 - categorical_accuracy: 0.9875 - val_loss: 4.2468 - val_categorical_accuracy: 0.2500
# Epoch 135/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0595 - categorical_accuracy: 0.9750 - val_loss: 3.2016 - val_categorical_accuracy: 0.2500
# Epoch 136/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0181 - categorical_accuracy: 1.0000 - val_loss: 2.7540 - val_categorical_accuracy: 0.3500
# Epoch 137/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0101 - categorical_accuracy: 1.0000 - val_loss: 3.8156 - val_categorical_accuracy: 0.3500
# Epoch 138/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0057 - categorical_accuracy: 1.0000 - val_loss: 2.3570 - val_categorical_accuracy: 0.3500
# Epoch 139/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0062 - categorical_accuracy: 1.0000 - val_loss: 3.8954 - val_categorical_accuracy: 0.3000
# Epoch 140/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0242 - categorical_accuracy: 0.9875 - val_loss: 3.3819 - val_categorical_accuracy: 0.3000
# Epoch 141/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0036 - categorical_accuracy: 1.0000 - val_loss: 3.7863 - val_categorical_accuracy: 0.3000
# Epoch 142/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0312 - categorical_accuracy: 0.9875 - val_loss: 3.4016 - val_categorical_accuracy: 0.4500
# Epoch 143/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0267 - categorical_accuracy: 0.9875 - val_loss: 4.2302 - val_categorical_accuracy: 0.3000
# Epoch 144/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0261 - categorical_accuracy: 0.9875 - val_loss: 3.6834 - val_categorical_accuracy: 0.3000
# Epoch 145/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0221 - categorical_accuracy: 0.9875 - val_loss: 3.3842 - val_categorical_accuracy: 0.3500
# Epoch 146/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0115 - categorical_accuracy: 1.0000 - val_loss: 3.9681 - val_categorical_accuracy: 0.3500
# Epoch 147/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0271 - categorical_accuracy: 0.9875 - val_loss: 3.8557 - val_categorical_accuracy: 0.3500
# Epoch 148/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0068 - categorical_accuracy: 1.0000 - val_loss: 4.4331 - val_categorical_accuracy: 0.2500
# Epoch 149/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0122 - categorical_accuracy: 1.0000 - val_loss: 3.8276 - val_categorical_accuracy: 0.3000
# Epoch 150/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0264 - categorical_accuracy: 0.9875 - val_loss: 4.1894 - val_categorical_accuracy: 0.3500
# Epoch 151/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0244 - categorical_accuracy: 1.0000 - val_loss: 3.3153 - val_categorical_accuracy: 0.4500
# Epoch 152/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0055 - categorical_accuracy: 1.0000 - val_loss: 3.1304 - val_categorical_accuracy: 0.4000
# Epoch 153/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1855 - categorical_accuracy: 0.9750 - val_loss: 3.8487 - val_categorical_accuracy: 0.4000
# Epoch 154/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0179 - categorical_accuracy: 1.0000 - val_loss: 2.5956 - val_categorical_accuracy: 0.4000
# Epoch 155/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0046 - categorical_accuracy: 1.0000 - val_loss: 3.5128 - val_categorical_accuracy: 0.2500
# Epoch 156/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0589 - categorical_accuracy: 0.9750 - val_loss: 3.0450 - val_categorical_accuracy: 0.3000
# Epoch 157/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0086 - categorical_accuracy: 1.0000 - val_loss: 3.6811 - val_categorical_accuracy: 0.4000
# Epoch 158/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0052 - categorical_accuracy: 1.0000 - val_loss: 3.6793 - val_categorical_accuracy: 0.4500
# Epoch 159/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0218 - categorical_accuracy: 0.9875 - val_loss: 3.6698 - val_categorical_accuracy: 0.3500
# Epoch 160/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0414 - categorical_accuracy: 0.9875 - val_loss: 3.0299 - val_categorical_accuracy: 0.4000
# Epoch 161/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0300 - categorical_accuracy: 0.9875 - val_loss: 4.0514 - val_categorical_accuracy: 0.2500
# Epoch 162/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 3.0467 - val_categorical_accuracy: 0.3000
# Epoch 163/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0155 - categorical_accuracy: 1.0000 - val_loss: 3.5692 - val_categorical_accuracy: 0.2000
# Epoch 164/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 2.9096 - val_categorical_accuracy: 0.4000
# Epoch 165/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 3.9119 - val_categorical_accuracy: 0.3000
# Epoch 166/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0132 - categorical_accuracy: 1.0000 - val_loss: 4.2181 - val_categorical_accuracy: 0.4000
# Epoch 167/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0099 - categorical_accuracy: 1.0000 - val_loss: 3.6862 - val_categorical_accuracy: 0.3000
# Epoch 168/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0030 - categorical_accuracy: 1.0000 - val_loss: 3.6160 - val_categorical_accuracy: 0.3500
# Epoch 169/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 3.1855 - val_categorical_accuracy: 0.2500
# Epoch 170/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0979 - categorical_accuracy: 0.9625 - val_loss: 3.4365 - val_categorical_accuracy: 0.3500
# Epoch 171/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 4.3940 - val_categorical_accuracy: 0.2500
# Epoch 172/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 3.9634 - val_categorical_accuracy: 0.3500
# Epoch 173/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0093 - categorical_accuracy: 1.0000 - val_loss: 3.6461 - val_categorical_accuracy: 0.3000
# Epoch 174/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 3.3624 - val_categorical_accuracy: 0.3500
# Epoch 175/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0084 - categorical_accuracy: 1.0000 - val_loss: 4.2113 - val_categorical_accuracy: 0.3000
# Epoch 176/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 3.5983 - val_categorical_accuracy: 0.3500
# Epoch 177/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0036 - categorical_accuracy: 1.0000 - val_loss: 3.7298 - val_categorical_accuracy: 0.3500
# Epoch 178/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0040 - categorical_accuracy: 1.0000 - val_loss: 4.0504 - val_categorical_accuracy: 0.4000
# Epoch 179/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0034 - categorical_accuracy: 1.0000 - val_loss: 4.6941 - val_categorical_accuracy: 0.3000
# Epoch 180/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 3.7390 - val_categorical_accuracy: 0.2500
# Epoch 181/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0034 - categorical_accuracy: 1.0000 - val_loss: 3.3816 - val_categorical_accuracy: 0.3500
# Epoch 182/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0407 - categorical_accuracy: 0.9875 - val_loss: 3.5081 - val_categorical_accuracy: 0.4000
# Epoch 183/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 3.8392 - val_categorical_accuracy: 0.4000
# Epoch 184/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0087 - categorical_accuracy: 1.0000 - val_loss: 3.9199 - val_categorical_accuracy: 0.2500
# Epoch 185/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 3.7307 - val_categorical_accuracy: 0.1500
# Epoch 186/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0086 - categorical_accuracy: 1.0000 - val_loss: 3.7262 - val_categorical_accuracy: 0.2500
# Epoch 187/500
# 20/20 [==============================] - 5s 234ms/step - loss: 0.0246 - categorical_accuracy: 0.9875 - val_loss: 3.8218 - val_categorical_accuracy: 0.3500
# Epoch 188/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0194 - categorical_accuracy: 1.0000 - val_loss: 3.0753 - val_categorical_accuracy: 0.2500
# Epoch 189/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0332 - categorical_accuracy: 0.9875 - val_loss: 3.3534 - val_categorical_accuracy: 0.4500
# Epoch 190/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0068 - categorical_accuracy: 1.0000 - val_loss: 3.6856 - val_categorical_accuracy: 0.3000
# Epoch 191/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0145 - categorical_accuracy: 0.9875 - val_loss: 3.1197 - val_categorical_accuracy: 0.2000
# Epoch 192/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 4.1746 - val_categorical_accuracy: 0.4000
# Epoch 193/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0062 - categorical_accuracy: 1.0000 - val_loss: 3.4506 - val_categorical_accuracy: 0.3000
# Epoch 194/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0030 - categorical_accuracy: 1.0000 - val_loss: 3.8765 - val_categorical_accuracy: 0.3500
# Epoch 195/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 3.2754 - val_categorical_accuracy: 0.3500
# Epoch 196/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 3.9819 - val_categorical_accuracy: 0.3000
# Epoch 197/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 4.4820 - val_categorical_accuracy: 0.2000
# Epoch 198/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 3.8097 - val_categorical_accuracy: 0.4500
# Epoch 199/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0039 - categorical_accuracy: 1.0000 - val_loss: 4.0736 - val_categorical_accuracy: 0.3500
# Epoch 200/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 3.9511 - val_categorical_accuracy: 0.3500
# Epoch 201/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0147 - categorical_accuracy: 0.9875 - val_loss: 3.9883 - val_categorical_accuracy: 0.2500
# Epoch 202/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 3.9855 - val_categorical_accuracy: 0.3500
# Epoch 203/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0345 - categorical_accuracy: 0.9875 - val_loss: 4.5191 - val_categorical_accuracy: 0.3000
# Epoch 204/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0097 - categorical_accuracy: 1.0000 - val_loss: 4.4708 - val_categorical_accuracy: 0.3500
# Epoch 205/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 3.9777 - val_categorical_accuracy: 0.3500
# Epoch 206/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0289 - categorical_accuracy: 0.9750 - val_loss: 3.1479 - val_categorical_accuracy: 0.2500
# Epoch 207/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 3.5118 - val_categorical_accuracy: 0.2500
# Epoch 208/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 3.0628 - val_categorical_accuracy: 0.4500
# Epoch 209/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0078 - categorical_accuracy: 1.0000 - val_loss: 3.9097 - val_categorical_accuracy: 0.4500
# Epoch 210/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0209 - categorical_accuracy: 0.9875 - val_loss: 4.1299 - val_categorical_accuracy: 0.1500
# Epoch 211/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 2.7653 - val_categorical_accuracy: 0.4500
# Epoch 212/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0159 - categorical_accuracy: 0.9875 - val_loss: 4.1642 - val_categorical_accuracy: 0.3500
# Epoch 213/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0069 - categorical_accuracy: 1.0000 - val_loss: 4.4510 - val_categorical_accuracy: 0.2500
# Epoch 214/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 4.3903 - val_categorical_accuracy: 0.3000
# Epoch 215/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 3.0170 - val_categorical_accuracy: 0.4500
# Epoch 216/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 3.8461 - val_categorical_accuracy: 0.2500
# Epoch 217/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 3.7549 - val_categorical_accuracy: 0.2500
# Epoch 218/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 3.7130 - val_categorical_accuracy: 0.3500
# Epoch 219/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 2.7597 - val_categorical_accuracy: 0.3000
# Epoch 220/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 3.1288 - val_categorical_accuracy: 0.3000
# Epoch 221/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 3.9809 - val_categorical_accuracy: 0.2000
# Epoch 222/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0056 - categorical_accuracy: 1.0000 - val_loss: 3.5883 - val_categorical_accuracy: 0.3500
# Epoch 223/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0073 - categorical_accuracy: 1.0000 - val_loss: 4.4526 - val_categorical_accuracy: 0.2500
# Epoch 224/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0034 - categorical_accuracy: 1.0000 - val_loss: 3.8210 - val_categorical_accuracy: 0.3000
# Epoch 225/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 3.2722 - val_categorical_accuracy: 0.4500
# Epoch 226/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 3.3468 - val_categorical_accuracy: 0.3500
# Epoch 227/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 3.8689 - val_categorical_accuracy: 0.3500
# Epoch 228/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0046 - categorical_accuracy: 1.0000 - val_loss: 3.9218 - val_categorical_accuracy: 0.2000
# Epoch 229/500
# 20/20 [==============================] - 5s 234ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 4.2547 - val_categorical_accuracy: 0.2000
# Epoch 230/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 3.6393 - val_categorical_accuracy: 0.3500
# Epoch 231/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0667 - categorical_accuracy: 0.9625 - val_loss: 3.4447 - val_categorical_accuracy: 0.3500
# Epoch 232/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 3.5780 - val_categorical_accuracy: 0.2000
# Epoch 233/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0248 - categorical_accuracy: 0.9875 - val_loss: 6.0268 - val_categorical_accuracy: 0.3000
# Epoch 234/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0298 - categorical_accuracy: 0.9875 - val_loss: 4.4193 - val_categorical_accuracy: 0.2500
# Epoch 235/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0030 - categorical_accuracy: 1.0000 - val_loss: 2.4430 - val_categorical_accuracy: 0.4500
# Epoch 236/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 4.2786 - val_categorical_accuracy: 0.2500
# Epoch 237/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 3.2221 - val_categorical_accuracy: 0.3500
# Epoch 238/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0043 - categorical_accuracy: 1.0000 - val_loss: 3.3741 - val_categorical_accuracy: 0.3000
# Epoch 239/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 3.9092 - val_categorical_accuracy: 0.4000
# Epoch 240/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 3.1609 - val_categorical_accuracy: 0.4000
# Epoch 241/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0096 - categorical_accuracy: 1.0000 - val_loss: 3.8596 - val_categorical_accuracy: 0.3000
# Epoch 242/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0497 - categorical_accuracy: 0.9875 - val_loss: 2.3775 - val_categorical_accuracy: 0.4500
# Epoch 243/500
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0090 - categorical_accuracy: 1.0000 - val_loss: 3.4193 - val_categorical_accuracy: 0.3000
# Epoch 244/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 3.7196 - val_categorical_accuracy: 0.2500
# Epoch 245/500
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 4.0654 - val_categorical_accuracy: 0.2500
# Epoch 246/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0047 - categorical_accuracy: 1.0000 - val_loss: 3.4252 - val_categorical_accuracy: 0.3000
# Epoch 247/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 2.8076 - val_categorical_accuracy: 0.4000
# Epoch 248/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 4.6453 - val_categorical_accuracy: 0.2500
# Epoch 249/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0088 - categorical_accuracy: 1.0000 - val_loss: 3.4715 - val_categorical_accuracy: 0.2500
# Epoch 250/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 3.0552 - val_categorical_accuracy: 0.4000
# Epoch 251/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 4.7481 - val_categorical_accuracy: 0.2500
# Epoch 252/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 3.0911 - val_categorical_accuracy: 0.3500
# Epoch 253/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0249 - categorical_accuracy: 1.0000 - val_loss: 3.4056 - val_categorical_accuracy: 0.2500
# Epoch 254/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0454 - categorical_accuracy: 0.9875 - val_loss: 6.0816 - val_categorical_accuracy: 0.1500
# Epoch 255/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0801 - categorical_accuracy: 0.9875 - val_loss: 4.2652 - val_categorical_accuracy: 0.2500
# Epoch 256/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0646 - categorical_accuracy: 0.9750 - val_loss: 3.3959 - val_categorical_accuracy: 0.4000
# Epoch 257/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.1251 - categorical_accuracy: 0.9500 - val_loss: 5.0045 - val_categorical_accuracy: 0.2500
# Epoch 258/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.1597 - categorical_accuracy: 0.9625 - val_loss: 4.2435 - val_categorical_accuracy: 0.3000
# Epoch 259/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2731 - categorical_accuracy: 0.8875 - val_loss: 6.1431 - val_categorical_accuracy: 0.3000
# Epoch 260/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.3028 - categorical_accuracy: 0.9125 - val_loss: 5.9195 - val_categorical_accuracy: 0.2500
# Epoch 261/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.1590 - categorical_accuracy: 0.9625 - val_loss: 4.5654 - val_categorical_accuracy: 0.2500
# Epoch 262/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1587 - categorical_accuracy: 0.9250 - val_loss: 6.5833 - val_categorical_accuracy: 0.2000
# Epoch 263/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.1010 - categorical_accuracy: 0.9500 - val_loss: 3.5136 - val_categorical_accuracy: 0.3500
# Epoch 264/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0231 - categorical_accuracy: 1.0000 - val_loss: 6.2349 - val_categorical_accuracy: 0.2000
# Epoch 265/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1193 - categorical_accuracy: 0.9625 - val_loss: 4.8086 - val_categorical_accuracy: 0.3500
# Epoch 266/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0348 - categorical_accuracy: 1.0000 - val_loss: 4.7509 - val_categorical_accuracy: 0.2500
# Epoch 267/500
# 20/20 [==============================] - 5s 234ms/step - loss: 0.0970 - categorical_accuracy: 0.9750 - val_loss: 4.0026 - val_categorical_accuracy: 0.3000
# Epoch 268/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0560 - categorical_accuracy: 0.9875 - val_loss: 3.7821 - val_categorical_accuracy: 0.4000
# Epoch 269/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0393 - categorical_accuracy: 0.9875 - val_loss: 3.0195 - val_categorical_accuracy: 0.3500
# Epoch 270/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0205 - categorical_accuracy: 1.0000 - val_loss: 3.7576 - val_categorical_accuracy: 0.2500
# Epoch 271/500
# ...
# Epoch 420/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0140 - categorical_accuracy: 1.0000 - val_loss: 3.9445 - val_categorical_accuracy: 0.2000
# Epoch 421/500
# 20/20 [==============================] - 5s 240ms/step - loss: 7.6262e-04 - categorical_accuracy: 1.0000 - val_loss: 3.8929 - val_categorical_accuracy: 0.3500
# Epoch 422/500
# 20/20 [==============================] - 5s 243ms/step - loss: 6.8975e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2891 - val_categorical_accuracy: 0.2000
# Epoch 423/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 4.7805 - val_categorical_accuracy: 0.2000
# Epoch 424/500
# 20/20 [==============================] - 5s 242ms/step - loss: 4.9435e-04 - categorical_accuracy: 1.0000 - val_loss: 3.3440 - val_categorical_accuracy: 0.3500
# Epoch 425/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0376 - categorical_accuracy: 0.9875 - val_loss: 2.9487 - val_categorical_accuracy: 0.2500
# Epoch 426/500
# 20/20 [==============================] - 5s 260ms/step - loss: 0.0350 - categorical_accuracy: 0.9875 - val_loss: 4.7958 - val_categorical_accuracy: 0.2500
# Epoch 427/500
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 2.6099 - val_categorical_accuracy: 0.3500
# Epoch 428/500
# 20/20 [==============================] - 5s 248ms/step - loss: 5.9024e-04 - categorical_accuracy: 1.0000 - val_loss: 4.9952 - val_categorical_accuracy: 0.3500
# Epoch 429/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0043 - categorical_accuracy: 1.0000 - val_loss: 4.9412 - val_categorical_accuracy: 0.1500
# Epoch 430/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0895 - categorical_accuracy: 0.9750 - val_loss: 4.2880 - val_categorical_accuracy: 0.2500
# Epoch 431/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0048 - categorical_accuracy: 1.0000 - val_loss: 4.3331 - val_categorical_accuracy: 0.3500
# Epoch 432/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 4.5622 - val_categorical_accuracy: 0.2500
# Epoch 433/500
# 20/20 [==============================] - 5s 244ms/step - loss: 6.2551e-04 - categorical_accuracy: 1.0000 - val_loss: 3.1533 - val_categorical_accuracy: 0.2000
# Epoch 434/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0314 - categorical_accuracy: 0.9875 - val_loss: 4.5396 - val_categorical_accuracy: 0.2000
# Epoch 435/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 4.6841 - val_categorical_accuracy: 0.2000
# Epoch 436/500
# 20/20 [==============================] - 5s 249ms/step - loss: 9.5100e-04 - categorical_accuracy: 1.0000 - val_loss: 3.3373 - val_categorical_accuracy: 0.3000
# Epoch 437/500
# 20/20 [==============================] - 5s 261ms/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 4.1158 - val_categorical_accuracy: 0.2500
# Epoch 438/500
# 20/20 [==============================] - 5s 258ms/step - loss: 5.7404e-04 - categorical_accuracy: 1.0000 - val_loss: 3.4304 - val_categorical_accuracy: 0.3000
# Epoch 439/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 2.5753 - val_categorical_accuracy: 0.3000
# Epoch 440/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 2.8862 - val_categorical_accuracy: 0.3000
# Epoch 441/500
# 20/20 [==============================] - 5s 247ms/step - loss: 5.2519e-04 - categorical_accuracy: 1.0000 - val_loss: 4.8429 - val_categorical_accuracy: 0.2500
# Epoch 442/500
# 20/20 [==============================] - 5s 248ms/step - loss: 7.7315e-04 - categorical_accuracy: 1.0000 - val_loss: 4.1737 - val_categorical_accuracy: 0.1500
# Epoch 443/500
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0499 - categorical_accuracy: 0.9750 - val_loss: 4.6081 - val_categorical_accuracy: 0.3000
# Epoch 444/500
# 20/20 [==============================] - 5s 253ms/step - loss: 7.1372e-04 - categorical_accuracy: 1.0000 - val_loss: 4.5121 - val_categorical_accuracy: 0.1500
# Epoch 445/500
# 20/20 [==============================] - 5s 246ms/step - loss: 9.0289e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2477 - val_categorical_accuracy: 0.3500
# Epoch 446/500
# 20/20 [==============================] - 5s 242ms/step - loss: 5.1142e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7802 - val_categorical_accuracy: 0.2000
# Epoch 447/500
# 20/20 [==============================] - 5s 253ms/step - loss: 8.4290e-04 - categorical_accuracy: 1.0000 - val_loss: 3.4223 - val_categorical_accuracy: 0.2500
# Epoch 448/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 3.1612 - val_categorical_accuracy: 0.3500
# Epoch 449/500
# 20/20 [==============================] - 5s 254ms/step - loss: 7.1135e-04 - categorical_accuracy: 1.0000 - val_loss: 4.8657 - val_categorical_accuracy: 0.2500
# Epoch 450/500
# 20/20 [==============================] - 5s 252ms/step - loss: 5.6735e-04 - categorical_accuracy: 1.0000 - val_loss: 3.8314 - val_categorical_accuracy: 0.1500
# Epoch 451/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 3.6957 - val_categorical_accuracy: 0.3000
# Epoch 452/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0072 - categorical_accuracy: 1.0000 - val_loss: 3.6787 - val_categorical_accuracy: 0.3000
# Epoch 453/500
# 20/20 [==============================] - 5s 237ms/step - loss: 4.9733e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5537 - val_categorical_accuracy: 0.3000
# Epoch 454/500
# 20/20 [==============================] - 5s 248ms/step - loss: 8.0928e-04 - categorical_accuracy: 1.0000 - val_loss: 3.4354 - val_categorical_accuracy: 0.3000
# Epoch 455/500
# 20/20 [==============================] - 5s 243ms/step - loss: 5.9461e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5597 - val_categorical_accuracy: 0.2500
# Epoch 456/500
# 20/20 [==============================] - 5s 242ms/step - loss: 8.2727e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6074 - val_categorical_accuracy: 0.2500
# Epoch 457/500
# 20/20 [==============================] - 5s 245ms/step - loss: 4.2156e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2487 - val_categorical_accuracy: 0.3000
# Epoch 458/500
# 20/20 [==============================] - 5s 249ms/step - loss: 4.7184e-04 - categorical_accuracy: 1.0000 - val_loss: 3.9324 - val_categorical_accuracy: 0.3000
# Epoch 459/500
# 20/20 [==============================] - 5s 246ms/step - loss: 4.2096e-04 - categorical_accuracy: 1.0000 - val_loss: 3.9027 - val_categorical_accuracy: 0.3000
# Epoch 460/500
# 20/20 [==============================] - 5s 245ms/step - loss: 5.2566e-04 - categorical_accuracy: 1.0000 - val_loss: 3.7229 - val_categorical_accuracy: 0.2500
# Epoch 461/500
# 20/20 [==============================] - 5s 251ms/step - loss: 6.4973e-04 - categorical_accuracy: 1.0000 - val_loss: 3.3345 - val_categorical_accuracy: 0.2500
# Epoch 462/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 4.3810 - val_categorical_accuracy: 0.2500
# Epoch 463/500
# 20/20 [==============================] - 5s 251ms/step - loss: 6.0413e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6349 - val_categorical_accuracy: 0.2500
# Epoch 464/500
# 20/20 [==============================] - 5s 245ms/step - loss: 5.3671e-04 - categorical_accuracy: 1.0000 - val_loss: 4.1971 - val_categorical_accuracy: 0.2000
# Epoch 465/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0048 - categorical_accuracy: 1.0000 - val_loss: 3.8812 - val_categorical_accuracy: 0.1500
# Epoch 466/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 2.8859 - val_categorical_accuracy: 0.3000
# Epoch 467/500
# 20/20 [==============================] - 5s 245ms/step - loss: 7.0995e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6443 - val_categorical_accuracy: 0.2500
# Epoch 468/500
# 20/20 [==============================] - 5s 254ms/step - loss: 5.3761e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6736 - val_categorical_accuracy: 0.2500
# Epoch 469/500
# 20/20 [==============================] - 5s 244ms/step - loss: 4.5543e-04 - categorical_accuracy: 1.0000 - val_loss: 4.5064 - val_categorical_accuracy: 0.1500
# Epoch 470/500
# 20/20 [==============================] - 5s 241ms/step - loss: 6.1228e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2818 - val_categorical_accuracy: 0.2000
# Epoch 471/500
# 20/20 [==============================] - 5s 242ms/step - loss: 7.0503e-04 - categorical_accuracy: 1.0000 - val_loss: 4.4735 - val_categorical_accuracy: 0.1500
# Epoch 472/500
# 20/20 [==============================] - 5s 249ms/step - loss: 7.0032e-04 - categorical_accuracy: 1.0000 - val_loss: 4.3694 - val_categorical_accuracy: 0.2500
# Epoch 473/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 3.3796 - val_categorical_accuracy: 0.2500
# Epoch 474/500
# 20/20 [==============================] - 5s 242ms/step - loss: 4.0801e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2020 - val_categorical_accuracy: 0.2500
# Epoch 475/500
# 20/20 [==============================] - 5s 246ms/step - loss: 7.7019e-04 - categorical_accuracy: 1.0000 - val_loss: 3.7366 - val_categorical_accuracy: 0.2000
# Epoch 476/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 3.6705 - val_categorical_accuracy: 0.3000
# Epoch 477/500
# 20/20 [==============================] - 5s 245ms/step - loss: 4.9901e-04 - categorical_accuracy: 1.0000 - val_loss: 4.0344 - val_categorical_accuracy: 0.2500
# Epoch 478/500
# 20/20 [==============================] - 5s 245ms/step - loss: 5.6141e-04 - categorical_accuracy: 1.0000 - val_loss: 2.6551 - val_categorical_accuracy: 0.3000
# Epoch 479/500
# 20/20 [==============================] - 5s 244ms/step - loss: 6.4935e-04 - categorical_accuracy: 1.0000 - val_loss: 3.7366 - val_categorical_accuracy: 0.2500
# Epoch 480/500
# 20/20 [==============================] - 5s 248ms/step - loss: 4.6898e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5442 - val_categorical_accuracy: 0.3000
# Epoch 481/500
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0164 - categorical_accuracy: 0.9875 - val_loss: 5.5107 - val_categorical_accuracy: 0.3000
# Epoch 482/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 3.0188 - val_categorical_accuracy: 0.3500
# Epoch 483/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 3.4755 - val_categorical_accuracy: 0.2500
# Epoch 484/500
# 20/20 [==============================] - 5s 243ms/step - loss: 7.0499e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2088 - val_categorical_accuracy: 0.1500
# Epoch 485/500
# 20/20 [==============================] - 5s 244ms/step - loss: 3.8029e-04 - categorical_accuracy: 1.0000 - val_loss: 3.9343 - val_categorical_accuracy: 0.2500
# Epoch 486/500
# 20/20 [==============================] - 5s 254ms/step - loss: 4.7399e-04 - categorical_accuracy: 1.0000 - val_loss: 4.1537 - val_categorical_accuracy: 0.3000
# Epoch 487/500
# 20/20 [==============================] - 5s 244ms/step - loss: 6.4959e-04 - categorical_accuracy: 1.0000 - val_loss: 2.8695 - val_categorical_accuracy: 0.3500
# Epoch 488/500
# 20/20 [==============================] - 5s 248ms/step - loss: 4.7525e-04 - categorical_accuracy: 1.0000 - val_loss: 3.8066 - val_categorical_accuracy: 0.2000
# Epoch 489/500
# 20/20 [==============================] - 5s 247ms/step - loss: 4.0651e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6705 - val_categorical_accuracy: 0.3000
# Epoch 490/500
# 20/20 [==============================] - 5s 244ms/step - loss: 5.6206e-04 - categorical_accuracy: 1.0000 - val_loss: 4.2952 - val_categorical_accuracy: 0.1500
# Epoch 491/500
# 20/20 [==============================] - 5s 241ms/step - loss: 3.5835e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5159 - val_categorical_accuracy: 0.3000
# Epoch 492/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 2.7547 - val_categorical_accuracy: 0.3000
# Epoch 493/500
# 20/20 [==============================] - 5s 246ms/step - loss: 5.6670e-04 - categorical_accuracy: 1.0000 - val_loss: 3.2394 - val_categorical_accuracy: 0.2000
# Epoch 494/500
# 20/20 [==============================] - 5s 250ms/step - loss: 4.3286e-04 - categorical_accuracy: 1.0000 - val_loss: 3.3190 - val_categorical_accuracy: 0.4000
# Epoch 495/500
# 20/20 [==============================] - 5s 244ms/step - loss: 3.8821e-04 - categorical_accuracy: 1.0000 - val_loss: 3.4967 - val_categorical_accuracy: 0.3000
# Epoch 496/500
# 20/20 [==============================] - 5s 242ms/step - loss: 3.9051e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5514 - val_categorical_accuracy: 0.3500
# Epoch 497/500
# 20/20 [==============================] - 5s 244ms/step - loss: 5.2669e-04 - categorical_accuracy: 1.0000 - val_loss: 3.5751 - val_categorical_accuracy: 0.2500
# Epoch 498/500
# 20/20 [==============================] - 5s 243ms/step - loss: 5.9550e-04 - categorical_accuracy: 1.0000 - val_loss: 3.6273 - val_categorical_accuracy: 0.2500
# Epoch 499/500
# 20/20 [==============================] - 5s 249ms/step - loss: 3.9124e-04 - categorical_accuracy: 1.0000 - val_loss: 2.9660 - val_categorical_accuracy: 0.3500
# Epoch 500/500
# 20/20 [==============================] - 5s 250ms/step - loss: 3.8275e-04 - categorical_accuracy: 1.0000 - val_loss: 3.7115 - val_categorical_accuracy: 0.2500
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>▁▅▅▆▇██▇████████████████████████████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>████▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁███▇▇▇▆▆▅▅▄▄▃▃▂▂▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>▄▁▆▄▄▄▃▅█▆▆▆▆▇▅█▇▆▄▅██▄▄▅▄▆▇▅▅▆▅▇▄▆▇▅▅▃▇</td></tr><tr><td>epoch/val_loss</td><td>▁▄▅▄█▄▇▆▂█▄▄▃▄▅▆▆▃▄▅▄▅█▇▄▄▇▄▅▆▆▆▄▅▄▃▅▆▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>1.0</td></tr><tr><td>epoch/epoch</td><td>499</td></tr><tr><td>epoch/learning_rate</td><td>1e-05</td></tr><tr><td>epoch/loss</td><td>0.00038</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>0.25</td></tr><tr><td>epoch/val_loss</td><td>3.7115</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">C1_Resnet50_augmentation</strong> at: <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/ccvd2jdl' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/ccvd2jdl</a><br/> View project at: <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_131505-ccvd2jdl/logs</code>

# %% [markdown]
# ### EfficientNetB0

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.EfficientNetB0(input_shape = MHI_SHAPE,
                                                include_top = False,
                                                weights = None,
                                                pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, run_name="C1_EfficientNetB0_augmentation_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 1e-4, 
            min_lr = 2.5e-5,
            T_max=501, 
            epochs=1000,
            filepath=os.path.join("models", "EfficientNetB0_2_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_153352-rac6yohp</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/rac6yohp' target="_blank">C1_EfficientNetB0_augmentation</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/rac6yohp' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/rac6yohp</a>
# Epoch 1/1000
# 2024-04-15 15:34:08.578734: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_11/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
#      20/Unknown - 31s 185ms/step - loss: 2.2131 - categorical_accuracy: 0.1250INFO:tensorflow:Assets written to: models/EfficientNetB0_2.tf/assets
# INFO:tensorflow:Assets written to: models/EfficientNetB0_2.tf/assets
# 20/20 [==============================] - 56s 2s/step - loss: 2.2131 - categorical_accuracy: 0.1250 - val_loss: 1.9368 - val_categorical_accuracy: 0.2000
# Epoch 2/1000
# 20/20 [==============================] - 5s 252ms/step - loss: 2.1524 - categorical_accuracy: 0.1750 - val_loss: 1.9347 - val_categorical_accuracy: 0.2000
# Epoch 3/1000
# 20/20 [==============================] - 5s 244ms/step - loss: 2.0655 - categorical_accuracy: 0.1125 - val_loss: 1.9138 - val_categorical_accuracy: 0.2000
# Epoch 4/1000
# 20/20 [==============================] - 5s 246ms/step - loss: 2.1920 - categorical_accuracy: 0.0875 - val_loss: 1.9003 - val_categorical_accuracy: 0.2000
# Epoch 5/1000
# 20/20 [==============================] - 5s 247ms/step - loss: 2.0835 - categorical_accuracy: 0.1375 - val_loss: 1.8892 - val_categorical_accuracy: 0.1500
# Epoch 6/1000
# 20/20 [==============================] - 5s 244ms/step - loss: 2.0303 - categorical_accuracy: 0.2125 - val_loss: 1.8723 - val_categorical_accuracy: 0.2000
# Epoch 7/1000
# 20/20 [==============================] - 5s 245ms/step - loss: 2.0152 - categorical_accuracy: 0.1500 - val_loss: 1.8745 - val_categorical_accuracy: 0.2000
# Epoch 8/1000
# 20/20 [==============================] - 5s 246ms/step - loss: 2.0712 - categorical_accuracy: 0.1625 - val_loss: 1.8824 - val_categorical_accuracy: 0.2000
# Epoch 9/1000
# 20/20 [==============================] - 5s 240ms/step - loss: 2.0219 - categorical_accuracy: 0.1375 - val_loss: 1.9249 - val_categorical_accuracy: 0.2000
# Epoch 10/1000
# 20/20 [==============================] - 5s 250ms/step - loss: 1.9534 - categorical_accuracy: 0.1625 - val_loss: 1.9079 - val_categorical_accuracy: 0.1500
# Epoch 11/1000
# 20/20 [==============================] - 5s 241ms/step - loss: 1.9776 - categorical_accuracy: 0.1625 - val_loss: 1.9330 - val_categorical_accuracy: 0.1500
# Epoch 12/1000
# 14/20 [====================>.........] - ETA: 1s - loss: 1.9670 - categorical_accuracy: 0.1964

# %% [markdown]
# ### ConvNeXt

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.ConvNeXtSmall(input_shape = MHI_SHAPE,
                                                include_top = False,
                                                weights = 'imagenet',
                                                pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))


keras_train(model, run_name="C1_ConvNeXt_augmentation_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="transforms_for_video_no_transforms", 
            max_lr = 1e-4, 
            min_lr = 5e-5,
            T_max=251, 
            epochs=500,
            filepath=os.path.join("models", "ConvNeXt_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_small_notop.h5
# 198551472/198551472 [==============================] - 6s 0us/step
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_180417-kxadc7up</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/kxadc7up' target="_blank">C1_ConvNeXt_augmentation</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/kxadc7up' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/kxadc7up</a>
# Epoch 1/500
#      20/Unknown - 60s 188ms/step - loss: 2.2045 - categorical_accuracy: 0.0875INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 95s 2s/step - loss: 2.2045 - categorical_accuracy: 0.0875 - val_loss: 1.9332 - val_categorical_accuracy: 0.1000
# Epoch 2/500
# 20/20 [==============================] - 5s 258ms/step - loss: 2.0744 - categorical_accuracy: 0.1125 - val_loss: 1.9793 - val_categorical_accuracy: 0.0500
# Epoch 3/500
# 20/20 [==============================] - 5s 257ms/step - loss: 2.0491 - categorical_accuracy: 0.0875 - val_loss: 2.0128 - val_categorical_accuracy: 0.0500
# Epoch 4/500
# 20/20 [==============================] - 5s 260ms/step - loss: 2.0446 - categorical_accuracy: 0.0875 - val_loss: 1.9730 - val_categorical_accuracy: 0.0500
# Epoch 5/500
# 20/20 [==============================] - 5s 253ms/step - loss: 2.0080 - categorical_accuracy: 0.0625 - val_loss: 1.9427 - val_categorical_accuracy: 0.0500
# Epoch 6/500
# 20/20 [==============================] - 5s 258ms/step - loss: 1.9871 - categorical_accuracy: 0.1000 - val_loss: 1.9480 - val_categorical_accuracy: 0.0500
# Epoch 7/500
# 20/20 [==============================] - 5s 248ms/step - loss: 1.9852 - categorical_accuracy: 0.0750 - val_loss: 1.9382 - val_categorical_accuracy: 0.0500
# Epoch 8/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.9814 - categorical_accuracy: 0.0750 - val_loss: 1.9404 - val_categorical_accuracy: 0.0500
# Epoch 9/500
# 20/20 [==============================] - 5s 257ms/step - loss: 1.9793 - categorical_accuracy: 0.0750 - val_loss: 1.9390 - val_categorical_accuracy: 0.0500
# Epoch 10/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.9795 - categorical_accuracy: 0.0625 - val_loss: 1.9388 - val_categorical_accuracy: 0.0500
# Epoch 11/500
# 20/20 [==============================] - 5s 253ms/step - loss: 1.9765 - categorical_accuracy: 0.0750 - val_loss: 1.9371 - val_categorical_accuracy: 0.0500
# Epoch 12/500
# 20/20 [==============================] - 5s 247ms/step - loss: 1.9758 - categorical_accuracy: 0.0750 - val_loss: 1.9364 - val_categorical_accuracy: 0.0500
# Epoch 13/500
# 20/20 [==============================] - 5s 245ms/step - loss: 1.9744 - categorical_accuracy: 0.0750 - val_loss: 1.9365 - val_categorical_accuracy: 0.0500
# Epoch 14/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9731 - categorical_accuracy: 0.0750 - val_loss: 1.9372 - val_categorical_accuracy: 0.0500
# Epoch 15/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.9728 - categorical_accuracy: 0.0750 - val_loss: 1.9361 - val_categorical_accuracy: 0.0500
# Epoch 16/500
# 20/20 [==============================] - 5s 246ms/step - loss: 1.9723 - categorical_accuracy: 0.0625 - val_loss: 1.9374 - val_categorical_accuracy: 0.0500
# Epoch 17/500
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9699 - categorical_accuracy: 0.0750 - val_loss: 1.9378 - val_categorical_accuracy: 0.0500
# Epoch 18/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9813 - categorical_accuracy: 0.0625 - val_loss: 1.9311 - val_categorical_accuracy: 0.0500
# Epoch 19/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.9845 - categorical_accuracy: 0.1000 - val_loss: 1.9458 - val_categorical_accuracy: 0.0500
# Epoch 20/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.9787 - categorical_accuracy: 0.0750 - val_loss: 1.9323 - val_categorical_accuracy: 0.0500
# Epoch 21/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.9690 - categorical_accuracy: 0.0750 - val_loss: 1.9373 - val_categorical_accuracy: 0.0500
# Epoch 22/500
# 20/20 [==============================] - 5s 246ms/step - loss: 1.9687 - categorical_accuracy: 0.0750 - val_loss: 1.9346 - val_categorical_accuracy: 0.0500
# Epoch 23/500
# 20/20 [==============================] - 5s 255ms/step - loss: 1.9677 - categorical_accuracy: 0.0750 - val_loss: 1.9337 - val_categorical_accuracy: 0.0500
# Epoch 24/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.9668 - categorical_accuracy: 0.0750 - val_loss: 1.9336 - val_categorical_accuracy: 0.0500
# Epoch 25/500
# 20/20 [==============================] - 5s 245ms/step - loss: 1.9667 - categorical_accuracy: 0.0750 - val_loss: 1.9334 - val_categorical_accuracy: 0.0500
# Epoch 26/500
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9656 - categorical_accuracy: 0.0750 - val_loss: 1.9335 - val_categorical_accuracy: 0.0500
# Epoch 27/500
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9651 - categorical_accuracy: 0.0750 - val_loss: 1.9330 - val_categorical_accuracy: 0.0500
# Epoch 28/500
# 20/20 [==============================] - 5s 246ms/step - loss: 1.9646 - categorical_accuracy: 0.0750 - val_loss: 1.9333 - val_categorical_accuracy: 0.0500
# Epoch 29/500
# 20/20 [==============================] - 5s 240ms/step - loss: 1.9642 - categorical_accuracy: 0.0750 - val_loss: 1.9316 - val_categorical_accuracy: 0.0500
# Epoch 30/500
# 20/20 [==============================] - 5s 243ms/step - loss: 1.9644 - categorical_accuracy: 0.0750 - val_loss: 1.9320 - val_categorical_accuracy: 0.0500
# Epoch 31/500
# 20/20 [==============================] - 5s 259ms/step - loss: 1.9639 - categorical_accuracy: 0.0750 - val_loss: 1.9317 - val_categorical_accuracy: 0.0500
# Epoch 32/500
# 20/20 [==============================] - 5s 243ms/step - loss: 1.9637 - categorical_accuracy: 0.0750 - val_loss: 1.9316 - val_categorical_accuracy: 0.0500
# Epoch 33/500
# 20/20 [==============================] - 5s 242ms/step - loss: 1.9631 - categorical_accuracy: 0.0750 - val_loss: 1.9319 - val_categorical_accuracy: 0.0500
# Epoch 34/500
# 20/20 [==============================] - 5s 257ms/step - loss: 1.9627 - categorical_accuracy: 0.0750 - val_loss: 1.9313 - val_categorical_accuracy: 0.0500
# Epoch 35/500
# 20/20 [==============================] - 5s 257ms/step - loss: 1.9625 - categorical_accuracy: 0.0750 - val_loss: 1.9311 - val_categorical_accuracy: 0.0500
# Epoch 36/500
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9614 - categorical_accuracy: 0.0750 - val_loss: 1.9306 - val_categorical_accuracy: 0.0500
# Epoch 37/500
# 20/20 [==============================] - 5s 259ms/step - loss: 1.9618 - categorical_accuracy: 0.0750 - val_loss: 1.9306 - val_categorical_accuracy: 0.0500
# Epoch 38/500
# 20/20 [==============================] - 5s 247ms/step - loss: 1.9608 - categorical_accuracy: 0.0875 - val_loss: 1.9314 - val_categorical_accuracy: 0.0500
# Epoch 39/500
# 20/20 [==============================] - 5s 251ms/step - loss: 1.9598 - categorical_accuracy: 0.0750 - val_loss: 1.9352 - val_categorical_accuracy: 0.0500
# Epoch 40/500
# 20/20 [==============================] - ETA: 0s - loss: 1.9513 - categorical_accuracy: 0.0750INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 28s 1s/step - loss: 1.9513 - categorical_accuracy: 0.0750 - val_loss: 1.8253 - val_categorical_accuracy: 0.2000
# Epoch 41/500
# 20/20 [==============================] - 5s 263ms/step - loss: 1.9713 - categorical_accuracy: 0.1125 - val_loss: 1.9541 - val_categorical_accuracy: 0.0500
# Epoch 42/500
# 20/20 [==============================] - 5s 253ms/step - loss: 1.9761 - categorical_accuracy: 0.1000 - val_loss: 1.9270 - val_categorical_accuracy: 0.0500
# Epoch 43/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9618 - categorical_accuracy: 0.0875 - val_loss: 1.9315 - val_categorical_accuracy: 0.0500
# Epoch 44/500
# 20/20 [==============================] - 5s 257ms/step - loss: 1.9512 - categorical_accuracy: 0.0625 - val_loss: 1.9317 - val_categorical_accuracy: 0.0500
# Epoch 45/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9438 - categorical_accuracy: 0.1125 - val_loss: 1.9646 - val_categorical_accuracy: 0.0500
# Epoch 46/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9717 - categorical_accuracy: 0.1625 - val_loss: 1.8922 - val_categorical_accuracy: 0.0500
# Epoch 47/500
# 20/20 [==============================] - ETA: 0s - loss: 1.9530 - categorical_accuracy: 0.1125INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 31s 2s/step - loss: 1.9530 - categorical_accuracy: 0.1125 - val_loss: 1.9018 - val_categorical_accuracy: 0.2500
# Epoch 48/500
# 20/20 [==============================] - 5s 256ms/step - loss: 1.9232 - categorical_accuracy: 0.1375 - val_loss: 1.9040 - val_categorical_accuracy: 0.1500
# Epoch 49/500
# 20/20 [==============================] - 5s 255ms/step - loss: 1.9247 - categorical_accuracy: 0.1625 - val_loss: 1.8875 - val_categorical_accuracy: 0.0500
# Epoch 50/500
# 20/20 [==============================] - 5s 249ms/step - loss: 1.9334 - categorical_accuracy: 0.1375 - val_loss: 1.8708 - val_categorical_accuracy: 0.1500
# Epoch 51/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.8623 - categorical_accuracy: 0.1750 - val_loss: 1.9486 - val_categorical_accuracy: 0.1000
# Epoch 52/500
# 20/20 [==============================] - 5s 259ms/step - loss: 1.9831 - categorical_accuracy: 0.0875 - val_loss: 1.9261 - val_categorical_accuracy: 0.0500
# Epoch 53/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.8968 - categorical_accuracy: 0.1250 - val_loss: 2.0088 - val_categorical_accuracy: 0.1000
# Epoch 54/500
# 20/20 [==============================] - 5s 250ms/step - loss: 1.8547 - categorical_accuracy: 0.3000 - val_loss: 1.8275 - val_categorical_accuracy: 0.2000
# Epoch 55/500
# 20/20 [==============================] - 5s 254ms/step - loss: 1.7545 - categorical_accuracy: 0.2500 - val_loss: 1.9827 - val_categorical_accuracy: 0.1500
# Epoch 56/500
# 20/20 [==============================] - 5s 248ms/step - loss: 1.6195 - categorical_accuracy: 0.3750 - val_loss: 1.9756 - val_categorical_accuracy: 0.0500
# Epoch 57/500
# 20/20 [==============================] - 5s 248ms/step - loss: 1.6025 - categorical_accuracy: 0.3750 - val_loss: 2.0051 - val_categorical_accuracy: 0.2000
# Epoch 58/500
# 20/20 [==============================] - 5s 264ms/step - loss: 1.4946 - categorical_accuracy: 0.5000 - val_loss: 2.0484 - val_categorical_accuracy: 0.1500
# Epoch 59/500
# 20/20 [==============================] - 5s 244ms/step - loss: 1.4542 - categorical_accuracy: 0.4375 - val_loss: 1.9099 - val_categorical_accuracy: 0.1500
# Epoch 60/500
# 20/20 [==============================] - ETA: 0s - loss: 1.5156 - categorical_accuracy: 0.3500INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 31s 2s/step - loss: 1.5156 - categorical_accuracy: 0.3500 - val_loss: 1.6401 - val_categorical_accuracy: 0.3500
# Epoch 61/500
# 20/20 [==============================] - 5s 254ms/step - loss: 1.2305 - categorical_accuracy: 0.5000 - val_loss: 1.9121 - val_categorical_accuracy: 0.3000
# Epoch 62/500
# 20/20 [==============================] - ETA: 0s - loss: 1.1229 - categorical_accuracy: 0.5875INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 31s 2s/step - loss: 1.1229 - categorical_accuracy: 0.5875 - val_loss: 1.8326 - val_categorical_accuracy: 0.4000
# Epoch 63/500
# 20/20 [==============================] - 5s 258ms/step - loss: 1.0103 - categorical_accuracy: 0.6500 - val_loss: 2.4030 - val_categorical_accuracy: 0.2500
# Epoch 64/500
# 20/20 [==============================] - 5s 252ms/step - loss: 1.0328 - categorical_accuracy: 0.6500 - val_loss: 1.9952 - val_categorical_accuracy: 0.2000
# Epoch 65/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.9660 - categorical_accuracy: 0.6250 - val_loss: 1.9318 - val_categorical_accuracy: 0.3500
# Epoch 66/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.9682 - categorical_accuracy: 0.6500 - val_loss: 2.4218 - val_categorical_accuracy: 0.2500
# Epoch 67/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.6661 - categorical_accuracy: 0.7625 - val_loss: 2.4044 - val_categorical_accuracy: 0.3000
# Epoch 68/500
# 20/20 [==============================] - 5s 241ms/step - loss: 0.7486 - categorical_accuracy: 0.7750 - val_loss: 2.2986 - val_categorical_accuracy: 0.3000
# Epoch 69/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.7024 - categorical_accuracy: 0.7125 - val_loss: 2.2024 - val_categorical_accuracy: 0.2500
# Epoch 70/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.6389 - categorical_accuracy: 0.7500 - val_loss: 2.3633 - val_categorical_accuracy: 0.2500
# Epoch 71/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.6859 - categorical_accuracy: 0.7625 - val_loss: 2.2615 - val_categorical_accuracy: 0.3500
# Epoch 72/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.5692 - categorical_accuracy: 0.8125 - val_loss: 2.4049 - val_categorical_accuracy: 0.3000
# Epoch 73/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.7446 - categorical_accuracy: 0.7625 - val_loss: 2.3029 - val_categorical_accuracy: 0.2500
# Epoch 74/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.5335 - categorical_accuracy: 0.7500 - val_loss: 2.0408 - val_categorical_accuracy: 0.3000
# Epoch 75/500
# 20/20 [==============================] - 5s 261ms/step - loss: 0.5794 - categorical_accuracy: 0.7625 - val_loss: 2.3496 - val_categorical_accuracy: 0.3500
# Epoch 76/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.6274 - categorical_accuracy: 0.7875 - val_loss: 2.3485 - val_categorical_accuracy: 0.3500
# Epoch 77/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.6346 - categorical_accuracy: 0.7625 - val_loss: 2.5730 - val_categorical_accuracy: 0.3000
# Epoch 78/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.4451 - categorical_accuracy: 0.8875 - val_loss: 2.5532 - val_categorical_accuracy: 0.2000
# Epoch 79/500
# 20/20 [==============================] - 5s 259ms/step - loss: 0.5500 - categorical_accuracy: 0.8375 - val_loss: 2.2845 - val_categorical_accuracy: 0.4000
# Epoch 80/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.5557 - categorical_accuracy: 0.8125 - val_loss: 2.6310 - val_categorical_accuracy: 0.4000
# Epoch 81/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.4707 - categorical_accuracy: 0.8375 - val_loss: 2.1878 - val_categorical_accuracy: 0.4000
# Epoch 82/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.5501 - categorical_accuracy: 0.8000 - val_loss: 2.4669 - val_categorical_accuracy: 0.3500
# Epoch 83/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.3897 - categorical_accuracy: 0.8875 - val_loss: 2.5059 - val_categorical_accuracy: 0.3500
# Epoch 84/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.4215 - categorical_accuracy: 0.8500 - val_loss: 2.5763 - val_categorical_accuracy: 0.3000
# Epoch 85/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.3963 - categorical_accuracy: 0.8625 - val_loss: 2.1818 - val_categorical_accuracy: 0.3000
# Epoch 86/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.2410 - categorical_accuracy: 0.9125 - val_loss: 2.7213 - val_categorical_accuracy: 0.2500
# Epoch 87/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.4173 - categorical_accuracy: 0.8375 - val_loss: 2.6723 - val_categorical_accuracy: 0.1000
# Epoch 88/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.3153 - categorical_accuracy: 0.8750 - val_loss: 3.1512 - val_categorical_accuracy: 0.3000
# Epoch 89/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.3689 - categorical_accuracy: 0.8500 - val_loss: 3.4472 - val_categorical_accuracy: 0.2500
# Epoch 90/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.3186 - categorical_accuracy: 0.8875 - val_loss: 3.1971 - val_categorical_accuracy: 0.2500
# Epoch 91/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.2291 - categorical_accuracy: 0.9125 - val_loss: 3.1866 - val_categorical_accuracy: 0.3000
# Epoch 92/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.4890 - categorical_accuracy: 0.8125 - val_loss: 2.1313 - val_categorical_accuracy: 0.4000
# Epoch 93/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.4900 - categorical_accuracy: 0.8000 - val_loss: 3.0277 - val_categorical_accuracy: 0.2000
# Epoch 94/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2494 - categorical_accuracy: 0.9000 - val_loss: 2.6617 - val_categorical_accuracy: 0.3000
# Epoch 95/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.3942 - categorical_accuracy: 0.8375 - val_loss: 3.2369 - val_categorical_accuracy: 0.2500
# Epoch 96/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2165 - categorical_accuracy: 0.9125 - val_loss: 3.1496 - val_categorical_accuracy: 0.2000
# Epoch 97/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.3056 - categorical_accuracy: 0.8625 - val_loss: 2.3596 - val_categorical_accuracy: 0.2500
# Epoch 98/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.2497 - categorical_accuracy: 0.9250 - val_loss: 3.4179 - val_categorical_accuracy: 0.1000
# Epoch 99/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.4354 - categorical_accuracy: 0.8375 - val_loss: 3.4443 - val_categorical_accuracy: 0.2500
# Epoch 100/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.2587 - categorical_accuracy: 0.9000 - val_loss: 3.2927 - val_categorical_accuracy: 0.2500
# Epoch 101/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1819 - categorical_accuracy: 0.9250 - val_loss: 3.1485 - val_categorical_accuracy: 0.1500
# Epoch 102/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.3357 - categorical_accuracy: 0.9000 - val_loss: 2.7323 - val_categorical_accuracy: 0.4000
# Epoch 103/500
# 20/20 [==============================] - ETA: 0s - loss: 0.3006 - categorical_accuracy: 0.9000INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 31s 2s/step - loss: 0.3006 - categorical_accuracy: 0.9000 - val_loss: 2.6426 - val_categorical_accuracy: 0.5000
# Epoch 104/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2711 - categorical_accuracy: 0.9375 - val_loss: 3.2121 - val_categorical_accuracy: 0.3500
# Epoch 105/500
# 20/20 [==============================] - 5s 263ms/step - loss: 0.2011 - categorical_accuracy: 0.9000 - val_loss: 2.9357 - val_categorical_accuracy: 0.3000
# Epoch 106/500
# 20/20 [==============================] - 5s 261ms/step - loss: 0.3200 - categorical_accuracy: 0.8750 - val_loss: 3.8748 - val_categorical_accuracy: 0.2500
# Epoch 107/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.2415 - categorical_accuracy: 0.9125 - val_loss: 3.4339 - val_categorical_accuracy: 0.3000
# Epoch 108/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.3197 - categorical_accuracy: 0.8875 - val_loss: 3.2738 - val_categorical_accuracy: 0.3500
# Epoch 109/500
# 20/20 [==============================] - 5s 259ms/step - loss: 0.2635 - categorical_accuracy: 0.8625 - val_loss: 3.2221 - val_categorical_accuracy: 0.2500
# Epoch 110/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.2156 - categorical_accuracy: 0.9125 - val_loss: 3.2593 - val_categorical_accuracy: 0.2000
# Epoch 111/500
# 20/20 [==============================] - 5s 261ms/step - loss: 0.2055 - categorical_accuracy: 0.9250 - val_loss: 3.7452 - val_categorical_accuracy: 0.3500
# Epoch 112/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.3553 - categorical_accuracy: 0.9250 - val_loss: 3.1014 - val_categorical_accuracy: 0.3500
# Epoch 113/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.3748 - categorical_accuracy: 0.8625 - val_loss: 3.2666 - val_categorical_accuracy: 0.3500
# Epoch 114/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1930 - categorical_accuracy: 0.9375 - val_loss: 3.1764 - val_categorical_accuracy: 0.2500
# Epoch 115/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.3065 - categorical_accuracy: 0.8875 - val_loss: 2.8106 - val_categorical_accuracy: 0.2500
# Epoch 116/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.2113 - categorical_accuracy: 0.9000 - val_loss: 3.3007 - val_categorical_accuracy: 0.1500
# Epoch 117/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2246 - categorical_accuracy: 0.9250 - val_loss: 2.7713 - val_categorical_accuracy: 0.3500
# Epoch 118/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.2613 - categorical_accuracy: 0.8875 - val_loss: 3.0999 - val_categorical_accuracy: 0.3000
# Epoch 119/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2309 - categorical_accuracy: 0.9000 - val_loss: 2.8934 - val_categorical_accuracy: 0.3000
# Epoch 120/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.3154 - categorical_accuracy: 0.8625 - val_loss: 2.5707 - val_categorical_accuracy: 0.3500
# Epoch 121/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.2550 - categorical_accuracy: 0.9125 - val_loss: 3.3306 - val_categorical_accuracy: 0.2500
# Epoch 122/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.2416 - categorical_accuracy: 0.8875 - val_loss: 2.1536 - val_categorical_accuracy: 0.2000
# Epoch 123/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2660 - categorical_accuracy: 0.9125 - val_loss: 3.5730 - val_categorical_accuracy: 0.3500
# Epoch 124/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1911 - categorical_accuracy: 0.9250 - val_loss: 3.4461 - val_categorical_accuracy: 0.1500
# Epoch 125/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.2526 - categorical_accuracy: 0.9000 - val_loss: 3.9809 - val_categorical_accuracy: 0.2000
# Epoch 126/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2271 - categorical_accuracy: 0.9250 - val_loss: 3.4033 - val_categorical_accuracy: 0.3500
# Epoch 127/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.2579 - categorical_accuracy: 0.8625 - val_loss: 3.1341 - val_categorical_accuracy: 0.3000
# Epoch 128/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.2469 - categorical_accuracy: 0.9125 - val_loss: 3.9041 - val_categorical_accuracy: 0.2500
# Epoch 129/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.2483 - categorical_accuracy: 0.9125 - val_loss: 3.6230 - val_categorical_accuracy: 0.3500
# Epoch 130/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1747 - categorical_accuracy: 0.9250 - val_loss: 2.9838 - val_categorical_accuracy: 0.4500
# Epoch 131/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1851 - categorical_accuracy: 0.9500 - val_loss: 2.7257 - val_categorical_accuracy: 0.4000
# Epoch 132/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1742 - categorical_accuracy: 0.9250 - val_loss: 2.8998 - val_categorical_accuracy: 0.4000
# Epoch 133/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1521 - categorical_accuracy: 0.9375 - val_loss: 2.8416 - val_categorical_accuracy: 0.3500
# Epoch 134/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1973 - categorical_accuracy: 0.9125 - val_loss: 2.9586 - val_categorical_accuracy: 0.3000
# Epoch 135/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1732 - categorical_accuracy: 0.9375 - val_loss: 4.0950 - val_categorical_accuracy: 0.2000
# Epoch 136/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.2487 - categorical_accuracy: 0.8750 - val_loss: 3.0085 - val_categorical_accuracy: 0.2000
# Epoch 137/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1009 - categorical_accuracy: 0.9375 - val_loss: 4.3633 - val_categorical_accuracy: 0.2500
# Epoch 138/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2033 - categorical_accuracy: 0.9375 - val_loss: 3.0371 - val_categorical_accuracy: 0.3500
# Epoch 139/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.3386 - categorical_accuracy: 0.8875 - val_loss: 3.9097 - val_categorical_accuracy: 0.3000
# Epoch 140/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.2208 - categorical_accuracy: 0.8875 - val_loss: 2.9996 - val_categorical_accuracy: 0.3500
# Epoch 141/500
# 20/20 [==============================] - 5s 261ms/step - loss: 0.2427 - categorical_accuracy: 0.8875 - val_loss: 3.8366 - val_categorical_accuracy: 0.1500
# Epoch 142/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.2472 - categorical_accuracy: 0.9000 - val_loss: 3.2895 - val_categorical_accuracy: 0.1500
# Epoch 143/500
# 20/20 [==============================] - 5s 268ms/step - loss: 0.2452 - categorical_accuracy: 0.9375 - val_loss: 3.0468 - val_categorical_accuracy: 0.2000
# Epoch 144/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.2074 - categorical_accuracy: 0.9125 - val_loss: 3.2631 - val_categorical_accuracy: 0.2500
# Epoch 145/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1312 - categorical_accuracy: 0.9500 - val_loss: 4.3429 - val_categorical_accuracy: 0.2500
# Epoch 146/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1726 - categorical_accuracy: 0.9375 - val_loss: 3.6327 - val_categorical_accuracy: 0.2000
# Epoch 147/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1049 - categorical_accuracy: 0.9500 - val_loss: 3.9583 - val_categorical_accuracy: 0.2500
# Epoch 148/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1980 - categorical_accuracy: 0.9250 - val_loss: 3.9710 - val_categorical_accuracy: 0.3000
# Epoch 149/500
# 20/20 [==============================] - 5s 259ms/step - loss: 0.1414 - categorical_accuracy: 0.9500 - val_loss: 3.5081 - val_categorical_accuracy: 0.2000
# Epoch 150/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1857 - categorical_accuracy: 0.9250 - val_loss: 3.2232 - val_categorical_accuracy: 0.3500
# Epoch 151/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1699 - categorical_accuracy: 0.9250 - val_loss: 4.1017 - val_categorical_accuracy: 0.1500
# Epoch 152/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.2194 - categorical_accuracy: 0.9000 - val_loss: 4.0853 - val_categorical_accuracy: 0.3500
# Epoch 153/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0744 - categorical_accuracy: 0.9750 - val_loss: 4.2674 - val_categorical_accuracy: 0.1500
# Epoch 154/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.2265 - categorical_accuracy: 0.9375 - val_loss: 4.0426 - val_categorical_accuracy: 0.2000
# Epoch 155/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.2058 - categorical_accuracy: 0.9125 - val_loss: 3.9005 - val_categorical_accuracy: 0.1000
# Epoch 156/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1112 - categorical_accuracy: 0.9625 - val_loss: 3.9405 - val_categorical_accuracy: 0.2500
# Epoch 157/500
# 20/20 [==============================] - 5s 239ms/step - loss: 0.1522 - categorical_accuracy: 0.9250 - val_loss: 3.6946 - val_categorical_accuracy: 0.3000
# Epoch 158/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.1680 - categorical_accuracy: 0.9250 - val_loss: 3.5651 - val_categorical_accuracy: 0.3500
# Epoch 159/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1690 - categorical_accuracy: 0.9375 - val_loss: 4.2340 - val_categorical_accuracy: 0.2000
# Epoch 160/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1959 - categorical_accuracy: 0.9125 - val_loss: 3.2885 - val_categorical_accuracy: 0.3500
# Epoch 161/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.2305 - categorical_accuracy: 0.9250 - val_loss: 3.5795 - val_categorical_accuracy: 0.3500
# Epoch 162/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1647 - categorical_accuracy: 0.9250 - val_loss: 3.5387 - val_categorical_accuracy: 0.3500
# Epoch 163/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1514 - categorical_accuracy: 0.9625 - val_loss: 3.0052 - val_categorical_accuracy: 0.3000
# Epoch 164/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1732 - categorical_accuracy: 0.9250 - val_loss: 4.3593 - val_categorical_accuracy: 0.1500
# Epoch 165/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1950 - categorical_accuracy: 0.8875 - val_loss: 4.0500 - val_categorical_accuracy: 0.2500
# Epoch 166/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1269 - categorical_accuracy: 0.9500 - val_loss: 4.2977 - val_categorical_accuracy: 0.1500
# Epoch 167/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0892 - categorical_accuracy: 0.9500 - val_loss: 4.6027 - val_categorical_accuracy: 0.2000
# Epoch 168/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1542 - categorical_accuracy: 0.9250 - val_loss: 4.0646 - val_categorical_accuracy: 0.2500
# Epoch 169/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1697 - categorical_accuracy: 0.9500 - val_loss: 4.5744 - val_categorical_accuracy: 0.2000
# Epoch 170/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1264 - categorical_accuracy: 0.9375 - val_loss: 4.3234 - val_categorical_accuracy: 0.3000
# Epoch 171/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1333 - categorical_accuracy: 0.9375 - val_loss: 3.7710 - val_categorical_accuracy: 0.3000
# Epoch 172/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.1667 - categorical_accuracy: 0.9375 - val_loss: 4.3374 - val_categorical_accuracy: 0.2500
# Epoch 173/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.2020 - categorical_accuracy: 0.9250 - val_loss: 2.8640 - val_categorical_accuracy: 0.3500
# Epoch 174/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2066 - categorical_accuracy: 0.9125 - val_loss: 4.2746 - val_categorical_accuracy: 0.1500
# Epoch 175/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1856 - categorical_accuracy: 0.9000 - val_loss: 3.2734 - val_categorical_accuracy: 0.3000
# Epoch 176/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1288 - categorical_accuracy: 0.9375 - val_loss: 3.6672 - val_categorical_accuracy: 0.3500
# Epoch 177/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.1398 - categorical_accuracy: 0.9625 - val_loss: 3.6591 - val_categorical_accuracy: 0.2000
# Epoch 178/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1750 - categorical_accuracy: 0.9125 - val_loss: 2.9225 - val_categorical_accuracy: 0.2500
# Epoch 179/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1414 - categorical_accuracy: 0.9500 - val_loss: 2.0735 - val_categorical_accuracy: 0.3000
# Epoch 180/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1334 - categorical_accuracy: 0.9375 - val_loss: 3.8331 - val_categorical_accuracy: 0.2000
# Epoch 181/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1172 - categorical_accuracy: 0.9375 - val_loss: 4.8482 - val_categorical_accuracy: 0.2000
# Epoch 182/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1197 - categorical_accuracy: 0.9500 - val_loss: 3.3739 - val_categorical_accuracy: 0.3000
# Epoch 183/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1292 - categorical_accuracy: 0.9250 - val_loss: 4.8947 - val_categorical_accuracy: 0.2000
# Epoch 184/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.1679 - categorical_accuracy: 0.9250 - val_loss: 2.8917 - val_categorical_accuracy: 0.4000
# Epoch 185/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1103 - categorical_accuracy: 0.9375 - val_loss: 4.2618 - val_categorical_accuracy: 0.2000
# Epoch 186/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1968 - categorical_accuracy: 0.9125 - val_loss: 3.6790 - val_categorical_accuracy: 0.2500
# Epoch 187/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1771 - categorical_accuracy: 0.9250 - val_loss: 4.2050 - val_categorical_accuracy: 0.2500
# Epoch 188/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.2445 - categorical_accuracy: 0.9000 - val_loss: 3.0664 - val_categorical_accuracy: 0.2000
# Epoch 189/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1312 - categorical_accuracy: 0.9250 - val_loss: 4.0628 - val_categorical_accuracy: 0.2500
# Epoch 190/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1591 - categorical_accuracy: 0.9375 - val_loss: 3.9068 - val_categorical_accuracy: 0.3000
# Epoch 191/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.2726 - categorical_accuracy: 0.9125 - val_loss: 4.0223 - val_categorical_accuracy: 0.1000
# Epoch 192/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1520 - categorical_accuracy: 0.9125 - val_loss: 3.0797 - val_categorical_accuracy: 0.3000
# Epoch 193/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0852 - categorical_accuracy: 0.9625 - val_loss: 3.6998 - val_categorical_accuracy: 0.4500
# Epoch 194/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1718 - categorical_accuracy: 0.9125 - val_loss: 5.7337 - val_categorical_accuracy: 0.1500
# Epoch 195/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1480 - categorical_accuracy: 0.9375 - val_loss: 3.5168 - val_categorical_accuracy: 0.2000
# Epoch 196/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0813 - categorical_accuracy: 0.9750 - val_loss: 3.3094 - val_categorical_accuracy: 0.4000
# Epoch 197/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1852 - categorical_accuracy: 0.9375 - val_loss: 4.3143 - val_categorical_accuracy: 0.2000
# Epoch 198/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0702 - categorical_accuracy: 0.9875 - val_loss: 4.1057 - val_categorical_accuracy: 0.3000
# Epoch 199/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.2142 - categorical_accuracy: 0.8750 - val_loss: 3.3832 - val_categorical_accuracy: 0.2500
# Epoch 200/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.2070 - categorical_accuracy: 0.9000 - val_loss: 3.7239 - val_categorical_accuracy: 0.2000
# Epoch 201/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1078 - categorical_accuracy: 0.9500 - val_loss: 3.7917 - val_categorical_accuracy: 0.2500
# Epoch 202/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1385 - categorical_accuracy: 0.9500 - val_loss: 3.7842 - val_categorical_accuracy: 0.3000
# Epoch 203/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0834 - categorical_accuracy: 0.9625 - val_loss: 3.9632 - val_categorical_accuracy: 0.2500
# Epoch 204/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1427 - categorical_accuracy: 0.9250 - val_loss: 3.2646 - val_categorical_accuracy: 0.2500
# Epoch 205/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1146 - categorical_accuracy: 0.9500 - val_loss: 3.7826 - val_categorical_accuracy: 0.2000
# Epoch 206/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1253 - categorical_accuracy: 0.9250 - val_loss: 4.7676 - val_categorical_accuracy: 0.1000
# Epoch 207/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0941 - categorical_accuracy: 0.9500 - val_loss: 3.7317 - val_categorical_accuracy: 0.1000
# Epoch 208/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1451 - categorical_accuracy: 0.9375 - val_loss: 3.8654 - val_categorical_accuracy: 0.2000
# Epoch 209/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0792 - categorical_accuracy: 0.9625 - val_loss: 4.3283 - val_categorical_accuracy: 0.2000
# Epoch 210/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1794 - categorical_accuracy: 0.9000 - val_loss: 4.4947 - val_categorical_accuracy: 0.1500
# Epoch 211/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1184 - categorical_accuracy: 0.9375 - val_loss: 2.1283 - val_categorical_accuracy: 0.4500
# Epoch 212/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1283 - categorical_accuracy: 0.9500 - val_loss: 3.4143 - val_categorical_accuracy: 0.3000
# Epoch 213/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0991 - categorical_accuracy: 0.9625 - val_loss: 4.5728 - val_categorical_accuracy: 0.2000
# Epoch 214/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.1237 - categorical_accuracy: 0.9625 - val_loss: 3.0059 - val_categorical_accuracy: 0.3500
# Epoch 215/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.2389 - categorical_accuracy: 0.9250 - val_loss: 3.8486 - val_categorical_accuracy: 0.2000
# Epoch 216/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1395 - categorical_accuracy: 0.9375 - val_loss: 3.9054 - val_categorical_accuracy: 0.1500
# Epoch 217/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0650 - categorical_accuracy: 0.9875 - val_loss: 3.9989 - val_categorical_accuracy: 0.2500
# Epoch 218/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1618 - categorical_accuracy: 0.9375 - val_loss: 3.3240 - val_categorical_accuracy: 0.3000
# Epoch 219/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1898 - categorical_accuracy: 0.9375 - val_loss: 3.2102 - val_categorical_accuracy: 0.3000
# Epoch 220/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1026 - categorical_accuracy: 0.9625 - val_loss: 3.2024 - val_categorical_accuracy: 0.2500
# Epoch 221/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.2239 - categorical_accuracy: 0.9000 - val_loss: 4.6597 - val_categorical_accuracy: 0.2500
# Epoch 222/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2669 - categorical_accuracy: 0.9125 - val_loss: 2.6851 - val_categorical_accuracy: 0.4000
# Epoch 223/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0683 - categorical_accuracy: 0.9625 - val_loss: 3.7300 - val_categorical_accuracy: 0.3000
# Epoch 224/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1205 - categorical_accuracy: 0.9250 - val_loss: 4.9219 - val_categorical_accuracy: 0.1500
# Epoch 225/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0788 - categorical_accuracy: 0.9625 - val_loss: 4.6888 - val_categorical_accuracy: 0.2500
# Epoch 226/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1233 - categorical_accuracy: 0.9375 - val_loss: 3.7509 - val_categorical_accuracy: 0.2000
# Epoch 227/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0454 - categorical_accuracy: 0.9750 - val_loss: 4.5251 - val_categorical_accuracy: 0.2000
# Epoch 228/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1568 - categorical_accuracy: 0.9250 - val_loss: 4.0314 - val_categorical_accuracy: 0.4000
# Epoch 229/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1009 - categorical_accuracy: 0.9500 - val_loss: 4.8022 - val_categorical_accuracy: 0.2500
# Epoch 230/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1593 - categorical_accuracy: 0.9250 - val_loss: 5.3327 - val_categorical_accuracy: 0.2500
# Epoch 231/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.2242 - categorical_accuracy: 0.9500 - val_loss: 3.3713 - val_categorical_accuracy: 0.3000
# Epoch 232/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1533 - categorical_accuracy: 0.9500 - val_loss: 3.8574 - val_categorical_accuracy: 0.3500
# Epoch 233/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0914 - categorical_accuracy: 0.9500 - val_loss: 3.9618 - val_categorical_accuracy: 0.2500
# Epoch 234/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1061 - categorical_accuracy: 0.9500 - val_loss: 3.1804 - val_categorical_accuracy: 0.4000
# Epoch 235/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.1510 - categorical_accuracy: 0.9375 - val_loss: 3.5358 - val_categorical_accuracy: 0.2500
# Epoch 236/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0493 - categorical_accuracy: 0.9750 - val_loss: 3.6111 - val_categorical_accuracy: 0.3000
# Epoch 237/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1212 - categorical_accuracy: 0.9500 - val_loss: 3.0914 - val_categorical_accuracy: 0.4000
# Epoch 238/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0543 - categorical_accuracy: 0.9750 - val_loss: 4.5901 - val_categorical_accuracy: 0.2000
# Epoch 239/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1645 - categorical_accuracy: 0.9250 - val_loss: 4.2294 - val_categorical_accuracy: 0.2000
# Epoch 240/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0936 - categorical_accuracy: 0.9500 - val_loss: 2.8331 - val_categorical_accuracy: 0.2500
# Epoch 241/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.2117 - categorical_accuracy: 0.9375 - val_loss: 4.9508 - val_categorical_accuracy: 0.1000
# Epoch 242/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0877 - categorical_accuracy: 0.9500 - val_loss: 4.8648 - val_categorical_accuracy: 0.2000
# Epoch 243/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0860 - categorical_accuracy: 0.9500 - val_loss: 3.9564 - val_categorical_accuracy: 0.2500
# Epoch 244/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1512 - categorical_accuracy: 0.9625 - val_loss: 4.6113 - val_categorical_accuracy: 0.2000
# Epoch 245/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0786 - categorical_accuracy: 0.9750 - val_loss: 2.6989 - val_categorical_accuracy: 0.4500
# Epoch 246/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1745 - categorical_accuracy: 0.9250 - val_loss: 2.7749 - val_categorical_accuracy: 0.4500
# Epoch 247/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0692 - categorical_accuracy: 0.9750 - val_loss: 5.0958 - val_categorical_accuracy: 0.2500
# Epoch 248/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2107 - categorical_accuracy: 0.9250 - val_loss: 5.0267 - val_categorical_accuracy: 0.3000
# Epoch 249/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1335 - categorical_accuracy: 0.9625 - val_loss: 4.3703 - val_categorical_accuracy: 0.2500
# Epoch 250/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1374 - categorical_accuracy: 0.9125 - val_loss: 4.4620 - val_categorical_accuracy: 0.2000
# Epoch 251/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1813 - categorical_accuracy: 0.9375 - val_loss: 4.4014 - val_categorical_accuracy: 0.2000
# Epoch 252/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0865 - categorical_accuracy: 0.9750 - val_loss: 4.4446 - val_categorical_accuracy: 0.2500
# Epoch 253/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2122 - categorical_accuracy: 0.9375 - val_loss: 4.2926 - val_categorical_accuracy: 0.2500
# Epoch 254/500
# 20/20 [==============================] - 5s 259ms/step - loss: 0.2390 - categorical_accuracy: 0.9250 - val_loss: 3.5401 - val_categorical_accuracy: 0.2000
# Epoch 255/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1541 - categorical_accuracy: 0.9500 - val_loss: 3.9895 - val_categorical_accuracy: 0.2500
# Epoch 256/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.2020 - categorical_accuracy: 0.9250 - val_loss: 3.6046 - val_categorical_accuracy: 0.4000
# Epoch 257/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1318 - categorical_accuracy: 0.9375 - val_loss: 4.0897 - val_categorical_accuracy: 0.2500
# Epoch 258/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.2017 - categorical_accuracy: 0.9250 - val_loss: 4.2689 - val_categorical_accuracy: 0.2000
# Epoch 259/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1421 - categorical_accuracy: 0.9375 - val_loss: 5.8778 - val_categorical_accuracy: 0.1500
# Epoch 260/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1495 - categorical_accuracy: 0.9500 - val_loss: 3.7226 - val_categorical_accuracy: 0.3500
# Epoch 261/500
# 20/20 [==============================] - ETA: 0s - loss: 0.2853 - categorical_accuracy: 0.8875INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# INFO:tensorflow:Assets written to: models/ConvNeXt.tf/assets
# 20/20 [==============================] - 31s 2s/step - loss: 0.2853 - categorical_accuracy: 0.8875 - val_loss: 3.4450 - val_categorical_accuracy: 0.5500
# Epoch 262/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1779 - categorical_accuracy: 0.9250 - val_loss: 4.5568 - val_categorical_accuracy: 0.2500
# Epoch 263/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.2334 - categorical_accuracy: 0.8875 - val_loss: 4.9152 - val_categorical_accuracy: 0.2000
# Epoch 264/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.1961 - categorical_accuracy: 0.9000 - val_loss: 4.1835 - val_categorical_accuracy: 0.2500
# Epoch 265/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1093 - categorical_accuracy: 0.9500 - val_loss: 3.2247 - val_categorical_accuracy: 0.3000
# Epoch 266/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.1331 - categorical_accuracy: 0.9375 - val_loss: 4.8238 - val_categorical_accuracy: 0.1500
# Epoch 267/500
# 20/20 [==============================] - 5s 263ms/step - loss: 0.1823 - categorical_accuracy: 0.9125 - val_loss: 3.4267 - val_categorical_accuracy: 0.2000
# Epoch 268/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.2289 - categorical_accuracy: 0.9000 - val_loss: 4.2717 - val_categorical_accuracy: 0.2500
# Epoch 269/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.2480 - categorical_accuracy: 0.9000 - val_loss: 4.2634 - val_categorical_accuracy: 0.2000
# Epoch 270/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.2023 - categorical_accuracy: 0.9125 - val_loss: 4.4481 - val_categorical_accuracy: 0.2000
# Epoch 271/500
# ...
# Epoch 418/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0951 - categorical_accuracy: 0.9500 - val_loss: 5.3211 - val_categorical_accuracy: 0.2000
# Epoch 419/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1206 - categorical_accuracy: 0.9625 - val_loss: 4.4845 - val_categorical_accuracy: 0.4000
# Epoch 420/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0718 - categorical_accuracy: 0.9625 - val_loss: 5.2574 - val_categorical_accuracy: 0.2500
# Epoch 421/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1021 - categorical_accuracy: 0.9375 - val_loss: 4.2105 - val_categorical_accuracy: 0.3500
# Epoch 422/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1696 - categorical_accuracy: 0.9375 - val_loss: 4.0833 - val_categorical_accuracy: 0.2500
# Epoch 423/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0960 - categorical_accuracy: 0.9625 - val_loss: 4.4418 - val_categorical_accuracy: 0.3000
# Epoch 424/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0630 - categorical_accuracy: 0.9625 - val_loss: 4.7427 - val_categorical_accuracy: 0.2500
# Epoch 425/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1425 - categorical_accuracy: 0.9375 - val_loss: 5.3929 - val_categorical_accuracy: 0.2000
# Epoch 426/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0624 - categorical_accuracy: 1.0000 - val_loss: 5.5954 - val_categorical_accuracy: 0.2000
# Epoch 427/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0428 - categorical_accuracy: 0.9750 - val_loss: 4.2757 - val_categorical_accuracy: 0.2500
# Epoch 428/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0793 - categorical_accuracy: 0.9500 - val_loss: 4.0853 - val_categorical_accuracy: 0.2500
# Epoch 429/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1384 - categorical_accuracy: 0.9625 - val_loss: 5.1665 - val_categorical_accuracy: 0.2500
# Epoch 430/500
# 20/20 [==============================] - 5s 259ms/step - loss: 0.1257 - categorical_accuracy: 0.9125 - val_loss: 4.2272 - val_categorical_accuracy: 0.3000
# Epoch 431/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0684 - categorical_accuracy: 0.9500 - val_loss: 4.6098 - val_categorical_accuracy: 0.3000
# Epoch 432/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.1422 - categorical_accuracy: 0.9375 - val_loss: 4.0730 - val_categorical_accuracy: 0.2000
# Epoch 433/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0827 - categorical_accuracy: 0.9500 - val_loss: 3.9319 - val_categorical_accuracy: 0.4500
# Epoch 434/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0378 - categorical_accuracy: 0.9750 - val_loss: 4.2046 - val_categorical_accuracy: 0.3500
# Epoch 435/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0535 - categorical_accuracy: 0.9625 - val_loss: 4.4336 - val_categorical_accuracy: 0.2000
# Epoch 436/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.1893 - categorical_accuracy: 0.9125 - val_loss: 4.0373 - val_categorical_accuracy: 0.3000
# Epoch 437/500
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1313 - categorical_accuracy: 0.9250 - val_loss: 4.5928 - val_categorical_accuracy: 0.2000
# Epoch 438/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0434 - categorical_accuracy: 0.9750 - val_loss: 3.9390 - val_categorical_accuracy: 0.3000
# Epoch 439/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1616 - categorical_accuracy: 0.9250 - val_loss: 3.9336 - val_categorical_accuracy: 0.2500
# Epoch 440/500
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0572 - categorical_accuracy: 0.9750 - val_loss: 2.0733 - val_categorical_accuracy: 0.5500
# Epoch 441/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0893 - categorical_accuracy: 0.9750 - val_loss: 4.2542 - val_categorical_accuracy: 0.2500
# Epoch 442/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0663 - categorical_accuracy: 0.9500 - val_loss: 4.0552 - val_categorical_accuracy: 0.2500
# Epoch 443/500
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0751 - categorical_accuracy: 0.9625 - val_loss: 3.4617 - val_categorical_accuracy: 0.3500
# Epoch 444/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0950 - categorical_accuracy: 0.9625 - val_loss: 4.0869 - val_categorical_accuracy: 0.2500
# Epoch 445/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0435 - categorical_accuracy: 0.9625 - val_loss: 3.7507 - val_categorical_accuracy: 0.3000
# Epoch 446/500
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0853 - categorical_accuracy: 0.9375 - val_loss: 4.0190 - val_categorical_accuracy: 0.2500
# Epoch 447/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0984 - categorical_accuracy: 0.9500 - val_loss: 3.7435 - val_categorical_accuracy: 0.3500
# Epoch 448/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1077 - categorical_accuracy: 0.9375 - val_loss: 3.0320 - val_categorical_accuracy: 0.4000
# Epoch 449/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.1118 - categorical_accuracy: 0.9500 - val_loss: 3.3644 - val_categorical_accuracy: 0.4000
# Epoch 450/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1088 - categorical_accuracy: 0.9375 - val_loss: 4.3463 - val_categorical_accuracy: 0.3500
# Epoch 451/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1621 - categorical_accuracy: 0.9375 - val_loss: 3.6398 - val_categorical_accuracy: 0.3500
# Epoch 452/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0540 - categorical_accuracy: 0.9625 - val_loss: 3.3259 - val_categorical_accuracy: 0.3000
# Epoch 453/500
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1087 - categorical_accuracy: 0.9625 - val_loss: 3.6039 - val_categorical_accuracy: 0.3000
# Epoch 454/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0325 - categorical_accuracy: 0.9750 - val_loss: 3.9003 - val_categorical_accuracy: 0.3000
# Epoch 455/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1526 - categorical_accuracy: 0.9000 - val_loss: 3.9709 - val_categorical_accuracy: 0.3500
# Epoch 456/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0574 - categorical_accuracy: 0.9750 - val_loss: 5.5275 - val_categorical_accuracy: 0.3000
# Epoch 457/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1112 - categorical_accuracy: 0.9500 - val_loss: 4.1406 - val_categorical_accuracy: 0.3500
# Epoch 458/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0949 - categorical_accuracy: 0.9625 - val_loss: 4.1877 - val_categorical_accuracy: 0.3000
# Epoch 459/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0856 - categorical_accuracy: 0.9375 - val_loss: 4.4114 - val_categorical_accuracy: 0.3000
# Epoch 460/500
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0944 - categorical_accuracy: 0.9375 - val_loss: 5.1862 - val_categorical_accuracy: 0.2000
# Epoch 461/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1079 - categorical_accuracy: 0.9625 - val_loss: 3.9369 - val_categorical_accuracy: 0.4500
# Epoch 462/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0673 - categorical_accuracy: 0.9625 - val_loss: 4.4601 - val_categorical_accuracy: 0.3000
# Epoch 463/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0812 - categorical_accuracy: 0.9625 - val_loss: 4.5092 - val_categorical_accuracy: 0.3000
# Epoch 464/500
# 20/20 [==============================] - 5s 262ms/step - loss: 0.1086 - categorical_accuracy: 0.9500 - val_loss: 5.1349 - val_categorical_accuracy: 0.2500
# Epoch 465/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0857 - categorical_accuracy: 0.9500 - val_loss: 4.9300 - val_categorical_accuracy: 0.3000
# Epoch 466/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0685 - categorical_accuracy: 0.9500 - val_loss: 3.9680 - val_categorical_accuracy: 0.2000
# Epoch 467/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1076 - categorical_accuracy: 0.9750 - val_loss: 4.9548 - val_categorical_accuracy: 0.2000
# Epoch 468/500
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0723 - categorical_accuracy: 0.9625 - val_loss: 3.7375 - val_categorical_accuracy: 0.3500
# Epoch 469/500
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0745 - categorical_accuracy: 0.9625 - val_loss: 5.1811 - val_categorical_accuracy: 0.2500
# Epoch 470/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0485 - categorical_accuracy: 0.9875 - val_loss: 5.2689 - val_categorical_accuracy: 0.3000
# Epoch 471/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1100 - categorical_accuracy: 0.9125 - val_loss: 5.4011 - val_categorical_accuracy: 0.3000
# Epoch 472/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.1167 - categorical_accuracy: 0.9500 - val_loss: 4.0317 - val_categorical_accuracy: 0.3500
# Epoch 473/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0969 - categorical_accuracy: 0.9625 - val_loss: 4.3888 - val_categorical_accuracy: 0.3500
# Epoch 474/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0701 - categorical_accuracy: 0.9625 - val_loss: 4.1131 - val_categorical_accuracy: 0.3500
# Epoch 475/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.1011 - categorical_accuracy: 0.9625 - val_loss: 4.6545 - val_categorical_accuracy: 0.4000
# Epoch 476/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0637 - categorical_accuracy: 0.9625 - val_loss: 4.4167 - val_categorical_accuracy: 0.3000
# Epoch 477/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1027 - categorical_accuracy: 0.9250 - val_loss: 4.8237 - val_categorical_accuracy: 0.4000
# Epoch 478/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0570 - categorical_accuracy: 0.9625 - val_loss: 5.5650 - val_categorical_accuracy: 0.1000
# Epoch 479/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.1260 - categorical_accuracy: 0.9375 - val_loss: 5.4461 - val_categorical_accuracy: 0.2500
# Epoch 480/500
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0682 - categorical_accuracy: 0.9625 - val_loss: 4.7603 - val_categorical_accuracy: 0.2000
# Epoch 481/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0717 - categorical_accuracy: 0.9500 - val_loss: 4.1685 - val_categorical_accuracy: 0.3500
# Epoch 482/500
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0398 - categorical_accuracy: 1.0000 - val_loss: 5.5824 - val_categorical_accuracy: 0.2500
# Epoch 483/500
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0843 - categorical_accuracy: 0.9750 - val_loss: 4.2471 - val_categorical_accuracy: 0.3500
# Epoch 484/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1008 - categorical_accuracy: 0.9250 - val_loss: 4.8712 - val_categorical_accuracy: 0.2500
# Epoch 485/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0855 - categorical_accuracy: 0.9500 - val_loss: 4.4610 - val_categorical_accuracy: 0.3500
# Epoch 486/500
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0467 - categorical_accuracy: 0.9875 - val_loss: 4.7608 - val_categorical_accuracy: 0.1500
# Epoch 487/500
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0394 - categorical_accuracy: 0.9750 - val_loss: 4.6892 - val_categorical_accuracy: 0.2500
# Epoch 488/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.1089 - categorical_accuracy: 0.9375 - val_loss: 4.5157 - val_categorical_accuracy: 0.3000
# Epoch 489/500
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0869 - categorical_accuracy: 0.9625 - val_loss: 4.2672 - val_categorical_accuracy: 0.3500
# Epoch 490/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0716 - categorical_accuracy: 0.9625 - val_loss: 4.9013 - val_categorical_accuracy: 0.2500
# Epoch 491/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0383 - categorical_accuracy: 0.9750 - val_loss: 5.1333 - val_categorical_accuracy: 0.3500
# Epoch 492/500
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0680 - categorical_accuracy: 0.9500 - val_loss: 4.2905 - val_categorical_accuracy: 0.3000
# Epoch 493/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1600 - categorical_accuracy: 0.9375 - val_loss: 4.6222 - val_categorical_accuracy: 0.2000
# Epoch 494/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0946 - categorical_accuracy: 0.9500 - val_loss: 5.3678 - val_categorical_accuracy: 0.2000
# Epoch 495/500
# 20/20 [==============================] - 5s 245ms/step - loss: 0.1990 - categorical_accuracy: 0.9125 - val_loss: 4.2673 - val_categorical_accuracy: 0.2500
# Epoch 496/500
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0729 - categorical_accuracy: 0.9500 - val_loss: 3.4596 - val_categorical_accuracy: 0.2000
# Epoch 497/500
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0402 - categorical_accuracy: 0.9625 - val_loss: 3.9423 - val_categorical_accuracy: 0.3000
# Epoch 498/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1068 - categorical_accuracy: 0.9250 - val_loss: 4.8026 - val_categorical_accuracy: 0.3000
# Epoch 499/500
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1141 - categorical_accuracy: 0.9125 - val_loss: 4.0267 - val_categorical_accuracy: 0.3500
# Epoch 500/500
# 20/20 [==============================] - 5s 251ms/step - loss: 0.1834 - categorical_accuracy: 0.9250 - val_loss: 4.5954 - val_categorical_accuracy: 0.4000
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>▁▁▁▁▁▆▇▇███▇████████████████████████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>████▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁███▇▇▇▆▆▅▅▄▄▃▃▂▂▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█████▄▃▂▂▁▂▂▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>▁▁▁▄▁▄██▇▃▅▇▅▅▄▆▅▅▇▄█▅▅▆▆▆▅▇▆▂▄▇▅▅▆█▄▇▅▄</td></tr><tr><td>epoch/val_loss</td><td>▁▁▁▁▁▁▂▁▃▃▄▃▄▄▄▃▃▃▄▅▄▅▄▄▅▄▄▅▄█▇▅▆▆▄▃▆▄▆▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>0.925</td></tr><tr><td>epoch/epoch</td><td>499</td></tr><tr><td>epoch/learning_rate</td><td>5e-05</td></tr><tr><td>epoch/loss</td><td>0.18337</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>0.4</td></tr><tr><td>epoch/val_loss</td><td>4.5954</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">C1_ConvNeXt_augmentation</strong> at: <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/kxadc7up' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/kxadc7up</a><br/> View project at: <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_180417-kxadc7up/logs</code>

# %% [markdown]
# # Cacheing V2

# %% [markdown]
# ## Dataset Creation

# %%
class SignRecognitionDatasetMHICachedV2(SignRecognitionDataset):

    def __init__(self, max_start: int, max_end, 
                 per_image_transform=None,
                 after_MHI_transform=None,
                 scaled_resolution : Tuple[int]= (224, 224),
                 frame_size:int=CONFIG.FRAME_SIZE,
                 data_limit : int = CONFIG.DATA_LIMIT,
                 decay : float = 0.7,
                 threshold_method : str = "regular",
                 threshold_val : float = 25/255.,
                 by_size=True,
                 train_val_split:float=CONFIG.PORTION_OF_DATA_FOR_TRAINING,
                 split:str="train") -> None:
        super().__init__(max_start, max_end)
        self.scaled_resolution = scaled_resolution
        self.DATA_LIMIT = data_limit
        self.by_size = by_size
        self.per_image_transform = per_image_transform
        self.after_MHI_transform = after_MHI_transform
        self.FRAME_SIZE = frame_size
        self.decay = decay
        self.threshold_method = threshold_method
        self.threshold_val = threshold_val
        
        self.keywords = ["image" ] + list(str(i) for i in range(frame_size-1))
        
        self.sort_by_size()
        
        if self.DATA_LIMIT > 0:
            self.video_paths        = self.video_paths[:self.DATA_LIMIT]
            self.labels             = self.labels[:self.DATA_LIMIT]
            self.start_frames       = self.start_frames[:self.DATA_LIMIT]
            self.end_frames         = self.end_frames[:self.DATA_LIMIT]
        
        
        self.label_2_id = { key : i for i, key in enumerate(np.unique(self.labels))}
        if data_limit < 0:
            train_ds_x, val_ds_x = train_test_split(self.videos_paths, train_size=train_val_split, random_state=42)
            train_ds_y, val_ds_y = train_test_split(self.labels, train_size=train_val_split, random_state=42)
            
        else:
            self.unique_labels = np.unique(self.labels[:data_limit])
            self.label_2_id = { key : i for i, key in enumerate(np.unique(self.labels))}
            
            train_ds_x, val_ds_x = train_test_split(self.videos_paths[:data_limit], train_size=train_val_split, random_state=42)
            train_ds_y, val_ds_y = train_test_split(self.labels[:data_limit], train_size=train_val_split, random_state=42)
                                    
        if split.lower() == "train":
            self.videos_paths = train_ds_x
            self.labels = train_ds_y
            
        elif split.lower() == "val":
            self.videos_paths = val_ds_x
            self.labels = val_ds_y
        
        else: 
            raise Exception("")

        self.cache_data()

    
    def cache_data(self):    
        self.cached_X = []
        self.cached_Y = []
        
        for i,path in tqdm(enumerate(self.videos_paths), desc="Cacheing"):
            
            trajectory = SignRecognitionDataset.get_video(path)  
            trajectory, label = self.preprocess_trajectory(trajectory), self.labels[i]     
            
            cached_X = []
            
            trajectory_length = trajectory.shape[0]
            if trajectory_length < self.FRAME_SIZE:
                cached_X.append(self.postprocess_trajectory(trajectory))
            else:
                for i in range(0, trajectory_length - self.FRAME_SIZE):
                    cached_X.append(self.postprocess_trajectory(trajectory[i: (i + self.FRAME_SIZE)]))

            
            onehotencoded = np.zeros(len(self.unique_labels))
            onehotencoded[self.label_2_id[label]] = 1.0
                    
            self.cached_X.append(cached_X)
            self.cached_Y.append(onehotencoded)
        
    def preprocess_trajectory(self, traj : List[np.ndarray]):
        return SignRecognitionDataset.rescale_video(traj, self.scaled_resolution)
        
    def __len__(self):
        return len(self.videos_paths)

    def postprocess_trajectory(self, traj : np.ndarray) -> np.ndarray:
        # timeframe, Width, height, channels
        ts, w, h, c = traj.shape
        
        mhi = np.zeros((w, h))
                
        for i in range(1, ts):
            frame_diff = np.abs(traj[i] - traj[i-1])
            gray_diff = np.mean(frame_diff, axis=2)
            
            _, binary_diff = cv2.threshold(gray_diff, self.threshold_val, 1.0, cv2.THRESH_BINARY)
    
    
            mhi = mhi * (1.0 - self.decay) + binary_diff

        mhi = mhi.reshape(mhi.shape[0], mhi.shape[1], 1)
        return np.concatenate([mhi,mhi,mhi], axis=2)


    def __getitem__(self, idx):
        
        trajectory, label = self.cached_X[idx], self.cached_Y[idx]
        
        # get random MHI from trajectory
        traj_len = len(trajectory)
        
        trajectory = trajectory[np.random.randint(traj_len)]        
        trajectory = self.per_image_transform(image=trajectory)["image"]

        return trajectory, label
    
    
import matplotlib.pyplot as plt 

transform = A.Compose(
    [
        A.Normalize(mean=CONFIG.mean, std=CONFIG.std),
        #A.HorizontalFlip(p=CONFIG.P_OF_TRANSFORM),
        #A.ShiftScaleRotate(p=CONFIG.P_OF_TRANSFORM, shift_limit=CONFIG.SHIFT_LIMIT, 
        #                   scale_limit=CONFIG.SCALE_LIMIT, rotate_limit=CONFIG.ROTATE_LIMIT),
        #A.RandomBrightnessContrast(p=CONFIG.P_OF_TRANSFORM_COLOR),
        #A.RGBShift(p=CONFIG.P_OF_TRANSFORM_COLOR),
    ]
)

train_ds = SignRecognitionDatasetMHICachedV2(1, 150, per_image_transform=transform, decay=CONFIG.DECAY, split="train")
val_ds = SignRecognitionDatasetMHICachedV2(1, 150, per_image_transform=transform, decay=CONFIG.DECAY, split="val")


train_ds_len = len(train_ds)
val_ds_len = len(val_ds)
unique_labels_num = len(train_ds.unique_labels)

print(f"size of train_ds = {len(train_ds)}, size of val_ds = {len(val_ds)}")
x, y = next(iter(train_ds))
x_shape = x.shape
y_shape = y.shape
print(x_shape, y_shape)
# Out:
# 100%|██████████| 2038/2038 [00:00<00:00, 166738.02it/s]
# Cacheing: 80it [02:07,  1.60s/it]
# 100%|██████████| 2038/2038 [00:00<00:00, 128467.82it/s]
# Cacheing: 20it [00:28,  1.44s/it]
# size of train_ds = 80, size of val_ds = 20
# (224, 224, 3) (7,)

# %%
def dataset_train_generator():
    # Instantiate your existing dataset loader

    for i in range(len(train_ds)):
        X_batch, Y_batch = train_ds[i]
        yield X_batch, Y_batch
        
def dataset_val_generator():
    # Instantiate your existing dataset loader

    for i in range(len(val_ds)):
        X_batch, Y_batch = val_ds[i]
        yield X_batch, Y_batch        

train_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_train_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)

val_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_val_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)

# %% [markdown]
# ## run the experiments

# %% [markdown]
# ### MobileNetV3

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.MobileNetV3Small(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, run_name="C2_MobileNetV3Small_augmentation_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            dataset_name="calcMHI-augmentMHI_no_transforms", 
            max_lr = 1e-4, 
            min_lr = 5e-5,
            T_max=251, 
            epochs=500,
            filepath=os.path.join("models", "C2_MobileNetV3Small_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_190038-op8dblu2</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/op8dblu2' target="_blank">C2_MobileNetV3Small</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/op8dblu2' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/op8dblu2</a>
# Epoch 1/100
#      19/Unknown - 18s 37ms/step - loss: 11.1512 - categorical_accuracy: 0.1579
# 2024-04-15 19:00:57.922702: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 6307957430542464359
# 2024-04-15 19:00:57.922794: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 9026497124938102457
# 2024-04-15 19:00:57.922815: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 7670920061644508805
# INFO:tensorflow:Assets written to: models/C2_MobileNetV3Small.tf/assets
# INFO:tensorflow:Assets written to: models/C2_MobileNetV3Small.tf/assets
# 20/20 [==============================] - 33s 828ms/step - loss: 11.1968 - categorical_accuracy: 0.1500 - val_loss: 2.0834 - val_categorical_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 1s 48ms/step - loss: 7.6474 - categorical_accuracy: 0.1250 - val_loss: 2.1278 - val_categorical_accuracy: 0.2000
# Epoch 3/100
# 20/20 [==============================] - 1s 46ms/step - loss: 5.3387 - categorical_accuracy: 0.2500 - val_loss: 2.2293 - val_categorical_accuracy: 0.2000
# Epoch 4/100
# 20/20 [==============================] - 1s 44ms/step - loss: 5.1190 - categorical_accuracy: 0.2125 - val_loss: 2.3188 - val_categorical_accuracy: 0.2000
# Epoch 5/100
# 20/20 [==============================] - 1s 42ms/step - loss: 4.6056 - categorical_accuracy: 0.2250 - val_loss: 2.3283 - val_categorical_accuracy: 0.2000
# Epoch 6/100
# 20/20 [==============================] - 1s 42ms/step - loss: 4.2142 - categorical_accuracy: 0.2375 - val_loss: 2.3995 - val_categorical_accuracy: 0.2000
# Epoch 7/100
# 20/20 [==============================] - 1s 43ms/step - loss: 4.2696 - categorical_accuracy: 0.2375 - val_loss: 2.4812 - val_categorical_accuracy: 0.2000
# Epoch 8/100
# 20/20 [==============================] - 1s 44ms/step - loss: 4.5407 - categorical_accuracy: 0.2625 - val_loss: 2.6190 - val_categorical_accuracy: 0.2000
# Epoch 9/100
# 20/20 [==============================] - 1s 42ms/step - loss: 3.7530 - categorical_accuracy: 0.3500 - val_loss: 2.6480 - val_categorical_accuracy: 0.2000
# Epoch 10/100
# 20/20 [==============================] - 1s 43ms/step - loss: 3.2388 - categorical_accuracy: 0.4000 - val_loss: 2.7497 - val_categorical_accuracy: 0.2000
# Epoch 11/100
# 20/20 [==============================] - 1s 44ms/step - loss: 3.5971 - categorical_accuracy: 0.3000 - val_loss: 2.8690 - val_categorical_accuracy: 0.0000e+00
# Epoch 12/100
# 20/20 [==============================] - 1s 45ms/step - loss: 3.1073 - categorical_accuracy: 0.3250 - val_loss: 3.1106 - val_categorical_accuracy: 0.0000e+00
# Epoch 13/100
# 20/20 [==============================] - 1s 44ms/step - loss: 3.5463 - categorical_accuracy: 0.3250 - val_loss: 3.2077 - val_categorical_accuracy: 0.0000e+00
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 3.6494 - categorical_accuracy: 0.2375 - val_loss: 3.4409 - val_categorical_accuracy: 0.0000e+00
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 2.8370 - categorical_accuracy: 0.3750 - val_loss: 3.6064 - val_categorical_accuracy: 0.0000e+00
# Epoch 16/100
# 20/20 [==============================] - 1s 45ms/step - loss: 3.0698 - categorical_accuracy: 0.3625 - val_loss: 3.5246 - val_categorical_accuracy: 0.0000e+00
# Epoch 17/100
# 20/20 [==============================] - 1s 46ms/step - loss: 3.1374 - categorical_accuracy: 0.4000 - val_loss: 3.4670 - val_categorical_accuracy: 0.0000e+00
# Epoch 18/100
# 20/20 [==============================] - 1s 44ms/step - loss: 3.2384 - categorical_accuracy: 0.3375 - val_loss: 3.2462 - val_categorical_accuracy: 0.0000e+00
# Epoch 19/100
# 20/20 [==============================] - 1s 45ms/step - loss: 2.4412 - categorical_accuracy: 0.4000 - val_loss: 2.9933 - val_categorical_accuracy: 0.0000e+00
# Epoch 20/100
# 20/20 [==============================] - 1s 48ms/step - loss: 2.4627 - categorical_accuracy: 0.4250 - val_loss: 2.9312 - val_categorical_accuracy: 0.2000
# Epoch 21/100
# 20/20 [==============================] - 1s 42ms/step - loss: 2.2872 - categorical_accuracy: 0.4750 - val_loss: 2.8571 - val_categorical_accuracy: 0.2000
# Epoch 22/100
# 20/20 [==============================] - 1s 41ms/step - loss: 2.5245 - categorical_accuracy: 0.4000 - val_loss: 2.9360 - val_categorical_accuracy: 0.2000
# Epoch 23/100
# 20/20 [==============================] - 1s 42ms/step - loss: 2.4394 - categorical_accuracy: 0.3875 - val_loss: 2.9105 - val_categorical_accuracy: 0.2000
# Epoch 24/100
# 20/20 [==============================] - 1s 44ms/step - loss: 2.0086 - categorical_accuracy: 0.4500 - val_loss: 2.9358 - val_categorical_accuracy: 0.2000
# Epoch 25/100
# 20/20 [==============================] - 1s 42ms/step - loss: 1.7765 - categorical_accuracy: 0.5000 - val_loss: 2.7911 - val_categorical_accuracy: 0.2000
# Epoch 26/100
# 20/20 [==============================] - 1s 41ms/step - loss: 2.7778 - categorical_accuracy: 0.3500 - val_loss: 2.6878 - val_categorical_accuracy: 0.2000
# Epoch 27/100
# 20/20 [==============================] - 1s 42ms/step - loss: 2.0042 - categorical_accuracy: 0.5000 - val_loss: 2.6613 - val_categorical_accuracy: 0.2000
# Epoch 28/100
# 20/20 [==============================] - 1s 40ms/step - loss: 2.2072 - categorical_accuracy: 0.4500 - val_loss: 2.8288 - val_categorical_accuracy: 0.2000
# Epoch 29/100
# 20/20 [==============================] - 1s 44ms/step - loss: 2.6217 - categorical_accuracy: 0.4125 - val_loss: 3.0416 - val_categorical_accuracy: 0.2000
# Epoch 30/100
# 20/20 [==============================] - 1s 40ms/step - loss: 1.8467 - categorical_accuracy: 0.5125 - val_loss: 3.6178 - val_categorical_accuracy: 0.0500
# Epoch 31/100
# 20/20 [==============================] - 1s 46ms/step - loss: 1.9467 - categorical_accuracy: 0.4875 - val_loss: 4.2296 - val_categorical_accuracy: 0.0500
# Epoch 32/100
# 20/20 [==============================] - 1s 45ms/step - loss: 1.6258 - categorical_accuracy: 0.5375 - val_loss: 4.2720 - val_categorical_accuracy: 0.0000e+00
# Epoch 33/100
# 20/20 [==============================] - 1s 44ms/step - loss: 1.7242 - categorical_accuracy: 0.5750 - val_loss: 4.4379 - val_categorical_accuracy: 0.0000e+00
# Epoch 34/100
# 20/20 [==============================] - 1s 43ms/step - loss: 2.1856 - categorical_accuracy: 0.5250 - val_loss: 4.8603 - val_categorical_accuracy: 0.0000e+00
# Epoch 35/100
# 20/20 [==============================] - 1s 46ms/step - loss: 1.8065 - categorical_accuracy: 0.5375 - val_loss: 4.8070 - val_categorical_accuracy: 0.0000e+00
# Epoch 36/100
# 20/20 [==============================] - 1s 49ms/step - loss: 1.6263 - categorical_accuracy: 0.4750 - val_loss: 4.6136 - val_categorical_accuracy: 0.0000e+00
# Epoch 37/100
# 20/20 [==============================] - 1s 46ms/step - loss: 1.2761 - categorical_accuracy: 0.6125 - val_loss: 4.5062 - val_categorical_accuracy: 0.0500
# Epoch 38/100
# 20/20 [==============================] - 1s 43ms/step - loss: 1.5122 - categorical_accuracy: 0.5750 - val_loss: 4.5208 - val_categorical_accuracy: 0.0500
# Epoch 39/100
# 20/20 [==============================] - 1s 44ms/step - loss: 1.7192 - categorical_accuracy: 0.5375 - val_loss: 4.6710 - val_categorical_accuracy: 0.0000e+00
# Epoch 40/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.4719 - categorical_accuracy: 0.6000 - val_loss: 4.4313 - val_categorical_accuracy: 0.0000e+00
# Epoch 41/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.4814 - categorical_accuracy: 0.6375 - val_loss: 4.3942 - val_categorical_accuracy: 0.0000e+00
# Epoch 42/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.7073 - categorical_accuracy: 0.5500 - val_loss: 4.4345 - val_categorical_accuracy: 0.2000
# Epoch 43/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.8530 - categorical_accuracy: 0.5750 - val_loss: 4.5668 - val_categorical_accuracy: 0.2000
# Epoch 44/100
# 20/20 [==============================] - 1s 42ms/step - loss: 1.2426 - categorical_accuracy: 0.6500 - val_loss: 4.4569 - val_categorical_accuracy: 0.2000
# Epoch 45/100
# 20/20 [==============================] - 1s 42ms/step - loss: 1.4183 - categorical_accuracy: 0.6125 - val_loss: 4.4030 - val_categorical_accuracy: 0.2000
# Epoch 46/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.9907 - categorical_accuracy: 0.7125 - val_loss: 4.6759 - val_categorical_accuracy: 0.2000
# Epoch 47/100
# 20/20 [==============================] - 1s 45ms/step - loss: 1.2487 - categorical_accuracy: 0.6125 - val_loss: 4.9496 - val_categorical_accuracy: 0.2000
# Epoch 48/100
# 20/20 [==============================] - 1s 43ms/step - loss: 1.2263 - categorical_accuracy: 0.6125 - val_loss: 5.3454 - val_categorical_accuracy: 0.2000
# Epoch 49/100
# 20/20 [==============================] - 1s 44ms/step - loss: 1.2303 - categorical_accuracy: 0.6250 - val_loss: 5.4214 - val_categorical_accuracy: 0.2000
# Epoch 50/100
# 20/20 [==============================] - 1s 45ms/step - loss: 1.2477 - categorical_accuracy: 0.6750 - val_loss: 5.4121 - val_categorical_accuracy: 0.2000
# Epoch 51/100
# 20/20 [==============================] - 1s 44ms/step - loss: 1.4147 - categorical_accuracy: 0.6750 - val_loss: 5.2455 - val_categorical_accuracy: 0.2000
# Epoch 52/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.2487 - categorical_accuracy: 0.6500 - val_loss: 5.1898 - val_categorical_accuracy: 0.2000
# Epoch 53/100
# 20/20 [==============================] - 1s 45ms/step - loss: 1.2343 - categorical_accuracy: 0.5875 - val_loss: 5.4313 - val_categorical_accuracy: 0.2000
# Epoch 54/100
# 20/20 [==============================] - 1s 44ms/step - loss: 1.2311 - categorical_accuracy: 0.6250 - val_loss: 5.8472 - val_categorical_accuracy: 0.2000
# Epoch 55/100
# 20/20 [==============================] - 1s 43ms/step - loss: 1.1531 - categorical_accuracy: 0.6750 - val_loss: 5.6918 - val_categorical_accuracy: 0.2000
# Epoch 56/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.9096 - categorical_accuracy: 0.6875 - val_loss: 5.0507 - val_categorical_accuracy: 0.2000
# Epoch 57/100
# 20/20 [==============================] - 1s 40ms/step - loss: 1.1521 - categorical_accuracy: 0.6500 - val_loss: 5.4299 - val_categorical_accuracy: 0.2000
# Epoch 58/100
# 20/20 [==============================] - 1s 40ms/step - loss: 1.0613 - categorical_accuracy: 0.6250 - val_loss: 5.1038 - val_categorical_accuracy: 0.2000
# Epoch 59/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.9272 - categorical_accuracy: 0.7250 - val_loss: 4.9809 - val_categorical_accuracy: 0.2000
# Epoch 60/100
# 20/20 [==============================] - 1s 41ms/step - loss: 1.2672 - categorical_accuracy: 0.6375 - val_loss: 5.4870 - val_categorical_accuracy: 0.2000
# Epoch 61/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.8977 - categorical_accuracy: 0.7250 - val_loss: 5.3455 - val_categorical_accuracy: 0.2000
# Epoch 62/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.9602 - categorical_accuracy: 0.7250 - val_loss: 5.3919 - val_categorical_accuracy: 0.2000
# Epoch 63/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.8078 - categorical_accuracy: 0.8125 - val_loss: 5.2342 - val_categorical_accuracy: 0.2000
# Epoch 64/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.8651 - categorical_accuracy: 0.7500 - val_loss: 5.3657 - val_categorical_accuracy: 0.2000
# Epoch 65/100
# 20/20 [==============================] - 1s 45ms/step - loss: 1.1397 - categorical_accuracy: 0.6750 - val_loss: 5.7445 - val_categorical_accuracy: 0.2000
# Epoch 66/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.7942 - categorical_accuracy: 0.7875 - val_loss: 5.8053 - val_categorical_accuracy: 0.2000
# Epoch 67/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.9189 - categorical_accuracy: 0.6875 - val_loss: 5.5156 - val_categorical_accuracy: 0.2000
# Epoch 68/100
# 20/20 [==============================] - 1s 48ms/step - loss: 0.8366 - categorical_accuracy: 0.7750 - val_loss: 5.4176 - val_categorical_accuracy: 0.2000
# Epoch 69/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.6146 - categorical_accuracy: 0.8375 - val_loss: 5.4357 - val_categorical_accuracy: 0.2000
# Epoch 70/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.7387 - categorical_accuracy: 0.7500 - val_loss: 5.5534 - val_categorical_accuracy: 0.2000
# Epoch 71/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.9694 - categorical_accuracy: 0.7125 - val_loss: 4.9212 - val_categorical_accuracy: 0.2000
# Epoch 72/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.4942 - categorical_accuracy: 0.8250 - val_loss: 4.3478 - val_categorical_accuracy: 0.2000
# Epoch 73/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.8611 - categorical_accuracy: 0.7875 - val_loss: 4.4862 - val_categorical_accuracy: 0.2000
# Epoch 74/100
# 20/20 [==============================] - 1s 42ms/step - loss: 1.0054 - categorical_accuracy: 0.7125 - val_loss: 4.7627 - val_categorical_accuracy: 0.2000
# Epoch 75/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.8075 - categorical_accuracy: 0.7500 - val_loss: 4.6887 - val_categorical_accuracy: 0.2000
# Epoch 76/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5188 - categorical_accuracy: 0.7875 - val_loss: 5.1241 - val_categorical_accuracy: 0.2000
# Epoch 77/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.9232 - categorical_accuracy: 0.7125 - val_loss: 5.3084 - val_categorical_accuracy: 0.2000
# Epoch 78/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.7124 - categorical_accuracy: 0.8125 - val_loss: 5.3759 - val_categorical_accuracy: 0.2000
# Epoch 79/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.7414 - categorical_accuracy: 0.7750 - val_loss: 5.6987 - val_categorical_accuracy: 0.2000
# Epoch 80/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.7271 - categorical_accuracy: 0.8125 - val_loss: 6.0166 - val_categorical_accuracy: 0.2000
# Epoch 81/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.5855 - categorical_accuracy: 0.8125 - val_loss: 6.2088 - val_categorical_accuracy: 0.2000
# Epoch 82/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.5790 - categorical_accuracy: 0.8250 - val_loss: 6.1361 - val_categorical_accuracy: 0.2000
# Epoch 83/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.7116 - categorical_accuracy: 0.8125 - val_loss: 5.9359 - val_categorical_accuracy: 0.2000
# Epoch 84/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5566 - categorical_accuracy: 0.8625 - val_loss: 6.2113 - val_categorical_accuracy: 0.2000
# Epoch 85/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.3659 - categorical_accuracy: 0.8625 - val_loss: 5.9041 - val_categorical_accuracy: 0.2000
# Epoch 86/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.5683 - categorical_accuracy: 0.8000 - val_loss: 5.3613 - val_categorical_accuracy: 0.2000
# Epoch 87/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.5875 - categorical_accuracy: 0.8125 - val_loss: 5.0790 - val_categorical_accuracy: 0.2000
# Epoch 88/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.5225 - categorical_accuracy: 0.8125 - val_loss: 4.5827 - val_categorical_accuracy: 0.2000
# Epoch 89/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.6900 - categorical_accuracy: 0.8125 - val_loss: 4.3622 - val_categorical_accuracy: 0.2000
# Epoch 90/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.5807 - categorical_accuracy: 0.8000 - val_loss: 4.1442 - val_categorical_accuracy: 0.2000
# Epoch 91/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.2809 - categorical_accuracy: 0.8875 - val_loss: 4.3437 - val_categorical_accuracy: 0.2000
# Epoch 92/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5426 - categorical_accuracy: 0.8500 - val_loss: 4.1321 - val_categorical_accuracy: 0.2000
# Epoch 93/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.5155 - categorical_accuracy: 0.8500 - val_loss: 4.2284 - val_categorical_accuracy: 0.2000
# Epoch 94/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.4926 - categorical_accuracy: 0.8875 - val_loss: 4.2717 - val_categorical_accuracy: 0.2000
# Epoch 95/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5281 - categorical_accuracy: 0.8250 - val_loss: 4.1961 - val_categorical_accuracy: 0.2000
# Epoch 96/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5438 - categorical_accuracy: 0.8125 - val_loss: 4.2207 - val_categorical_accuracy: 0.2000
# Epoch 97/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.4055 - categorical_accuracy: 0.8625 - val_loss: 4.4071 - val_categorical_accuracy: 0.2000
# Epoch 98/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2151 - categorical_accuracy: 0.9500 - val_loss: 4.4008 - val_categorical_accuracy: 0.2000
# Epoch 99/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.4363 - categorical_accuracy: 0.8625 - val_loss: 4.6213 - val_categorical_accuracy: 0.2000
# Epoch 100/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.3332 - categorical_accuracy: 0.8750 - val_loss: 4.3218 - val_categorical_accuracy: 0.2000
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>▁▂▂▂▂▃▃▃▄▃▃▄▄▅▄▅▆▆▆▆▆▆▆▆▆▇▆█▇▆▆▇▇█▇▇████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>████▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁███▇▇▇▆▆▅▅▄▄▃▃▂▂▁▁▁█</td></tr><tr><td>epoch/loss</td><td>█▄▄▄▃▃▃▃▂▂▃▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>████▁▁▁▁████▃▁▁▁▁███████████████████████</td></tr><tr><td>epoch/val_loss</td><td>▁▁▂▂▂▃▃▃▂▂▂▂▅▆▅▅▅▅▅▇▆▇▆▆▇▇▇▇▅▆▆▇██▆▅▄▅▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>0.875</td></tr><tr><td>epoch/epoch</td><td>99</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>0.33321</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>0.2</td></tr><tr><td>epoch/val_loss</td><td>4.3218</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">C2_MobileNetV3Small</strong> at: <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/op8dblu2' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/op8dblu2</a><br/> View project at: <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_190038-op8dblu2/logs</code>

# %% [markdown]
# ### Resnet50

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.ResNet50(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, 
            run_name="C2_Resnet50_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            T_max=251, 
            epochs=500,
            max_lr = 0.75e-4, 
            min_lr = 2.5e-5,
            dataset_name="calcMHI-augmentMHI_no_transforms", 
            filepath=os.path.join("models", "MHI_Resnet50_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_190615-urqfxmog</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/urqfxmog' target="_blank">C2_Resnet50</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/urqfxmog' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/urqfxmog</a>
# Epoch 1/500
#      20/Unknown - 27s 59ms/step - loss: 2.5596 - categorical_accuracy: 0.1750
# 2024-04-15 19:06:44.268103: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 7827257057883545257
# 2024-04-15 19:06:44.268228: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 8940206431827680969
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 44s 931ms/step - loss: 2.5596 - categorical_accuracy: 0.1750 - val_loss: 2.8761 - val_categorical_accuracy: 0.2000
# Epoch 2/500
# 20/20 [==============================] - 1s 58ms/step - loss: 2.1957 - categorical_accuracy: 0.2250 - val_loss: 2.9090 - val_categorical_accuracy: 0.2000
# Epoch 3/500
# 20/20 [==============================] - 1s 58ms/step - loss: 2.0456 - categorical_accuracy: 0.2375 - val_loss: 2.3261 - val_categorical_accuracy: 0.2000
# Epoch 4/500
# 20/20 [==============================] - 1s 64ms/step - loss: 2.0417 - categorical_accuracy: 0.2750 - val_loss: 2.3356 - val_categorical_accuracy: 0.2000
# Epoch 5/500
# 20/20 [==============================] - 1s 64ms/step - loss: 1.7729 - categorical_accuracy: 0.3875 - val_loss: 4.5294 - val_categorical_accuracy: 0.2000
# Epoch 6/500
# 20/20 [==============================] - 1s 63ms/step - loss: 1.8547 - categorical_accuracy: 0.3000 - val_loss: 4.1211 - val_categorical_accuracy: 0.2000
# Epoch 7/500
# 20/20 [==============================] - 1s 60ms/step - loss: 1.6266 - categorical_accuracy: 0.3750 - val_loss: 4.4373 - val_categorical_accuracy: 0.2000
# Epoch 8/500
# 20/20 [==============================] - 1s 61ms/step - loss: 1.7674 - categorical_accuracy: 0.4250 - val_loss: 3.2890 - val_categorical_accuracy: 0.2000
# Epoch 9/500
# 20/20 [==============================] - 1s 56ms/step - loss: 1.5652 - categorical_accuracy: 0.4375 - val_loss: 3.2872 - val_categorical_accuracy: 0.2000
# Epoch 10/500
# 20/20 [==============================] - 1s 60ms/step - loss: 1.3548 - categorical_accuracy: 0.4500 - val_loss: 3.2342 - val_categorical_accuracy: 0.2000
# Epoch 11/500
# 20/20 [==============================] - 1s 60ms/step - loss: 1.2755 - categorical_accuracy: 0.5625 - val_loss: 3.8158 - val_categorical_accuracy: 0.2000
# Epoch 12/500
# 20/20 [==============================] - 1s 58ms/step - loss: 1.4280 - categorical_accuracy: 0.4875 - val_loss: 4.1096 - val_categorical_accuracy: 0.2000
# Epoch 13/500
# 20/20 [==============================] - 1s 59ms/step - loss: 1.1775 - categorical_accuracy: 0.5750 - val_loss: 3.0396 - val_categorical_accuracy: 0.2000
# Epoch 14/500
# 20/20 [==============================] - 1s 58ms/step - loss: 1.1573 - categorical_accuracy: 0.5625 - val_loss: 2.6176 - val_categorical_accuracy: 0.0500
# Epoch 15/500
# 20/20 [==============================] - 1s 61ms/step - loss: 1.1563 - categorical_accuracy: 0.5750 - val_loss: 2.9275 - val_categorical_accuracy: 0.0500
# Epoch 16/500
# 20/20 [==============================] - 1s 61ms/step - loss: 1.1416 - categorical_accuracy: 0.6375 - val_loss: 2.4059 - val_categorical_accuracy: 0.2000
# Epoch 17/500
# 20/20 [==============================] - 1s 67ms/step - loss: 1.0861 - categorical_accuracy: 0.6500 - val_loss: 2.8110 - val_categorical_accuracy: 0.2000
# Epoch 18/500
# 20/20 [==============================] - 1s 62ms/step - loss: 1.0947 - categorical_accuracy: 0.6250 - val_loss: 3.0796 - val_categorical_accuracy: 0.1500
# Epoch 19/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.9658 - categorical_accuracy: 0.6625 - val_loss: 2.6013 - val_categorical_accuracy: 0.2000
# Epoch 20/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.9444 - categorical_accuracy: 0.7000 - val_loss: 3.6797 - val_categorical_accuracy: 0.0500
# Epoch 21/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.9928 - categorical_accuracy: 0.6625 - val_loss: 3.6386 - val_categorical_accuracy: 0.0500
# Epoch 22/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.8337 - categorical_accuracy: 0.7500 - val_loss: 4.2531 - val_categorical_accuracy: 0.0500
# Epoch 23/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.9388 - categorical_accuracy: 0.7125 - val_loss: 6.3735 - val_categorical_accuracy: 0.2000
# Epoch 24/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.7520 - categorical_accuracy: 0.8000 - val_loss: 12.1319 - val_categorical_accuracy: 0.0500
# Epoch 25/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.6909 - categorical_accuracy: 0.7750 - val_loss: 8.1435 - val_categorical_accuracy: 0.2000
# Epoch 26/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.6297 - categorical_accuracy: 0.8125 - val_loss: 9.4190 - val_categorical_accuracy: 0.2000
# Epoch 27/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.8388 - categorical_accuracy: 0.7750 - val_loss: 9.4236 - val_categorical_accuracy: 0.2000
# Epoch 28/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.7422 - categorical_accuracy: 0.7250 - val_loss: 8.1192 - val_categorical_accuracy: 0.2000
# Epoch 29/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.6888 - categorical_accuracy: 0.7750 - val_loss: 12.3196 - val_categorical_accuracy: 0.2000
# Epoch 30/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.6238 - categorical_accuracy: 0.8125 - val_loss: 14.6790 - val_categorical_accuracy: 0.2000
# Epoch 31/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.6049 - categorical_accuracy: 0.8000 - val_loss: 18.2986 - val_categorical_accuracy: 0.0500
# Epoch 32/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.5369 - categorical_accuracy: 0.8000 - val_loss: 15.7413 - val_categorical_accuracy: 0.2000
# Epoch 33/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.5069 - categorical_accuracy: 0.8500 - val_loss: 28.6784 - val_categorical_accuracy: 0.2000
# Epoch 34/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.5226 - categorical_accuracy: 0.8000 - val_loss: 48.4128 - val_categorical_accuracy: 0.2000
# Epoch 35/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.5535 - categorical_accuracy: 0.8500 - val_loss: 58.6601 - val_categorical_accuracy: 0.2000
# Epoch 36/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.4803 - categorical_accuracy: 0.8875 - val_loss: 40.3443 - val_categorical_accuracy: 0.2000
# Epoch 37/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.4066 - categorical_accuracy: 0.8750 - val_loss: 33.9168 - val_categorical_accuracy: 0.2000
# Epoch 38/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.3459 - categorical_accuracy: 0.9125 - val_loss: 19.4569 - val_categorical_accuracy: 0.2000
# Epoch 39/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.3869 - categorical_accuracy: 0.9000 - val_loss: 14.2475 - val_categorical_accuracy: 0.2000
# Epoch 40/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.3519 - categorical_accuracy: 0.8875 - val_loss: 18.3880 - val_categorical_accuracy: 0.2000
# Epoch 41/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.3979 - categorical_accuracy: 0.8500 - val_loss: 17.9744 - val_categorical_accuracy: 0.2000
# Epoch 42/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.2684 - categorical_accuracy: 0.9375 - val_loss: 11.8527 - val_categorical_accuracy: 0.2000
# Epoch 43/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.4968 - categorical_accuracy: 0.8625 - val_loss: 11.7919 - val_categorical_accuracy: 0.1500
# Epoch 44/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.3213 - categorical_accuracy: 0.9125 - val_loss: 14.9032 - val_categorical_accuracy: 0.1500
# Epoch 45/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.2931 - categorical_accuracy: 0.9250 - val_loss: 14.9966 - val_categorical_accuracy: 0.2000
# Epoch 46/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.2512 - categorical_accuracy: 0.9250 - val_loss: 17.4749 - val_categorical_accuracy: 0.2000
# Epoch 47/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2941 - categorical_accuracy: 0.9375 - val_loss: 12.6253 - val_categorical_accuracy: 0.2000
# Epoch 48/500
# 20/20 [==============================] - 1s 56ms/step - loss: 0.2477 - categorical_accuracy: 0.9375 - val_loss: 15.5026 - val_categorical_accuracy: 0.2000
# Epoch 49/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.2484 - categorical_accuracy: 0.8875 - val_loss: 19.4849 - val_categorical_accuracy: 0.2000
# Epoch 50/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2609 - categorical_accuracy: 0.9625 - val_loss: 20.5867 - val_categorical_accuracy: 0.2000
# Epoch 51/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.2826 - categorical_accuracy: 0.9250 - val_loss: 20.1601 - val_categorical_accuracy: 0.2000
# Epoch 52/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.2816 - categorical_accuracy: 0.9125 - val_loss: 13.1816 - val_categorical_accuracy: 0.2000
# Epoch 53/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.2276 - categorical_accuracy: 0.9500 - val_loss: 13.4388 - val_categorical_accuracy: 0.2000
# Epoch 54/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.1989 - categorical_accuracy: 0.9250 - val_loss: 14.3227 - val_categorical_accuracy: 0.2000
# Epoch 55/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.1505 - categorical_accuracy: 0.9750 - val_loss: 16.7013 - val_categorical_accuracy: 0.0500
# Epoch 56/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1278 - categorical_accuracy: 0.9750 - val_loss: 16.5755 - val_categorical_accuracy: 0.1500
# Epoch 57/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.1504 - categorical_accuracy: 0.9500 - val_loss: 17.3806 - val_categorical_accuracy: 0.1000
# Epoch 58/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2419 - categorical_accuracy: 0.9375 - val_loss: 18.4066 - val_categorical_accuracy: 0.1000
# Epoch 59/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0753 - categorical_accuracy: 0.9875 - val_loss: 20.4045 - val_categorical_accuracy: 0.2000
# Epoch 60/500
# 20/20 [==============================] - 1s 54ms/step - loss: 0.1255 - categorical_accuracy: 0.9750 - val_loss: 14.5531 - val_categorical_accuracy: 0.2000
# Epoch 61/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1563 - categorical_accuracy: 0.9625INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 19s 1s/step - loss: 0.1563 - categorical_accuracy: 0.9625 - val_loss: 19.2733 - val_categorical_accuracy: 0.2500
# Epoch 62/500
# 20/20 [==============================] - ETA: 0s - loss: 0.2343 - categorical_accuracy: 0.9500INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# INFO:tensorflow:Assets written to: models/MHI_Resnet50.tf/assets
# 20/20 [==============================] - 19s 1s/step - loss: 0.2343 - categorical_accuracy: 0.9500 - val_loss: 20.3617 - val_categorical_accuracy: 0.3000
# Epoch 63/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.2062 - categorical_accuracy: 0.9625 - val_loss: 18.3190 - val_categorical_accuracy: 0.2500
# Epoch 64/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0724 - categorical_accuracy: 0.9875 - val_loss: 21.3327 - val_categorical_accuracy: 0.2000
# Epoch 65/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0748 - categorical_accuracy: 0.9875 - val_loss: 27.8325 - val_categorical_accuracy: 0.2000
# Epoch 66/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.1365 - categorical_accuracy: 0.9500 - val_loss: 25.7577 - val_categorical_accuracy: 0.2000
# Epoch 67/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1439 - categorical_accuracy: 0.9500 - val_loss: 21.3883 - val_categorical_accuracy: 0.1500
# Epoch 68/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0718 - categorical_accuracy: 0.9750 - val_loss: 24.6883 - val_categorical_accuracy: 0.1500
# Epoch 69/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0751 - categorical_accuracy: 1.0000 - val_loss: 22.0187 - val_categorical_accuracy: 0.1500
# Epoch 70/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0646 - categorical_accuracy: 0.9875 - val_loss: 10.2791 - val_categorical_accuracy: 0.1500
# Epoch 71/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1429 - categorical_accuracy: 0.9750 - val_loss: 10.2833 - val_categorical_accuracy: 0.1000
# Epoch 72/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0753 - categorical_accuracy: 0.9875 - val_loss: 10.0427 - val_categorical_accuracy: 0.3000
# Epoch 73/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0801 - categorical_accuracy: 0.9750 - val_loss: 6.5025 - val_categorical_accuracy: 0.2500
# Epoch 74/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0818 - categorical_accuracy: 0.9875 - val_loss: 6.9198 - val_categorical_accuracy: 0.2000
# Epoch 75/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0868 - categorical_accuracy: 0.9875 - val_loss: 7.3351 - val_categorical_accuracy: 0.3000
# Epoch 76/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0372 - categorical_accuracy: 1.0000 - val_loss: 9.5834 - val_categorical_accuracy: 0.2000
# Epoch 77/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0300 - categorical_accuracy: 1.0000 - val_loss: 8.1161 - val_categorical_accuracy: 0.2000
# Epoch 78/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0344 - categorical_accuracy: 1.0000 - val_loss: 8.9084 - val_categorical_accuracy: 0.1500
# Epoch 79/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0505 - categorical_accuracy: 0.9875 - val_loss: 6.4788 - val_categorical_accuracy: 0.2500
# Epoch 80/500
# 20/20 [==============================] - 1s 56ms/step - loss: 0.0619 - categorical_accuracy: 1.0000 - val_loss: 5.7804 - val_categorical_accuracy: 0.0500
# Epoch 81/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0335 - categorical_accuracy: 1.0000 - val_loss: 5.6294 - val_categorical_accuracy: 0.2000
# Epoch 82/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0359 - categorical_accuracy: 1.0000 - val_loss: 6.0870 - val_categorical_accuracy: 0.1000
# Epoch 83/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0288 - categorical_accuracy: 1.0000 - val_loss: 6.6384 - val_categorical_accuracy: 0.1000
# Epoch 84/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0217 - categorical_accuracy: 1.0000 - val_loss: 6.8142 - val_categorical_accuracy: 0.2500
# Epoch 85/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0208 - categorical_accuracy: 1.0000 - val_loss: 6.6036 - val_categorical_accuracy: 0.1500
# Epoch 86/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0277 - categorical_accuracy: 1.0000 - val_loss: 7.0904 - val_categorical_accuracy: 0.0500
# Epoch 87/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0322 - categorical_accuracy: 1.0000 - val_loss: 10.0883 - val_categorical_accuracy: 0.0500
# Epoch 88/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0323 - categorical_accuracy: 1.0000 - val_loss: 5.5959 - val_categorical_accuracy: 0.2000
# Epoch 89/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0336 - categorical_accuracy: 0.9875 - val_loss: 5.2603 - val_categorical_accuracy: 0.2000
# Epoch 90/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0314 - categorical_accuracy: 1.0000 - val_loss: 6.4545 - val_categorical_accuracy: 0.0500
# Epoch 91/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0462 - categorical_accuracy: 0.9875 - val_loss: 4.5229 - val_categorical_accuracy: 0.2000
# Epoch 92/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0997 - categorical_accuracy: 0.9625 - val_loss: 7.3143 - val_categorical_accuracy: 0.0500
# Epoch 93/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0263 - categorical_accuracy: 1.0000 - val_loss: 5.7257 - val_categorical_accuracy: 0.0500
# Epoch 94/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0359 - categorical_accuracy: 1.0000 - val_loss: 5.2104 - val_categorical_accuracy: 0.1000
# Epoch 95/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0359 - categorical_accuracy: 1.0000 - val_loss: 6.7819 - val_categorical_accuracy: 0.1000
# Epoch 96/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0244 - categorical_accuracy: 1.0000 - val_loss: 5.5484 - val_categorical_accuracy: 0.1000
# Epoch 97/500
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0259 - categorical_accuracy: 1.0000 - val_loss: 6.8699 - val_categorical_accuracy: 0.1000
# Epoch 98/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0288 - categorical_accuracy: 1.0000 - val_loss: 5.5043 - val_categorical_accuracy: 0.0500
# Epoch 99/500
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0290 - categorical_accuracy: 1.0000 - val_loss: 6.6426 - val_categorical_accuracy: 0.1000
# Epoch 100/500
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0476 - categorical_accuracy: 0.9875 - val_loss: 5.0729 - val_categorical_accuracy: 0.1000
# Epoch 101/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0183 - categorical_accuracy: 1.0000 - val_loss: 9.4788 - val_categorical_accuracy: 0.0500
# Epoch 102/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0191 - categorical_accuracy: 1.0000 - val_loss: 7.3598 - val_categorical_accuracy: 0.1000
# Epoch 103/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0270 - categorical_accuracy: 1.0000 - val_loss: 6.6064 - val_categorical_accuracy: 0.1000
# Epoch 104/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0156 - categorical_accuracy: 1.0000 - val_loss: 4.0170 - val_categorical_accuracy: 0.1500
# Epoch 105/500
# 20/20 [==============================] - 1s 57ms/step - loss: 0.1144 - categorical_accuracy: 0.9875 - val_loss: 6.3322 - val_categorical_accuracy: 0.2000
# Epoch 106/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0165 - categorical_accuracy: 1.0000 - val_loss: 5.6223 - val_categorical_accuracy: 0.2000
# Epoch 107/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0230 - categorical_accuracy: 1.0000 - val_loss: 5.3145 - val_categorical_accuracy: 0.1500
# Epoch 108/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0170 - categorical_accuracy: 1.0000 - val_loss: 5.8554 - val_categorical_accuracy: 0.0500
# Epoch 109/500
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0192 - categorical_accuracy: 1.0000 - val_loss: 7.4421 - val_categorical_accuracy: 0.0500
# Epoch 110/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0243 - categorical_accuracy: 1.0000 - val_loss: 5.8625 - val_categorical_accuracy: 0.2000
# Epoch 111/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1511 - categorical_accuracy: 0.9750 - val_loss: 6.6860 - val_categorical_accuracy: 0.1000
# Epoch 112/500
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0166 - categorical_accuracy: 1.0000 - val_loss: 6.5161 - val_categorical_accuracy: 0.1500
# Epoch 113/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0165 - categorical_accuracy: 1.0000 - val_loss: 5.7663 - val_categorical_accuracy: 0.1500
# Epoch 114/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0120 - categorical_accuracy: 1.0000 - val_loss: 5.7401 - val_categorical_accuracy: 0.1000
# Epoch 115/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0106 - categorical_accuracy: 1.0000 - val_loss: 5.1982 - val_categorical_accuracy: 0.0500
# Epoch 116/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0127 - categorical_accuracy: 1.0000 - val_loss: 6.2413 - val_categorical_accuracy: 0.1500
# Epoch 117/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0161 - categorical_accuracy: 1.0000 - val_loss: 5.4738 - val_categorical_accuracy: 0.0500
# Epoch 118/500
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0269 - categorical_accuracy: 1.0000 - val_loss: 6.4176 - val_categorical_accuracy: 0.1000
# Epoch 119/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0144 - categorical_accuracy: 1.0000 - val_loss: 5.6813 - val_categorical_accuracy: 0.0500
# Epoch 120/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0110 - categorical_accuracy: 1.0000 - val_loss: 6.5142 - val_categorical_accuracy: 0.1500
# Epoch 121/500
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0097 - categorical_accuracy: 1.0000 - val_loss: 10.3528 - val_categorical_accuracy: 0.0500
# Epoch 122/500
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0116 - categorical_accuracy: 1.0000 - val_loss: 8.5266 - val_categorical_accuracy: 0.1000
# Epoch 123/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0503 - categorical_accuracy: 0.9875 - val_loss: 8.7259 - val_categorical_accuracy: 0.0000e+00
# Epoch 124/500
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0363 - categorical_accuracy: 0.9875 - val_loss: 6.3344 - val_categorical_accuracy: 0.0500
# Epoch 125/500
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0115 - categorical_accuracy: 1.0000 - val_loss: 6.6105 - val_categorical_accuracy: 0.0500
# Epoch 126/500
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0094 - categorical_accuracy: 1.0000 - val_loss: 6.6218 - val_categorical_accuracy: 0.0500
# Epoch 127/500
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0092 - categorical_accuracy: 1.0000 - val_loss: 5.5520 - val_categorical_accuracy: 0.1000

# %% [markdown]
# ### EfficientNetB0

# %%
MHI_SHAPE = (224,224,3)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.EfficientNetB0(input_shape = MHI_SHAPE,
                                                include_top = False,
                                                weights = 'imagenet',
                                                pooling='max')
# Freeze the convolutional base
base_model.trainable = True

#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(keras.layers.Flatten())
model.add(Dense(256, activation="relu"))
model.add(keras.layers.BatchNormalization())
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, 
            run_name="C2_EfficientNetB0_no_transforms", 
            train_ds=train_dataset, 
            val_ds=val_dataset, 
            T_max=501, 
            epochs=1000,
            max_lr = 1e-4, 
            min_lr = 1e-5,
            dataset_name="calcMHI-augmentMHI_no_transforms", 
            filepath=os.path.join("models", "C2_EfficientNetB0_no_transforms.tf"), 
            USE_WANDB=CONFIG.USE_WANDB)
# Out:
# Finishing last run (ID:5xdn4tq7) before initializing another...
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>▁▃▁▅▆▄▇▅▆█▅▅▄█▅▆▇█▃</td></tr><tr><td>epoch/epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>█████▇▇▇▆▆▆▅▅▄▄▃▂▂▁</td></tr><tr><td>epoch/loss</td><td>█▇▅▅▅▅▃▄▃▃▃▃▄▁▄▁▂▂▄</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>▂▄▂▅█▂▄▄▅▄▅▂▅▄█▇▄▁▄</td></tr><tr><td>epoch/val_loss</td><td>▂▃▄▄▅▂▆█▇▄▅▆▄▂▂▁▄▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>0.1875</td></tr><tr><td>epoch/epoch</td><td>18</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>1.92845</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>0.15</td></tr><tr><td>epoch/val_loss</td><td>2.57362</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">C2_EfficientNetB0</strong> at: <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/5xdn4tq7' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/5xdn4tq7</a><br/> View project at: <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_202427-5xdn4tq7/logs</code>
# Successfully finished last run (ID:5xdn4tq7). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011114899276031388, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/workspace/wandb/run-20240415_202505-qeq7932w</code>
# Syncing run <strong><a href='https://wandb.ai/mlewand7/MHI-CNN/runs/qeq7932w' target="_blank">C2_EfficientNetB0</a></strong> to <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a>
#  View run at <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/qeq7932w' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/qeq7932w</a>
# Epoch 1/1000
#      19/Unknown - 1s 12ms/step - loss: 2.5541 - categorical_accuracy: 0.1447
# 2024-04-15 20:25:12.610324: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 3349952044877754649
# 2024-04-15 20:25:12.610375: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 14498149272523616542
# 2024-04-15 20:25:12.610405: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 14133121464649995126
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# 2024-04-15 20:25:12.840681: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 3349952044877754649
# 2024-04-15 20:25:12.840769: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 6630784775236842777
# 2024-04-15 20:25:12.840846: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 4556428208539362992
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# 20/20 [==============================] - 2s 76ms/step - loss: 2.5875 - categorical_accuracy: 0.1375 - val_loss: 2.3158 - val_categorical_accuracy: 0.0500
# Epoch 2/1000
# 19/20 [===========================>..] - ETA: 0s - loss: 2.0391 - categorical_accuracy: 0.1579INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# 20/20 [==============================] - 1s 64ms/step - loss: 2.0335 - categorical_accuracy: 0.1500 - val_loss: 2.0524 - val_categorical_accuracy: 0.3000
# Epoch 3/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 2.0073 - categorical_accuracy: 0.2375 - val_loss: 2.0798 - val_categorical_accuracy: 0.1000
# Epoch 4/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.8469 - categorical_accuracy: 0.3000 - val_loss: 2.2172 - val_categorical_accuracy: 0.0500
# Epoch 5/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.8352 - categorical_accuracy: 0.3250 - val_loss: 2.0751 - val_categorical_accuracy: 0.2000
# Epoch 6/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.7232 - categorical_accuracy: 0.2500 - val_loss: 2.2522 - val_categorical_accuracy: 0.1000
# Epoch 7/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.7331 - categorical_accuracy: 0.3625 - val_loss: 2.3925 - val_categorical_accuracy: 0.1500
# Epoch 8/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6562 - categorical_accuracy: 0.3875 - val_loss: 1.9868 - val_categorical_accuracy: 0.3000
# Epoch 9/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.5955 - categorical_accuracy: 0.4000 - val_loss: 2.4290 - val_categorical_accuracy: 0.2500
# Epoch 10/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 1.7477 - categorical_accuracy: 0.3625 - val_loss: 2.7094 - val_categorical_accuracy: 0.1000
# Epoch 11/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6261 - categorical_accuracy: 0.4000 - val_loss: 3.0150 - val_categorical_accuracy: 0.1500
# Epoch 12/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.6520 - categorical_accuracy: 0.4125 - val_loss: 3.5452 - val_categorical_accuracy: 0.2000
# Epoch 13/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.6303 - categorical_accuracy: 0.4250 - val_loss: 3.1868 - val_categorical_accuracy: 0.0500
# Epoch 14/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.6466 - categorical_accuracy: 0.3875 - val_loss: 2.6969 - val_categorical_accuracy: 0.1000
# Epoch 15/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6303 - categorical_accuracy: 0.3625 - val_loss: 2.9540 - val_categorical_accuracy: 0.1000
# Epoch 16/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6910 - categorical_accuracy: 0.3500 - val_loss: 3.0008 - val_categorical_accuracy: 0.1000
# Epoch 17/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6404 - categorical_accuracy: 0.3375 - val_loss: 2.7738 - val_categorical_accuracy: 0.1000
# Epoch 18/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.6702 - categorical_accuracy: 0.4000 - val_loss: 2.1081 - val_categorical_accuracy: 0.2000
# Epoch 19/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.5797 - categorical_accuracy: 0.4625 - val_loss: 1.9757 - val_categorical_accuracy: 0.2500
# Epoch 20/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4900 - categorical_accuracy: 0.4375 - val_loss: 2.5085 - val_categorical_accuracy: 0.1000
# Epoch 21/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.6084 - categorical_accuracy: 0.3750 - val_loss: 2.5979 - val_categorical_accuracy: 0.0000e+00
# Epoch 22/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4934 - categorical_accuracy: 0.3750 - val_loss: 2.4951 - val_categorical_accuracy: 0.1000
# Epoch 23/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.6220 - categorical_accuracy: 0.3375 - val_loss: 2.8696 - val_categorical_accuracy: 0.0500
# Epoch 24/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.6025 - categorical_accuracy: 0.3875 - val_loss: 2.2879 - val_categorical_accuracy: 0.2000
# Epoch 25/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.5309 - categorical_accuracy: 0.4625 - val_loss: 2.6556 - val_categorical_accuracy: 0.1000
# Epoch 26/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 1.5899 - categorical_accuracy: 0.4250 - val_loss: 2.1519 - val_categorical_accuracy: 0.1500
# Epoch 27/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4353 - categorical_accuracy: 0.4625 - val_loss: 2.2006 - val_categorical_accuracy: 0.2500
# Epoch 28/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4867 - categorical_accuracy: 0.4500 - val_loss: 2.3287 - val_categorical_accuracy: 0.2500
# Epoch 29/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5093 - categorical_accuracy: 0.4750 - val_loss: 2.2671 - val_categorical_accuracy: 0.1500
# Epoch 30/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4831 - categorical_accuracy: 0.4250 - val_loss: 2.5978 - val_categorical_accuracy: 0.1000
# Epoch 31/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5577 - categorical_accuracy: 0.5125 - val_loss: 2.4565 - val_categorical_accuracy: 0.1000
# Epoch 32/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5660 - categorical_accuracy: 0.3750 - val_loss: 2.4234 - val_categorical_accuracy: 0.1000
# Epoch 33/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.6950 - categorical_accuracy: 0.2625 - val_loss: 2.5136 - val_categorical_accuracy: 0.1000
# Epoch 34/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.5942 - categorical_accuracy: 0.4125 - val_loss: 2.5102 - val_categorical_accuracy: 0.1500
# Epoch 35/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5445 - categorical_accuracy: 0.4500 - val_loss: 2.6122 - val_categorical_accuracy: 0.1500
# Epoch 36/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.5564 - categorical_accuracy: 0.3750 - val_loss: 2.5932 - val_categorical_accuracy: 0.1000
# Epoch 37/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4479 - categorical_accuracy: 0.4500 - val_loss: 2.4070 - val_categorical_accuracy: 0.1500
# Epoch 38/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3219 - categorical_accuracy: 0.5625 - val_loss: 2.3497 - val_categorical_accuracy: 0.2500
# Epoch 39/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.5896 - categorical_accuracy: 0.3625 - val_loss: 1.9963 - val_categorical_accuracy: 0.2500
# Epoch 40/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5045 - categorical_accuracy: 0.5250 - val_loss: 2.0380 - val_categorical_accuracy: 0.1500
# Epoch 41/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5160 - categorical_accuracy: 0.4000 - val_loss: 2.1948 - val_categorical_accuracy: 0.1500
# Epoch 42/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3654 - categorical_accuracy: 0.5250 - val_loss: 2.5356 - val_categorical_accuracy: 0.1500
# Epoch 43/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.5802 - categorical_accuracy: 0.4125 - val_loss: 2.0439 - val_categorical_accuracy: 0.0500
# Epoch 44/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3926 - categorical_accuracy: 0.5125 - val_loss: 2.2417 - val_categorical_accuracy: 0.2500
# Epoch 45/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.5310 - categorical_accuracy: 0.4625 - val_loss: 2.3913 - val_categorical_accuracy: 0.1000
# Epoch 46/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4794 - categorical_accuracy: 0.4625 - val_loss: 2.4402 - val_categorical_accuracy: 0.1000
# Epoch 47/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4227 - categorical_accuracy: 0.4875 - val_loss: 2.1504 - val_categorical_accuracy: 0.2500
# Epoch 48/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.4102 - categorical_accuracy: 0.5000 - val_loss: 2.0511 - val_categorical_accuracy: 0.2000
# Epoch 49/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.4548 - categorical_accuracy: 0.4750 - val_loss: 2.1814 - val_categorical_accuracy: 0.1000
# Epoch 50/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.5092 - categorical_accuracy: 0.4500 - val_loss: 2.3921 - val_categorical_accuracy: 0.0000e+00
# Epoch 51/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.5033 - categorical_accuracy: 0.4625 - val_loss: 2.3265 - val_categorical_accuracy: 0.0500
# Epoch 52/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4771 - categorical_accuracy: 0.5000 - val_loss: 2.3965 - val_categorical_accuracy: 0.0000e+00
# Epoch 53/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4435 - categorical_accuracy: 0.4875 - val_loss: 2.5386 - val_categorical_accuracy: 0.2500
# Epoch 54/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5975 - categorical_accuracy: 0.4375 - val_loss: 2.5931 - val_categorical_accuracy: 0.1000
# Epoch 55/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3650 - categorical_accuracy: 0.5250 - val_loss: 2.7791 - val_categorical_accuracy: 0.1000
# Epoch 56/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3948 - categorical_accuracy: 0.4375 - val_loss: 2.3333 - val_categorical_accuracy: 0.1000
# Epoch 57/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4705 - categorical_accuracy: 0.4750 - val_loss: 2.3320 - val_categorical_accuracy: 0.1000
# Epoch 58/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4284 - categorical_accuracy: 0.4625 - val_loss: 2.3518 - val_categorical_accuracy: 0.1000
# Epoch 59/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3756 - categorical_accuracy: 0.4875 - val_loss: 2.3822 - val_categorical_accuracy: 0.1000
# Epoch 60/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5049 - categorical_accuracy: 0.4875 - val_loss: 2.3631 - val_categorical_accuracy: 0.2500
# Epoch 61/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4343 - categorical_accuracy: 0.5375 - val_loss: 2.3264 - val_categorical_accuracy: 0.0500
# Epoch 62/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4923 - categorical_accuracy: 0.4500 - val_loss: 2.1820 - val_categorical_accuracy: 0.1000
# Epoch 63/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4984 - categorical_accuracy: 0.4875 - val_loss: 2.4311 - val_categorical_accuracy: 0.0500
# Epoch 64/1000
# 20/20 [==============================] - ETA: 0s - loss: 1.4061 - categorical_accuracy: 0.5125INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(150528, 256), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe258581790>, 140610031114224), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c588790>, 140610031311072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe26c368ad0>, 140610035535184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6c4390>, 140610035539696), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(256, 7), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6e7450>, 140610031314672), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe23c6b7ad0>, 140610030804768), {}).
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# INFO:tensorflow:Assets written to: models/C2_EfficientNetB0.tf/assets
# 20/20 [==============================] - 1s 66ms/step - loss: 1.4061 - categorical_accuracy: 0.5125 - val_loss: 1.9711 - val_categorical_accuracy: 0.3500
# Epoch 65/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.5720 - categorical_accuracy: 0.4500 - val_loss: 2.4768 - val_categorical_accuracy: 0.0500
# Epoch 66/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3005 - categorical_accuracy: 0.5375 - val_loss: 2.0595 - val_categorical_accuracy: 0.0500
# Epoch 67/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3653 - categorical_accuracy: 0.5250 - val_loss: 2.3544 - val_categorical_accuracy: 0.1000
# Epoch 68/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4216 - categorical_accuracy: 0.5125 - val_loss: 2.3392 - val_categorical_accuracy: 0.1000
# Epoch 69/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3836 - categorical_accuracy: 0.5250 - val_loss: 2.1411 - val_categorical_accuracy: 0.1500
# Epoch 70/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.5183 - categorical_accuracy: 0.5125 - val_loss: 2.2569 - val_categorical_accuracy: 0.1000
# Epoch 71/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4801 - categorical_accuracy: 0.5625 - val_loss: 2.5297 - val_categorical_accuracy: 0.1500
# Epoch 72/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.5330 - categorical_accuracy: 0.4750 - val_loss: 2.5676 - val_categorical_accuracy: 0.2000
# Epoch 73/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3938 - categorical_accuracy: 0.5125 - val_loss: 2.2728 - val_categorical_accuracy: 0.2000
# Epoch 74/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3824 - categorical_accuracy: 0.5125 - val_loss: 2.2113 - val_categorical_accuracy: 0.0500
# Epoch 75/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4842 - categorical_accuracy: 0.4125 - val_loss: 2.0611 - val_categorical_accuracy: 0.2000
# Epoch 76/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3363 - categorical_accuracy: 0.4625 - val_loss: 2.3566 - val_categorical_accuracy: 0.0500
# Epoch 77/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.5032 - categorical_accuracy: 0.4375 - val_loss: 2.3647 - val_categorical_accuracy: 0.1500
# Epoch 78/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4637 - categorical_accuracy: 0.4375 - val_loss: 2.4429 - val_categorical_accuracy: 0.1000
# Epoch 79/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4878 - categorical_accuracy: 0.4375 - val_loss: 2.2254 - val_categorical_accuracy: 0.1500
# Epoch 80/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3359 - categorical_accuracy: 0.4750 - val_loss: 2.8957 - val_categorical_accuracy: 0.0500
# Epoch 81/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 1.3790 - categorical_accuracy: 0.4875 - val_loss: 2.3335 - val_categorical_accuracy: 0.0500
# Epoch 82/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4036 - categorical_accuracy: 0.5250 - val_loss: 2.4093 - val_categorical_accuracy: 0.2000
# Epoch 83/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4489 - categorical_accuracy: 0.5250 - val_loss: 2.2492 - val_categorical_accuracy: 0.2000
# Epoch 84/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 1.4461 - categorical_accuracy: 0.5375 - val_loss: 2.2074 - val_categorical_accuracy: 0.0500
# Epoch 85/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3630 - categorical_accuracy: 0.5000 - val_loss: 2.4649 - val_categorical_accuracy: 0.2000
# Epoch 86/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4249 - categorical_accuracy: 0.4750 - val_loss: 2.2547 - val_categorical_accuracy: 0.2500
# Epoch 87/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4854 - categorical_accuracy: 0.4500 - val_loss: 2.4749 - val_categorical_accuracy: 0.1500
# Epoch 88/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4310 - categorical_accuracy: 0.5250 - val_loss: 2.3379 - val_categorical_accuracy: 0.1500
# Epoch 89/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3852 - categorical_accuracy: 0.5625 - val_loss: 2.4607 - val_categorical_accuracy: 0.1000
# Epoch 90/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4133 - categorical_accuracy: 0.4625 - val_loss: 2.6228 - val_categorical_accuracy: 0.0500
# Epoch 91/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3396 - categorical_accuracy: 0.5375 - val_loss: 2.5806 - val_categorical_accuracy: 0.2000
# Epoch 92/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3921 - categorical_accuracy: 0.5125 - val_loss: 2.5434 - val_categorical_accuracy: 0.1000
# Epoch 93/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3889 - categorical_accuracy: 0.5000 - val_loss: 2.4133 - val_categorical_accuracy: 0.0500
# Epoch 94/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.2629 - categorical_accuracy: 0.5625 - val_loss: 2.6389 - val_categorical_accuracy: 0.0500
# Epoch 95/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4357 - categorical_accuracy: 0.4750 - val_loss: 2.6641 - val_categorical_accuracy: 0.0500
# Epoch 96/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4735 - categorical_accuracy: 0.4625 - val_loss: 2.7030 - val_categorical_accuracy: 0.1000
# Epoch 97/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3019 - categorical_accuracy: 0.5875 - val_loss: 2.3871 - val_categorical_accuracy: 0.1500
# Epoch 98/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4428 - categorical_accuracy: 0.4500 - val_loss: 2.2405 - val_categorical_accuracy: 0.1000
# Epoch 99/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3659 - categorical_accuracy: 0.4750 - val_loss: 2.2616 - val_categorical_accuracy: 0.0500
# Epoch 100/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3025 - categorical_accuracy: 0.5625 - val_loss: 2.3584 - val_categorical_accuracy: 0.2000
# Epoch 101/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4312 - categorical_accuracy: 0.5625 - val_loss: 2.3845 - val_categorical_accuracy: 0.2000
# Epoch 102/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3985 - categorical_accuracy: 0.5500 - val_loss: 2.4844 - val_categorical_accuracy: 0.1000
# Epoch 103/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4125 - categorical_accuracy: 0.5125 - val_loss: 2.5504 - val_categorical_accuracy: 0.1000
# Epoch 104/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4095 - categorical_accuracy: 0.4750 - val_loss: 2.4444 - val_categorical_accuracy: 0.1000
# Epoch 105/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4013 - categorical_accuracy: 0.4750 - val_loss: 2.5579 - val_categorical_accuracy: 0.2000
# Epoch 106/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.2569 - categorical_accuracy: 0.5375 - val_loss: 2.5764 - val_categorical_accuracy: 0.2000
# Epoch 107/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4502 - categorical_accuracy: 0.4625 - val_loss: 2.5147 - val_categorical_accuracy: 0.1500
# Epoch 108/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.2699 - categorical_accuracy: 0.5500 - val_loss: 2.1270 - val_categorical_accuracy: 0.1500
# Epoch 109/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4769 - categorical_accuracy: 0.4375 - val_loss: 2.2569 - val_categorical_accuracy: 0.1000
# Epoch 110/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3371 - categorical_accuracy: 0.5875 - val_loss: 2.1343 - val_categorical_accuracy: 0.1000
# Epoch 111/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4054 - categorical_accuracy: 0.5125 - val_loss: 2.2314 - val_categorical_accuracy: 0.2000
# Epoch 112/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4400 - categorical_accuracy: 0.4500 - val_loss: 1.9640 - val_categorical_accuracy: 0.2000
# Epoch 113/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3637 - categorical_accuracy: 0.5375 - val_loss: 1.8775 - val_categorical_accuracy: 0.3500
# Epoch 114/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.5750 - categorical_accuracy: 0.4500 - val_loss: 2.3711 - val_categorical_accuracy: 0.0500
# Epoch 115/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3212 - categorical_accuracy: 0.5125 - val_loss: 2.3377 - val_categorical_accuracy: 0.0500
# Epoch 116/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.2830 - categorical_accuracy: 0.5500 - val_loss: 2.2361 - val_categorical_accuracy: 0.3500
# Epoch 117/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3823 - categorical_accuracy: 0.5625 - val_loss: 2.3195 - val_categorical_accuracy: 0.2000
# Epoch 118/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3207 - categorical_accuracy: 0.5875 - val_loss: 1.9678 - val_categorical_accuracy: 0.3000
# Epoch 119/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3897 - categorical_accuracy: 0.4875 - val_loss: 2.3423 - val_categorical_accuracy: 0.2500
# Epoch 120/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3606 - categorical_accuracy: 0.5250 - val_loss: 2.5160 - val_categorical_accuracy: 0.1500
# Epoch 121/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4403 - categorical_accuracy: 0.4625 - val_loss: 2.5722 - val_categorical_accuracy: 0.1000
# Epoch 122/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.2905 - categorical_accuracy: 0.5625 - val_loss: 2.5782 - val_categorical_accuracy: 0.1000
# Epoch 123/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4145 - categorical_accuracy: 0.5000 - val_loss: 2.2910 - val_categorical_accuracy: 0.1500
# Epoch 124/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3388 - categorical_accuracy: 0.5625 - val_loss: 2.5620 - val_categorical_accuracy: 0.1000
# Epoch 125/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.4802 - categorical_accuracy: 0.4625 - val_loss: 2.1089 - val_categorical_accuracy: 0.1500
# Epoch 126/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1595 - categorical_accuracy: 0.5750 - val_loss: 2.0470 - val_categorical_accuracy: 0.1000
# Epoch 127/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3121 - categorical_accuracy: 0.5375 - val_loss: 2.1349 - val_categorical_accuracy: 0.2500
# Epoch 128/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2981 - categorical_accuracy: 0.5875 - val_loss: 1.7496 - val_categorical_accuracy: 0.2000
# Epoch 129/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4380 - categorical_accuracy: 0.4750 - val_loss: 2.3220 - val_categorical_accuracy: 0.1500
# Epoch 130/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.4262 - categorical_accuracy: 0.5125 - val_loss: 2.2664 - val_categorical_accuracy: 0.1500
# Epoch 131/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3336 - categorical_accuracy: 0.5875 - val_loss: 1.8643 - val_categorical_accuracy: 0.1500
# Epoch 132/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.3368 - categorical_accuracy: 0.5625 - val_loss: 2.4847 - val_categorical_accuracy: 0.1000
# Epoch 133/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3905 - categorical_accuracy: 0.4875 - val_loss: 2.2154 - val_categorical_accuracy: 0.2000
# Epoch 134/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4227 - categorical_accuracy: 0.5250 - val_loss: 2.4606 - val_categorical_accuracy: 0.1500
# Epoch 135/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2428 - categorical_accuracy: 0.5875 - val_loss: 2.3305 - val_categorical_accuracy: 0.0500
# Epoch 136/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3901 - categorical_accuracy: 0.4750 - val_loss: 2.2485 - val_categorical_accuracy: 0.1000
# Epoch 137/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4755 - categorical_accuracy: 0.5125 - val_loss: 2.0954 - val_categorical_accuracy: 0.1500
# Epoch 138/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.3317 - categorical_accuracy: 0.5500 - val_loss: 2.3217 - val_categorical_accuracy: 0.1500
# Epoch 139/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3920 - categorical_accuracy: 0.4625 - val_loss: 2.2492 - val_categorical_accuracy: 0.2000
# Epoch 140/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4382 - categorical_accuracy: 0.5375 - val_loss: 2.3151 - val_categorical_accuracy: 0.2000
# Epoch 141/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.4452 - categorical_accuracy: 0.4875 - val_loss: 2.5362 - val_categorical_accuracy: 0.0500
# Epoch 142/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3445 - categorical_accuracy: 0.5250 - val_loss: 2.5063 - val_categorical_accuracy: 0.2000
# Epoch 143/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3367 - categorical_accuracy: 0.5375 - val_loss: 2.4531 - val_categorical_accuracy: 0.1500
# Epoch 144/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 1.3618 - categorical_accuracy: 0.5625 - val_loss: 2.6449 - val_categorical_accuracy: 0.1000
# Epoch 145/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3797 - categorical_accuracy: 0.5125 - val_loss: 2.4214 - val_categorical_accuracy: 0.1500
# Epoch 146/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3932 - categorical_accuracy: 0.4625 - val_loss: 2.6529 - val_categorical_accuracy: 0.0500
# Epoch 147/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3241 - categorical_accuracy: 0.4750 - val_loss: 2.1421 - val_categorical_accuracy: 0.1500
# Epoch 148/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3227 - categorical_accuracy: 0.4875 - val_loss: 2.0779 - val_categorical_accuracy: 0.1500
# Epoch 149/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3822 - categorical_accuracy: 0.4875 - val_loss: 2.3736 - val_categorical_accuracy: 0.1000
# Epoch 150/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.2715 - categorical_accuracy: 0.6125 - val_loss: 2.1935 - val_categorical_accuracy: 0.2500
# Epoch 151/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.3455 - categorical_accuracy: 0.5250 - val_loss: 2.2967 - val_categorical_accuracy: 0.0500
# Epoch 152/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.4762 - categorical_accuracy: 0.4750 - val_loss: 1.9781 - val_categorical_accuracy: 0.2500
# Epoch 153/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.2369 - categorical_accuracy: 0.5875 - val_loss: 2.3826 - val_categorical_accuracy: 0.0500
# Epoch 154/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2355 - categorical_accuracy: 0.6000 - val_loss: 2.4143 - val_categorical_accuracy: 0.1500
# Epoch 155/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.3651 - categorical_accuracy: 0.5750 - val_loss: 2.5040 - val_categorical_accuracy: 0.1500
# Epoch 156/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 1.3108 - categorical_accuracy: 0.5750 - val_loss: 1.8693 - val_categorical_accuracy: 0.2000
# Epoch 157/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2682 - categorical_accuracy: 0.5750 - val_loss: 2.3158 - val_categorical_accuracy: 0.2000
# Epoch 158/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.2608 - categorical_accuracy: 0.5875 - val_loss: 2.5526 - val_categorical_accuracy: 0.1500
# Epoch 159/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3608 - categorical_accuracy: 0.5625 - val_loss: 1.9865 - val_categorical_accuracy: 0.1000
# Epoch 160/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.3853 - categorical_accuracy: 0.5625 - val_loss: 2.2114 - val_categorical_accuracy: 0.1500
# Epoch 161/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.3188 - categorical_accuracy: 0.6125 - val_loss: 2.1038 - val_categorical_accuracy: 0.2000
# Epoch 162/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.4185 - categorical_accuracy: 0.4750 - val_loss: 2.5222 - val_categorical_accuracy: 0.1500
# Epoch 163/1000
# ...
# Epoch 918/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1793 - categorical_accuracy: 0.5875 - val_loss: 2.4561 - val_categorical_accuracy: 0.2000
# Epoch 919/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.1539 - categorical_accuracy: 0.5625 - val_loss: 2.8339 - val_categorical_accuracy: 0.0500
# Epoch 920/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0836 - categorical_accuracy: 0.7000 - val_loss: 2.7723 - val_categorical_accuracy: 0.1000
# Epoch 921/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9885 - categorical_accuracy: 0.7000 - val_loss: 2.3661 - val_categorical_accuracy: 0.1000
# Epoch 922/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9398 - categorical_accuracy: 0.7375 - val_loss: 2.5953 - val_categorical_accuracy: 0.1000
# Epoch 923/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0979 - categorical_accuracy: 0.6000 - val_loss: 2.3230 - val_categorical_accuracy: 0.2000
# Epoch 924/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.2981 - categorical_accuracy: 0.5250 - val_loss: 2.7992 - val_categorical_accuracy: 0.1000
# Epoch 925/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0126 - categorical_accuracy: 0.6875 - val_loss: 2.4169 - val_categorical_accuracy: 0.1500
# Epoch 926/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9560 - categorical_accuracy: 0.7375 - val_loss: 2.7675 - val_categorical_accuracy: 0.1500
# Epoch 927/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0074 - categorical_accuracy: 0.6750 - val_loss: 2.3305 - val_categorical_accuracy: 0.0500
# Epoch 928/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9860 - categorical_accuracy: 0.7000 - val_loss: 2.7279 - val_categorical_accuracy: 0.1000
# Epoch 929/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.0712 - categorical_accuracy: 0.6375 - val_loss: 2.4988 - val_categorical_accuracy: 0.1500
# Epoch 930/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0521 - categorical_accuracy: 0.6375 - val_loss: 2.1097 - val_categorical_accuracy: 0.1000
# Epoch 931/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0320 - categorical_accuracy: 0.6500 - val_loss: 2.6906 - val_categorical_accuracy: 0.1500
# Epoch 932/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.1349 - categorical_accuracy: 0.5750 - val_loss: 2.6780 - val_categorical_accuracy: 0.1000
# Epoch 933/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0635 - categorical_accuracy: 0.6500 - val_loss: 2.7755 - val_categorical_accuracy: 0.1500
# Epoch 934/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0301 - categorical_accuracy: 0.6750 - val_loss: 2.6279 - val_categorical_accuracy: 0.1000
# Epoch 935/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.8974 - categorical_accuracy: 0.6750 - val_loss: 2.8335 - val_categorical_accuracy: 0.1000
# Epoch 936/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.8961 - categorical_accuracy: 0.7750 - val_loss: 2.9544 - val_categorical_accuracy: 0.1000
# Epoch 937/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0503 - categorical_accuracy: 0.6875 - val_loss: 2.5516 - val_categorical_accuracy: 0.1500
# Epoch 938/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.1145 - categorical_accuracy: 0.6375 - val_loss: 3.0027 - val_categorical_accuracy: 0.0500
# Epoch 939/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0591 - categorical_accuracy: 0.6500 - val_loss: 3.0029 - val_categorical_accuracy: 0.0000e+00
# Epoch 940/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9195 - categorical_accuracy: 0.7750 - val_loss: 2.6948 - val_categorical_accuracy: 0.1500
# Epoch 941/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9203 - categorical_accuracy: 0.7375 - val_loss: 2.3180 - val_categorical_accuracy: 0.1000
# Epoch 942/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9696 - categorical_accuracy: 0.6000 - val_loss: 2.2978 - val_categorical_accuracy: 0.1000
# Epoch 943/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9721 - categorical_accuracy: 0.6375 - val_loss: 2.4927 - val_categorical_accuracy: 0.0500
# Epoch 944/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9881 - categorical_accuracy: 0.6875 - val_loss: 2.6119 - val_categorical_accuracy: 0.0500
# Epoch 945/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0044 - categorical_accuracy: 0.6500 - val_loss: 2.7286 - val_categorical_accuracy: 0.0500
# Epoch 946/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0366 - categorical_accuracy: 0.6250 - val_loss: 2.5512 - val_categorical_accuracy: 0.1500
# Epoch 947/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0163 - categorical_accuracy: 0.6750 - val_loss: 2.5566 - val_categorical_accuracy: 0.1000
# Epoch 948/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.2514 - categorical_accuracy: 0.5250 - val_loss: 3.0729 - val_categorical_accuracy: 0.1500
# Epoch 949/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0287 - categorical_accuracy: 0.6875 - val_loss: 2.6575 - val_categorical_accuracy: 0.1000
# Epoch 950/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9347 - categorical_accuracy: 0.6750 - val_loss: 2.4995 - val_categorical_accuracy: 0.0000e+00
# Epoch 951/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0903 - categorical_accuracy: 0.6625 - val_loss: 2.5775 - val_categorical_accuracy: 0.1000
# Epoch 952/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0829 - categorical_accuracy: 0.6500 - val_loss: 2.5716 - val_categorical_accuracy: 0.1500
# Epoch 953/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9766 - categorical_accuracy: 0.6500 - val_loss: 2.4928 - val_categorical_accuracy: 0.1500
# Epoch 954/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1404 - categorical_accuracy: 0.6125 - val_loss: 2.7982 - val_categorical_accuracy: 0.1500
# Epoch 955/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8576 - categorical_accuracy: 0.7500 - val_loss: 2.7638 - val_categorical_accuracy: 0.0000e+00
# Epoch 956/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9283 - categorical_accuracy: 0.7375 - val_loss: 2.1506 - val_categorical_accuracy: 0.3000
# Epoch 957/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.1313 - categorical_accuracy: 0.6625 - val_loss: 2.3204 - val_categorical_accuracy: 0.1000
# Epoch 958/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.8840 - categorical_accuracy: 0.6750 - val_loss: 2.2319 - val_categorical_accuracy: 0.1500
# Epoch 959/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9694 - categorical_accuracy: 0.6625 - val_loss: 2.4450 - val_categorical_accuracy: 0.1000
# Epoch 960/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8541 - categorical_accuracy: 0.7500 - val_loss: 2.7991 - val_categorical_accuracy: 0.0500
# Epoch 961/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0016 - categorical_accuracy: 0.7000 - val_loss: 2.3677 - val_categorical_accuracy: 0.2000
# Epoch 962/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.8813 - categorical_accuracy: 0.7625 - val_loss: 2.9765 - val_categorical_accuracy: 0.2000
# Epoch 963/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8331 - categorical_accuracy: 0.7750 - val_loss: 2.5170 - val_categorical_accuracy: 0.1500
# Epoch 964/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.1417 - categorical_accuracy: 0.6125 - val_loss: 2.3710 - val_categorical_accuracy: 0.1500
# Epoch 965/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9958 - categorical_accuracy: 0.6500 - val_loss: 2.3739 - val_categorical_accuracy: 0.1000
# Epoch 966/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9429 - categorical_accuracy: 0.7000 - val_loss: 2.5759 - val_categorical_accuracy: 0.2000
# Epoch 967/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0527 - categorical_accuracy: 0.7000 - val_loss: 2.4618 - val_categorical_accuracy: 0.1500
# Epoch 968/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.2101 - categorical_accuracy: 0.6125 - val_loss: 2.9587 - val_categorical_accuracy: 0.0500
# Epoch 969/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.8956 - categorical_accuracy: 0.7375 - val_loss: 2.5024 - val_categorical_accuracy: 0.1500
# Epoch 970/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 1.0263 - categorical_accuracy: 0.6625 - val_loss: 2.7299 - val_categorical_accuracy: 0.1000
# Epoch 971/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9379 - categorical_accuracy: 0.7250 - val_loss: 2.3373 - val_categorical_accuracy: 0.2000
# Epoch 972/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9388 - categorical_accuracy: 0.7000 - val_loss: 2.5515 - val_categorical_accuracy: 0.2000
# Epoch 973/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0469 - categorical_accuracy: 0.6625 - val_loss: 2.7901 - val_categorical_accuracy: 0.0500
# Epoch 974/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 1.0202 - categorical_accuracy: 0.6875 - val_loss: 2.7805 - val_categorical_accuracy: 0.2000
# Epoch 975/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9617 - categorical_accuracy: 0.6750 - val_loss: 2.5247 - val_categorical_accuracy: 0.1000
# Epoch 976/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9925 - categorical_accuracy: 0.6250 - val_loss: 2.5682 - val_categorical_accuracy: 0.1500
# Epoch 977/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9494 - categorical_accuracy: 0.6250 - val_loss: 2.1947 - val_categorical_accuracy: 0.1000
# Epoch 978/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9710 - categorical_accuracy: 0.6750 - val_loss: 2.5906 - val_categorical_accuracy: 0.2000
# Epoch 979/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9101 - categorical_accuracy: 0.8000 - val_loss: 2.4261 - val_categorical_accuracy: 0.1500
# Epoch 980/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9607 - categorical_accuracy: 0.7000 - val_loss: 2.5166 - val_categorical_accuracy: 0.0500
# Epoch 981/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0345 - categorical_accuracy: 0.6125 - val_loss: 2.6443 - val_categorical_accuracy: 0.1000
# Epoch 982/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9519 - categorical_accuracy: 0.7125 - val_loss: 2.6177 - val_categorical_accuracy: 0.1000
# Epoch 983/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.1320 - categorical_accuracy: 0.5500 - val_loss: 2.4705 - val_categorical_accuracy: 0.1500
# Epoch 984/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0067 - categorical_accuracy: 0.7125 - val_loss: 2.4600 - val_categorical_accuracy: 0.1000
# Epoch 985/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.8861 - categorical_accuracy: 0.7250 - val_loss: 2.4229 - val_categorical_accuracy: 0.2000
# Epoch 986/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.8844 - categorical_accuracy: 0.7250 - val_loss: 2.8203 - val_categorical_accuracy: 0.1000
# Epoch 987/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9702 - categorical_accuracy: 0.6875 - val_loss: 2.4029 - val_categorical_accuracy: 0.1500
# Epoch 988/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0598 - categorical_accuracy: 0.6500 - val_loss: 2.4512 - val_categorical_accuracy: 0.2000
# Epoch 989/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9993 - categorical_accuracy: 0.8000 - val_loss: 2.4154 - val_categorical_accuracy: 0.1500
# Epoch 990/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.1513 - categorical_accuracy: 0.6125 - val_loss: 2.0106 - val_categorical_accuracy: 0.3000
# Epoch 991/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 0.9413 - categorical_accuracy: 0.7125 - val_loss: 2.1595 - val_categorical_accuracy: 0.2000
# Epoch 992/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0775 - categorical_accuracy: 0.6250 - val_loss: 2.7884 - val_categorical_accuracy: 0.1500
# Epoch 993/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.0423 - categorical_accuracy: 0.6500 - val_loss: 2.5194 - val_categorical_accuracy: 0.1500
# Epoch 994/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 0.8579 - categorical_accuracy: 0.7250 - val_loss: 2.4968 - val_categorical_accuracy: 0.1500
# Epoch 995/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0892 - categorical_accuracy: 0.6125 - val_loss: 2.4485 - val_categorical_accuracy: 0.1000
# Epoch 996/1000
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1251 - categorical_accuracy: 0.6125 - val_loss: 2.6697 - val_categorical_accuracy: 0.1500
# Epoch 997/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.7552 - categorical_accuracy: 0.8000 - val_loss: 2.4565 - val_categorical_accuracy: 0.2000
# Epoch 998/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 1.1511 - categorical_accuracy: 0.6000 - val_loss: 2.5573 - val_categorical_accuracy: 0.1000
# Epoch 999/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 0.9796 - categorical_accuracy: 0.7000 - val_loss: 2.8769 - val_categorical_accuracy: 0.1000
# Epoch 1000/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 1.2134 - categorical_accuracy: 0.6125 - val_loss: 2.4550 - val_categorical_accuracy: 0.1500
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>▁▁▂▃▃▅▄▃▃▃▅▅▅▇▆▇▆▆▆▆▆▅▃▇▅▅▆▆▆▇█▆▆▇█▇▇▇▅▆</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>████▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁███▇▇▇▆▆▅▅▄▄▃▃▂▂▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▇▅▅▆▄▅▅▅▅▃▄▄▂▃▂▃▂▂▃▃▅▅▂▃▂▃▂▃▂▂▂▁▁▁▂▂▁▄▂</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>▆▃▃▂▃▅▄▃▄▃▂▄▂▃▃▅▂▅▃▄▄▃▂▁▂▄▅█▇▂▃▅▄▃▅▄▃▂▂▄</td></tr><tr><td>epoch/val_loss</td><td>▂▅▄▇▅▁▄▆▃▃▅▂▄▅▅▅▅▄▅▅▆▇▆▆▄▅▃▄▃▆▆▄▅█▅▆▇▆█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/categorical_accuracy</td><td>0.6125</td></tr><tr><td>epoch/epoch</td><td>999</td></tr><tr><td>epoch/learning_rate</td><td>1e-05</td></tr><tr><td>epoch/loss</td><td>1.21336</td></tr><tr><td>epoch/val_categorical_accuracy</td><td>0.15</td></tr><tr><td>epoch/val_loss</td><td>2.45497</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">C2_EfficientNetB0</strong> at: <a href='https://wandb.ai/mlewand7/MHI-CNN/runs/qeq7932w' target="_blank">https://wandb.ai/mlewand7/MHI-CNN/runs/qeq7932w</a><br/> View project at: <a href='https://wandb.ai/mlewand7/MHI-CNN' target="_blank">https://wandb.ai/mlewand7/MHI-CNN</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_202505-qeq7932w/logs</code>
