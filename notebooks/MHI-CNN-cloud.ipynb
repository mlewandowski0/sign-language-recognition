# %%
# !pip install opencv-python numpy tensorflow scikit-learn matplotlib wandb tdqm wurlitzer
# Out:
# Requirement already satisfied: opencv-python in d:\anaconda\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (2.14.0)
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (1.3.0)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (3.7.2)
# Requirement already satisfied: wandb in d:\anaconda\lib\site-packages (0.16.5)
# Requirement already satisfied: tdqm in d:\anaconda\lib\site-packages (0.0.1)
# Requirement already satisfied: wurlitzer in d:\anaconda\lib\site-packages (3.0.3)
# Requirement already satisfied: tensorflow-intel==2.14.0 in d:\anaconda\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: scipy>=1.5.0 in d:\anaconda\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in d:\anaconda\lib\site-packages (from wandb) (8.0.4)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in d:\anaconda\lib\site-packages (from wandb) (3.1.42)
# Requirement already satisfied: requests<3,>=2.0.0 in d:\anaconda\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in d:\anaconda\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in d:\anaconda\lib\site-packages (from wandb) (1.43.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in d:\anaconda\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in d:\anaconda\lib\site-packages (from wandb) (6.0)
# Requirement already satisfied: setproctitle in d:\anaconda\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in d:\anaconda\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from tdqm) (4.65.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.0.0->wandb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
#all the required dependencies of the project
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import random
import wandb

from typing import Tuple
from collections import Counter
import albumentations as A
from tqdm import tqdm
from typing import List
import json
import tensorflow.keras as keras 
import tensorflow as tf

# %%
class CONFIG:
    ROOT_DIRECTORY = os.path.join("..", "data", "WLASL")
    JSON_FILE = "WLASL_v0.3.json"
    NSLT_FILE = "nslt_100.json"
    VIDEO_FOLDER = "videos"

    mean=[0.485, 0.456, 0.406]
    std=[0.229, 0.224, 0.225]
    DEBUG = True
    
    P_OF_TRANSFORM = 0.9
    P_OF_TRANSFORM_COLOR = 0.2
    
    SHIFT_LIMIT=0.1
    SCALE_LIMIT=0.1
    ROTATE_LIMIT=10
    
    # set to small, when prototyping, or 0 when deploying to cloud or PC with loads of RAM
    DATA_LIMIT = 100
    FRAME_SIZE = 20
    
    
    BATCH_SIZE = 4
    PORTION_OF_DATA_FOR_TRAINING = 0.8

    ROUND_DIGIT = 3
    #WANDB_RUN = "mediapipe-asl-dataset"

# %%
from sklearn.model_selection import train_test_split
from math import ceil

class SignRecognitionDataset(keras.utils.Sequence):

    def __init__(self, max_start : int, max_end) -> None:
        # setup the paths
        video_path = os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.VIDEO_FOLDER)
        dataset_description = os.path.join(CONFIG.ROOT_DIRECTORY)

        # load the filepaths for videos
        self.video_paths = [os.path.join(video_path, file) for file in os.listdir(video_path)]

        # load the dataset config json
        self.config_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.JSON_FILE)) as f:
            self.config_json = json.load(f)

        # load the dataset json
        self.dataset_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.NSLT_FILE)) as f:
            self.dataset_json = json.load(f)
        
        self.videos_paths = []
        self.paths_not_found = []
        self.labels = []
        self.start_frames = []
        self.end_frames = []
       
        self.dataset_json = None
        with open(os.path.join(CONFIG.ROOT_DIRECTORY, CONFIG.NSLT_FILE)) as f:
            self.dataset_json = json.load(f) 

        for el in tqdm(self.dataset_json.items()):
            video_id, properties = el[0], el[1]
            path = os.path.join(video_path, video_id + ".mp4")
            
            if not os.path.exists(path):
                self.paths_not_found.append(path)
                continue

            subset = properties["subset"]
            label, start, end = properties["action"]
            
            if start > max_start:
                continue
                
            if end > max_end:
                continue
            
            self.videos_paths.append(path)
            self.labels.append(label)
            self.start_frames.append(start)
            self.end_frames.append(end)
    
        self.videos_paths = np.array(self.video_paths)
        self.paths_not_found = np.array(self.paths_not_found)
        self.labels = np.array(self.labels)
        self.start_frames = np.array(self.start_frames)
        self.end_frames = np.array(self.end_frames)

        self.unique_labels = np.unique(self.labels)
        
    
    def preprocess_trajectory(self, traj : List[np.ndarray]):
        return traj
    
    def __len__(self):
        return len(self.videos_paths)

    def __getitem__(self, idx):
        path, label = self.videos_paths[idx], self.labels[idx]
        trajectory = SignRecognitionDataset.get_video(path)
        
        return self.preprocess_trajectory(trajectory), label

    def permutate(self):
        l = len(self.videos_paths)
        mask = np.arange(l)
        np.random.shuffle(mask)
        
        self.videos_paths = np.array(self.videos_paths)[mask]
        self.labels = np.array(self.labels)[mask]
        self.start_frames = np.array(self.start_frames)[mask]
        self.end_frames = np.array(self.end_frames)[mask]
        
    def sort_by_size(self):
        c = Counter(self.labels)
        _mask = sorted([ (10000 * c[l] + l, i) for i, l in enumerate(self.labels)])[::-1]
        mask_by_size = np.array([el[1] for el in _mask])

        self.video_paths        = np.array(self.video_paths)[mask_by_size]
        self.labels             = np.array(self.labels)[mask_by_size]
        self.start_frames       = np.array(self.start_frames)[mask_by_size]
        self.end_frames         = np.array(self.end_frames)[mask_by_size]

    def crop_video(self, trajectory : np.array) -> np.array:
        cropped = trajectory
        
        if self.FRAME_SIZE != 0:
            frame_size = len(trajectory)
            start = 0 
            
            if frame_size > self.FRAME_SIZE:
                start = np.random.randint(0, frame_size - self.FRAME_SIZE)
            cropped = trajectory[start: (start + self.FRAME_SIZE)]
                    
            if len(cropped) < self.FRAME_SIZE:
                necessary = self.FRAME_SIZE - len(cropped)
                t, h, w, c = trajectory.shape
                cropped = np.concatenate([cropped, np.zeros((necessary, h, w, c))], axis= 0)
                
            return cropped
                        
        return trajectory
                
    @staticmethod
    def get_video(video_path : str) -> List[np.ndarray]:

        if not os.path.exists(video_path):
            return None

        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            return None

        frames = []
        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                frame_array = np.array(frame)
                frames.append(cv2.cvtColor(frame_array, cv2.COLOR_BGR2RGB))
            else:
                break

        cap.release()
        return np.array(frames)

    @staticmethod
    def rescale_video(frames : np.ndarray, desired_shape) -> np.ndarray:
        refined = []
        for img in frames: 
            y, x, c = img.shape
            cropped = img[:, (x // 2 - y//2) : (x // 2 + y//2), :]
            scaled = cv2.resize(cropped, desired_shape)
            refined.append(scaled)
    
        return np.array(refined)

# %%
class SignRecognitionDatasetMHICachedV2(SignRecognitionDataset):

    def __init__(self, max_start: int, max_end, 
                 per_image_transform=None,
                 after_MHI_transform=None,
                 scaled_resolution : Tuple[int]= (224, 224),
                 frame_size:int=CONFIG.FRAME_SIZE,
                 data_limit : int = CONFIG.DATA_LIMIT,
                 decay : float = 0.7,
                 threshold_method : str = "regular",
                 threshold_val : float = 25/255.,
                 by_size=True,
                 train_val_split:float=CONFIG.PORTION_OF_DATA_FOR_TRAINING,
                 split:str="train") -> None:
        super().__init__(max_start, max_end)
        self.scaled_resolution = scaled_resolution
        self.DATA_LIMIT = data_limit
        self.by_size = by_size
        self.per_image_transform = per_image_transform
        self.after_MHI_transform = after_MHI_transform
        self.FRAME_SIZE = frame_size
        self.decay = decay
        self.threshold_method = threshold_method
        self.threshold_val = threshold_val
        
        self.keywords = ["image" ] + list(str(i) for i in range(frame_size-1))
        
        self.sort_by_size()
        
        if self.DATA_LIMIT > 0:
            self.video_paths        = self.video_paths[:self.DATA_LIMIT]
            self.labels             = self.labels[:self.DATA_LIMIT]
            self.start_frames       = self.start_frames[:self.DATA_LIMIT]
            self.end_frames         = self.end_frames[:self.DATA_LIMIT]
        
        
        self.label_2_id = { key : i for i, key in enumerate(np.unique(self.labels))}
        if data_limit < 0:
            train_ds_x, val_ds_x = train_test_split(self.videos_paths, train_size=train_val_split, random_state=42)
            train_ds_y, val_ds_y = train_test_split(self.labels, train_size=train_val_split, random_state=42)
            
        else:
            self.unique_labels = np.unique(self.labels[:data_limit])
            self.label_2_id = { key : i for i, key in enumerate(np.unique(self.labels))}
            
            train_ds_x, val_ds_x = train_test_split(self.videos_paths[:data_limit], train_size=train_val_split, random_state=42)
            train_ds_y, val_ds_y = train_test_split(self.labels[:data_limit], train_size=train_val_split, random_state=42)
                                    
        if split.lower() == "train":
            self.videos_paths = train_ds_x
            self.labels = train_ds_y
            
        elif split.lower() == "val":
            self.videos_paths = val_ds_x
            self.labels = val_ds_y
        
        else: 
            raise Exception("")

        self.cache_data()

    
    def cache_data(self):    
        self.cached_X = []
        self.cached_Y = []
        
        for i,path in tqdm(enumerate(self.videos_paths), desc="Cacheing"):
            
            trajectory = SignRecognitionDataset.get_video(path)  
            trajectory, label = self.preprocess_trajectory(trajectory), self.labels[i]     
            
            cached_X = []
            
            trajectory_length = trajectory.shape[0]
            if trajectory_length < self.FRAME_SIZE:
                cached_X.append(self.postprocess_trajectory(trajectory))
            else:
                for i in range(0, trajectory_length - self.FRAME_SIZE):
                    cached_X.append(self.postprocess_trajectory(trajectory[i: (i + self.FRAME_SIZE)]))

            
            onehotencoded = np.zeros(len(self.unique_labels))
            onehotencoded[self.label_2_id[label]] = 1.0
                    
            self.cached_X.append(cached_X)
            self.cached_Y.append(onehotencoded)
        
    def preprocess_trajectory(self, traj : List[np.ndarray]):
        return SignRecognitionDataset.rescale_video(traj, self.scaled_resolution)
        
    def __len__(self):
        return len(self.videos_paths)

    def postprocess_trajectory(self, traj : np.ndarray) -> np.ndarray:
        # timeframe, Width, height, channels
        ts, w, h, c = traj.shape
        
        mhi = np.zeros((w, h))
                
        for i in range(1, ts):
            frame_diff = np.abs(traj[i] - traj[i-1])
            gray_diff = np.mean(frame_diff, axis=2)
            
            _, binary_diff = cv2.threshold(gray_diff, self.threshold_val, 1.0, cv2.THRESH_BINARY)
    
    
            mhi = mhi * (1.0 - self.decay) + binary_diff

        mhi = mhi.reshape(mhi.shape[0], mhi.shape[1], 1)
        return np.concatenate([mhi,mhi,mhi], axis=2)


    def __getitem__(self, idx):
        
        trajectory, label = self.cached_X[idx], self.cached_Y[idx]
        
        # get random MHI from trajectory
        traj_len = len(trajectory)
        
        trajectory = trajectory[np.random.randint(traj_len)]        
        trajectory = self.per_image_transform(image=trajectory)["image"]

        return trajectory, label
    
    
import matplotlib.pyplot as plt 

transform = A.Compose(
    [
        A.Normalize(mean=CONFIG.mean, std=CONFIG.std),
        A.HorizontalFlip(p=CONFIG.P_OF_TRANSFORM),
        A.ShiftScaleRotate(p=CONFIG.P_OF_TRANSFORM, shift_limit=CONFIG.SHIFT_LIMIT, 
                           scale_limit=CONFIG.SCALE_LIMIT, rotate_limit=CONFIG.ROTATE_LIMIT),
        #A.RandomBrightnessContrast(p=CONFIG.P_OF_TRANSFORM_COLOR),
        #A.RGBShift(p=CONFIG.P_OF_TRANSFORM_COLOR),
    ]
)

train_ds = SignRecognitionDatasetMHICachedV2(1, 150, per_image_transform=transform, decay=0.09,
                                             data_limit=10, split="train")
val_ds = SignRecognitionDatasetMHICachedV2(1, 150, per_image_transform=transform, decay=0.09,
                                           data_limit=10, split="val")


print(f"size of train_ds = {len(train_ds)}, size of val_ds = {len(val_ds)}")
x, y = next(iter(train_ds))
x_shape = x.shape
y_shape = y.shape
print(x_shape, y_shape)
# Out:
# 100%|██████████| 2038/2038 [00:00<00:00, 42621.05it/s]
# Cacheing: 8it [00:09,  1.22s/it]
# 100%|██████████| 2038/2038 [00:00<00:00, 42861.04it/s]
# Cacheing: 2it [00:01,  1.22it/s]
# size of train_ds = 8, size of val_ds = 2
# (224, 224, 3) (1,)

# %%
def dataset_train_generator():
    # Instantiate your existing dataset loader

    for i in range(len(train_ds)):
        X_batch, Y_batch = train_ds[i]
        yield X_batch, Y_batch
        
def dataset_val_generator():
    # Instantiate your existing dataset loader

    for i in range(len(val_ds)):
        X_batch, Y_batch = val_ds[i]
        yield X_batch, Y_batch        

train_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_train_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)

val_dataset = tf.data.Dataset.from_generator(
    lambda: dataset_val_generator(),
    output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
    output_shapes=(x_shape, y_shape)
).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      12         X_batch, Y_batch = val_ds[i]
#      13         yield X_batch, Y_batch
#      15 train_dataset = tf.data.Dataset.from_generator(
#      16     lambda: dataset_train_generator(),
#      17     output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
# ---> 18     output_shapes=(x_shape, y_shape)
#      19 ).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)
#      21 val_dataset = tf.data.Dataset.from_generator(
#      22     lambda: dataset_val_generator(),
#      23     output_types=(tf.float32, tf.float32),  # Adjust types based on your actual data
#      24     output_shapes=(x_shape, y_shape)
#      25 ).prefetch(tf.data.AUTOTUNE).batch(CONFIG.BATCH_SIZE)
#
# NameError: name 'x_shape' is not defined

# %%
import time 

ls = [] 

start_t = time.time()
for x,y in tqdm(train_dataset):
    ls.append(y)

print(f"iteration through dataset took :  {round(time.time() - start_t, CONFIG.ROUND_DIGIT)} s")
# Out:
# 10it [00:05,  1.73it/s]
# iteration through dataset took :  5.791 s

# %% [markdown]
# ## Training - Setup

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LeakyReLU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import backend as K
from wandb.keras import WandbMetricsLogger
from keras.callbacks import Callback
from wandb.keras import WandbMetricsLogger
import tensorflow as tf
import wandb


class CosineAnnealingLearningRateScheduler(Callback):
    def __init__(self, max_lr, min_lr, T_max):
        super(CosineAnnealingLearningRateScheduler, self).__init__()
        self.max_lr = max_lr  # Maximum learning rate (i.e., start learning rate)
        self.min_lr = min_lr  # Minimum learning rate
        self.T_max = T_max    # Specifies the number of epochs per cycle
        self.t = 0            # Current epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.t += 1
        cos = np.cos(np.pi * (self.t % self.T_max) / self.T_max)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + cos)

        keras.backend.set_value(self.model.optimizer.lr, lr)

def keras_train(model, filepath : str, run_name : str, max_lr = 1e-4, min_lr = 5e-5, T_max=50, epochs=100,
                decay = 0.09,USE_WANDB=True): 


    train_ds = SignRecognitionDatasetMHI(1, 150, per_image_transform=transform, decay=decay, split="train")
    val_ds = SignRecognitionDatasetMHI(1, 150, per_image_transform=transform, decay=decay, split="val")
    
    checkpoint = keras.callbacks.ModelCheckpoint(filepath,
                                                 monitor="val_categorical_accuracy",
                                                 verbose=0,
                                                 save_best_only=True,
                                                 mode="max",
                                                 save_freq="epoch")
    
    cosine_annealer = CosineAnnealingLearningRateScheduler(max_lr=max_lr,
                                                           min_lr=min_lr,
                                                           T_max=T_max)

    callbacks = [checkpoint, cosine_annealer]

    if USE_WANDB:
        wandb.init(project=CONFIG.WANDB_RUN,
                        name=run_name,
                        notes="Model summary : \n" + str(model),
                        config={"max_lr" : max_lr, 
                                "min_lr" : min_lr, 
                                "scheduler" : "cosineAnnealer", 
                                "epochs" : epochs, 
                                "T_max" : T_max, 
                                "train_size" : len(train_ds.labels),
                                "val_size" : len(val_ds.labels),
                                "unique_classes" : len(np.unique(train_ds.labels)), 
                                "video_length" : CONFIG.FRAME_SIZE,
                                "decay" : decay,
                                "SHIFT_LIMIT" : CONFIG.SHIFT_LIMIT,
                                "SCALE_LIMIT" : CONFIG.SCALE_LIMIT,
                                "ROTATE_LIMIT" : CONFIG.ROTATE_LIMIT
                               })
        callbacks.append(WandbMetricsLogger())
    
    #Adam Optimizer - fixed learning rate.
    adam_optimizer = tf.keras.optimizers.Adam(learning_rate=max_lr, clipnorm=1.)
    #lr_metric = get_lr_metric(adam_optimizer)

    model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    
    #history = model.fit(train_dataset_parquet, epochs=epochs, validation_data = val_dataset_parquet, batch_size = 8, callbacks=[WandbMetricsLogger(), checkpoint, cosine_annealer])
    history = model.fit(train_ds, epochs=epochs, validation_data = val_ds, batch_size = 8, callbacks=callbacks)
    #wandb.finish()
    if USE_WANDB:      
        wandb.finish()
    
    return history

# %% [markdown]
# ## Train MobileNetV3Small Transfer Learning with ImageNet

# %%
MHI_SHAPE = (224,224,3)
#reshaped_data = data.reshape(-1, 480, 640, 1)
# get the base model, exclude final dense layers - we will modify/output this
base_model = tf.keras.applications.MobileNetV3Small(input_shape = MHI_SHAPE,
                                               include_top = False,
                                               weights = 'imagenet',
                                               pooling='max')
# Freeze the convolutional base
base_model.trainable = False
#get the base model summary
base_model.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_2[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add (TFOpLambda)    (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#
#  re_lu (ReLU)                (None, 112, 112, 16)         0         ['tf.math.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 112, 112, 16)         0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_1[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_1 (TFOpLambda)  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#                                                                     /Conv_1[0][0]']
#
#  re_lu_2 (ReLU)              (None, 1, 1, 16)             0         ['tf.math.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 16)             0         ['re_lu_2[0][0]']
#  mbda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_1[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_3 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_3[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_4 (ReLU)              (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_4[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_5 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_6 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_6[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_2 (TFOpLambda)  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_7 (ReLU)              (None, 28, 28, 96)           0         ['tf.math.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 28, 28, 96)           0         ['re_lu_7[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_3 (TFOpLambda)  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_8 (ReLU)              (None, 14, 14, 96)           0         ['tf.math.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 14, 14, 96)           0         ['re_lu_8[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_3[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_2[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_4 (TFOpLambda)  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_9 (ReLU)              (None, 1, 1, 96)             0         ['tf.math.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None, 1, 1, 96)             0         ['re_lu_9[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_2[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_5 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_10 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_10[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_6 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_11 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_11[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_4[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_7 (TFOpLambda)  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_12 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 1, 1, 240)            0         ['re_lu_12[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_4[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_8 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_13 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_13[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_9 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_14 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_14[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_6[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_10 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_15 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_15[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_6[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_11 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_16[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_12 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_17[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_8[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_13 (TFOpLambda  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_18 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_18[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_8[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_14 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_14[0][0]']
#
#  tf.math.multiply_14 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_19[0][0]']
#  ambda)
#
#  multiply_9 (Multiply)       (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_15 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_15[0][0]']
#
#  tf.math.multiply_15 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_20[0][0]']
#  ambda)
#
#  multiply_10 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_16 (TFOpLambda  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_21 (ReLU)             (None, 1, 1, 144)            0         ['tf.math.add_16[0][0]']
#
#  tf.math.multiply_16 (TFOpL  (None, 1, 1, 144)            0         ['re_lu_21[0][0]']
#  ambda)
#
#  expanded_conv_7/squeeze_ex  (None, 14, 14, 144)          0         ['multiply_10[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_16[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 48)           6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
# ...
#  )                                                                  Norm[0][0]']
#
#  re_lu_25 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_20[0][0]']
#
#  tf.math.multiply_20 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_25[0][0]']
#  ambda)
#
#  multiply_13 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_20[0][0]']
#
#  expanded_conv_9/depthwise   (None, 7, 7, 576)            14400     ['multiply_13[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 7, 7, 576)            2304      ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_21 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_26 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_26[0][0]']
#  ambda)
#
#  multiply_14 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_21[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_14[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_22 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_27 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_27[0][0]']
#  ambda)
#
#  expanded_conv_9/squeeze_ex  (None, 7, 7, 576)            0         ['multiply_14[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_22[0][0]']
#
#  expanded_conv_9/project (C  (None, 7, 7, 96)             55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, 7, 7, 96)             384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 7, 7, 96)             0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 7, 7, 576)            55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 7, 7, 576)            2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_23 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#  )                                                                  hNorm[0][0]']
#
#  re_lu_28 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_28[0][0]']
#  ambda)
#
#  multiply_15 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_23[0][0]']
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_15[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_24 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_29 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_29[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_25 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_30 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_30[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_25[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_26 (TFOpLambda  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  )
#
#  re_lu_31 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_31[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_26[0][0]']
#
#  max_pool (GlobalMaxPooling  (None, 576)                  0         ['multiply_17[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 939120 (3.58 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 939120 (3.58 MB)
# __________________________________________________________________________________________________

# %%
model = Sequential()
base = tf.keras.applications.ResNet50V2(include_top=False)
model.add(base)
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 5s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, None, None, 2048   23564800
#                              )
#
#  dense_1 (Dense)             (None, None, None, 7)     14343
#
# =================================================================
# Total params: 23579143 (89.95 MB)
# Trainable params: 23533703 (89.77 MB)
# Non-trainable params: 45440 (177.50 KB)
# _________________________________________________________________

# %%
#len(train_ds.unique_labels) outputs the length of the labels.
#MobileNetV3 without additional dense layer - add softmax classification layer
model = Sequential()
model.add(base_model)
model.add(Dense(len(train_ds.unique_labels), activation='softmax'))

keras_train(model, filepath=os.path.join("models", "MHI_MobileNetV3Small.tf"))
# Out:
# Epoch 1/100
#      10/Unknown - 11s 587ms/step - loss: 2.7736 - categorical_accuracy: 0.1250INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# 10/10 [==============================] - 42s 4s/step - loss: 2.7736 - categorical_accuracy: 0.1250 - val_loss: 2.6568 - val_categorical_accuracy: 0.1500
# Epoch 2/100
# 10/10 [==============================] - ETA: 0s - loss: 2.6335 - categorical_accuracy: 0.1750INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# 10/10 [==============================] - 35s 4s/step - loss: 2.6335 - categorical_accuracy: 0.1750 - val_loss: 2.4964 - val_categorical_accuracy: 0.2000
# Epoch 3/100
# 10/10 [==============================] - ETA: 0s - loss: 2.5041 - categorical_accuracy: 0.1625INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# INFO:tensorflow:Assets written to: models\MHI_MobileNetV3Small.tf\assets
# 10/10 [==============================] - 35s 4s/step - loss: 2.5041 - categorical_accuracy: 0.1625 - val_loss: 2.2893 - val_categorical_accuracy: 0.2500
# Epoch 4/100
# 10/10 [==============================] - 8s 790ms/step - loss: 2.4289 - categorical_accuracy: 0.1375 - val_loss: 2.1219 - val_categorical_accuracy: 0.1500
# Epoch 5/100
# 10/10 [==============================] - 7s 703ms/step - loss: 2.3095 - categorical_accuracy: 0.1500 - val_loss: 2.3840 - val_categorical_accuracy: 0.2500
# Epoch 6/100
# 10/10 [==============================] - 7s 701ms/step - loss: 2.1987 - categorical_accuracy: 0.1875 - val_loss: 2.1743 - val_categorical_accuracy: 0.2000
# Epoch 7/100
# 10/10 [==============================] - 7s 699ms/step - loss: 2.0786 - categorical_accuracy: 0.2000 - val_loss: 2.1657 - val_categorical_accuracy: 0.1000
# Epoch 8/100
# 10/10 [==============================] - 7s 689ms/step - loss: 2.1797 - categorical_accuracy: 0.1625 - val_loss: 2.1313 - val_categorical_accuracy: 0.1500
# Epoch 9/100
# 10/10 [==============================] - 7s 697ms/step - loss: 2.1208 - categorical_accuracy: 0.1875 - val_loss: 2.2340 - val_categorical_accuracy: 0.1500
# Epoch 10/100
# 10/10 [==============================] - 7s 670ms/step - loss: 2.0560 - categorical_accuracy: 0.1500 - val_loss: 2.1304 - val_categorical_accuracy: 0.2000
# Epoch 11/100
# 10/10 [==============================] - 7s 709ms/step - loss: 2.0905 - categorical_accuracy: 0.1625 - val_loss: 2.2544 - val_categorical_accuracy: 0.1000
# Epoch 12/100
# 10/10 [==============================] - 7s 690ms/step - loss: 2.0740 - categorical_accuracy: 0.1875 - val_loss: 2.0292 - val_categorical_accuracy: 0.1000
# Epoch 13/100
# 10/10 [==============================] - 7s 709ms/step - loss: 2.0045 - categorical_accuracy: 0.1750 - val_loss: 1.9302 - val_categorical_accuracy: 0.2000
# Epoch 14/100
# 10/10 [==============================] - 7s 680ms/step - loss: 2.0074 - categorical_accuracy: 0.2375 - val_loss: 2.2143 - val_categorical_accuracy: 0.1000
# Epoch 15/100
# 10/10 [==============================] - 7s 697ms/step - loss: 2.0509 - categorical_accuracy: 0.2250 - val_loss: 2.1025 - val_categorical_accuracy: 0.1000
# Epoch 16/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.9783 - categorical_accuracy: 0.2000 - val_loss: 2.1801 - val_categorical_accuracy: 0.1500
# Epoch 17/100
# 10/10 [==============================] - 9s 884ms/step - loss: 2.0272 - categorical_accuracy: 0.1500 - val_loss: 2.0838 - val_categorical_accuracy: 0.2500
# Epoch 18/100
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9452 - categorical_accuracy: 0.2083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 7
#       4 model.add(base_model)
#       5 model.add(Dense(len(train_ds.unique_labels), activation='softmax'))
# ----> 7 keras_train(model, filepath=os.path.join("models", "MHI_MobileNetV3Small.tf"))
#
# Cell In[30], line 63, in keras_train(model, filepath, max_lr, min_lr, T_max, epochs)
#      47 """wandb.init(project=CONFIG.WANDB_RUN,
#      48                  name=run_name,
#      49                  notes="Model summary : \n" + str(model),
#    (...)
#      59                          "features" : mediapipe_features
#      60                          }) """
#      62 #history = model.fit(train_dataset_parquet, epochs=epochs, validation_data = val_dataset_parquet, batch_size = 8, callbacks=[WandbMetricsLogger(), checkpoint, cosine_annealer])
# ---> 63 history = model.fit(train_dataset, epochs=epochs, validation_data = val_dataset, batch_size = 8, callbacks=[checkpoint])
#      64 #wandb.finish()
#      66 return history
#
# File d:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Anaconda\Lib\site-packages\keras\src\engine\training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:867, in Function._call(self, *args, **kwds)
#     864   self._lock.release()
#     865   # In this case we have created variables on the first call, so we run the
#     866   # defunned version which is guaranteed to never create variables.
# --> 867   return tracing_compilation.call_function(
#     868       args, kwds, self._no_variable_creation_config
#     869   )
#     870 elif self._variable_creation_config is not None:
#     871   # Release the lock early so that multiple threads can perform the call
#     872   # in parallel.
#     873   self._lock.release()
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File d:\Anaconda\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:
